# %%
import sympy as sp
import numpy as np
import matplotlib.pyplot as plt
import postprocess as pp
# import plots
import os
# Out:
# postproc

# %% [markdown]
# ## Investigating Bifurcations and Stability

# %%
experiment = '../../test/output/linesearch/7375f6da731f67fd282aa1c5fdab6682'
params, data, signature = pp.load_data(experiment)

# %%
pp.plot_operator_spectrum(data, parameters=params)
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <Axes: title={'center': "Spectrum of Nonlinear Operator $H_{\\ell}:=E_\\ell''(y_t)$"}, xlabel='Load $t$', ylabel='Eigenvalues'>)

# %%
data["eigs"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/indexes/base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'eigs'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 data["eigs"]
#
# ...

# %%
[x["lambda_t"] for x in data["cone_data"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 [x["lambda_t"] for x in data["cone_data"]]
#
# Cell In[18], line 1, in <listcomp>(.0)
# ----> 1 [x["lambda_t"] for x in data["cone_data"]]
#
# KeyError: 'lambda_t'

# %%
experiment = '../../test/output/linesearch/4726c1e8f854d713d985fe01f6d40712'
params, data, signature = pp.load_data(experiment)

# %%
pp.plot_operator_spectrum(data, parameters=params)
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <Axes: title={'center': "Spectrum of Nonlinear Operator $H_{\\ell}:=E_\\ell''(y_t)$"}, xlabel='Load $t$', ylabel='Eigenvalues'>)
