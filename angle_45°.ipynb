# %% [markdown]
# <a href="https://colab.research.google.com/github/kumiori/mec647/blob/Assala_T/angle_45%C2%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
import sys

try:
    import google.colab  # noqa: F401
except ImportError:
    import ufl  # noqa: F401
    import dolfinx  # noqa: F401
else:
    try:
        import ufl
        import dolfinx
    except ImportError:
        # !wget "https://fem-on-colab.github.io/releases/fenicsx-install.sh" -O "/tmp/fenicsx-install.sh" && bash "/tmp/fenicsx-install.sh";
        import ufl  # noqa: F401
        import dolfinx  # noqa: F401

try:
    import pyvista
except ImportError:
    # !{sys.executable} -m pip install --upgrade pyvista itkwidgets;
    import pyvista  # noqa: F401
    from pyvista.utilities import xvfb

try:
    import gmsh
except ImportError:
    # !{sys.executable} -m pip install gmsh
    import gmsh

# !sudo apt install libgl1-mesa-glx xvfb;
# !{sys.executable} -m pip install pythreejs;
# !{sys.executable} -m pip install ipygany;
# !{sys.executable} -m pip install --upgrade PyYAML
# !pip install --ignore-installed PyYAML

# %%
branch_name = 'main'
# branch_name = 'Assala_T'

# !rm -rf mec647
try:
  # !git clone -b {branch_name} https://github.com/kumiori/mec647.git
  sys.path.append('mec647/')

  print()
  print(f'Cloned brach: {branch_name}')
  print(f'Last commit message')
  # !cd mec647/ && git log -n 1 && cd ..
  import mec647
  from mec647 import meshes
  from mec647.meshes import primitives
  # from mec647.algorithms import am
  from mec647.utils.viz import plot_mesh, plot_scalar, plot_vector

except Exception as e:
  print('Something went wrong', e)
  # !rm -rf mec647
  # !git clone https://github.com/kumiori/mec647.git
# Out:
# Cloning into 'mec647'...
# remote: Enumerating objects: 1255, done.
# remote: Counting objects: 100% (1255/1255), done.
# remote: Compressing objects: 100% (929/929), done.
# remote: Total 1255 (delta 641), reused 628 (delta 285), pack-reused 0
# Receiving objects: 100% (1255/1255), 19.66 MiB | 11.38 MiB/s, done.
# Resolving deltas: 100% (641/641), done.
#
# Cloned brach: main
# Last commit message
# commit 25aa48ad32b5c11d7dd6e087bdf09fea88442b28 (HEAD -> main, origin/main, origin/HEAD)
# Merge: 822d5b0 222efb0
# Author: igorassist <igorassist98@gmail.com>
# Date:   Sat Feb 26 14:14:34 2022 +0100
#
#     Merge branch 'main' of https://github.com/kumiori/mec647

# %%
import matplotlib.pyplot as plt
from petsc4py import PETSc
import numpy as np
from mpi4py import MPI

comm = MPI.COMM_WORLD

from dolfinx.fem import (
    Constant,
    Function,
    FunctionSpace,
    assemble_scalar,
    dirichletbc,
    form,
    locate_dofs_geometrical,
    set_bc,
)

# meshes
import meshes
from meshes import primitives

import models
from models import DamageElasticityModel as Brittle

# %%
import numpy as np
import yaml
import json
import sys
import os
from pathlib import Path

from mpi4py import MPI

import petsc4py
from petsc4py import PETSc

import dolfinx
import dolfinx.plot
from dolfinx import log
import ufl

import algorithms
from algorithms import am

from dolfinx.io import XDMFFile

import logging

logging.basicConfig(level=logging.INFO)

import dolfinx
import dolfinx.plot
import dolfinx.io
from dolfinx.fem import (
    Constant,
    Function,
    FunctionSpace,
    assemble_scalar,
    dirichletbc,
    form,
    locate_dofs_geometrical,
    set_bc,
)
import matplotlib.pyplot as plt
import pyvista 
from pyvista.utilities import xvfb


# visualisation
from utils import viz
import matplotlib.pyplot as plt
from utils.viz import plot_mesh, plot_vector, plot_scalar
generateStepwiseOutput=True

# %%
# Parameters
parameters = {
    'loading': {
        'min': 0.0,
        'max': 1.,
        'steps': 10
    },
    'geometry': {
        'geom_type': 'Plate with Kink',
        'Lx': .6,
        'Ly': 1, 
        'L0': 0.3,
        'theta': -45,
        'eta': 1e-2,
    },
    'model': {
        'E': 3.e+9,
        'nu': 0.4,
        'w1': 1.,
        'ell': 0.1, 
        'k_res': 1.e-8
    },
    'solvers': {
          'elasticity': {        
            'snes': {
                'snes_type': 'newtontr',
                'snes_stol': 1e-8,
                'snes_atol': 1e-8,
                'snes_rtol': 1e-8,
                'snes_max_it': 250,
                'snes_monitor': "",
                'ksp_type': 'preonly',
                'pc_type': 'lu',
                'pc_factor_mat_solver_type': 'mumps'
            }
        },
          'damage': {        
            'snes': {
                'snes_type': 'vinewtonrsls',
                'snes_stol': 1e-5,
                'snes_atol': 1e-5,
                'snes_rtol': 1e-8,
                'snes_max_it': 100,
                'snes_monitor': "",
                'ksp_type': 'preonly',
                'pc_type': 'lu',
                'pc_factor_mat_solver_type': 'mumps'
            },
        },
          'damage_elasticity': {
            "max_it": 2000,
            "alpha_rtol": 1.0e-4,
            "criterion": "alpha_H1"
          }
    }
}

# %%
def  mesh_kink(name,
                Lx,
                Ly,
                # a,
                # b,
               rad,
               theta,
              # theta
                eta,
                lc,
                tdim,
                order=1,
                msh_file=None,
                comm=MPI.COMM_WORLD):
    """
    Create mesh of 3d tensile test specimen according to ISO 6892-1:2019 using the Python API of Gmsh.
    """
    # Perform Gmsh work only on rank = 0

    if comm.rank == 0:

        import gmsh

        # Initialise gmsh and set options
        gmsh.initialize()
        gmsh.option.setNumber("General.Terminal", 1)

        gmsh.option.setNumber("Mesh.Algorithm", 6)
        model = gmsh.model()
        model.add("Rectangle")
        model.setCurrent("Rectangle")
        # points = [p1, p2, p3, p4, p5, p6, p7, p8,p9,p10,p11]
        p1 = model.geo.addPoint(0.0, 0.0, 0, lc, tag=1)
        p2 = model.geo.addPoint(Lx, 0.0, 0, lc, tag=2)
        p3 = model.geo.addPoint(Lx, Ly, 0.0, lc, tag=3)
        p4 = model.geo.addPoint(0, Ly, 0, lc, tag=4)

        p5 = model.geo.addPoint(Lx/2 + rad*np.cos(theta), Ly/2 + rad*np.sin(theta), 0.0, lc/3, tag=5)
        p7 = model.geo.addPoint(Lx/2 - rad*np.cos(theta), Ly/2 - rad*np.sin(theta), 0.0, lc/3, tag=7)

        # p5 = model.geo.addPoint(Lx/2 +a, Ly/2 +b,0.0, lc/1.5, tag=5)
        p6 = model.geo.addPoint(Lx/2, Ly/2 + eta,0, lc, tag=6)
        # p7 = model.geo.addPoint(Lx/2-a,Ly/2-b,0,lc/1.5, tag=7)
        p8 = model.geo.addPoint(Lx/2,Ly/2 - eta,0, lc, tag=8)

        # Lines = [L1, L2, L3, L4, L5, L6, L7, L8]
        L1 = model.geo.addLine(p1, p2, tag=1)
        L2 = model.geo.addLine(p2, p3, tag=2)
        L3 = model.geo.addLine(p3, p4, tag=3)
        L4 = model.geo.addLine(p4, p1, tag=4)
        L5 = model.geo.addLine(p5, p6, tag=5)
        L6 = model.geo.addLine(p6, p7, tag=6)
        L7 = model.geo.addLine(p7, p8, tag=7)
        L8 = model.geo.addLine(p8, p5, tag=8)


        
        cloop1 = model.geo.addCurveLoop([L1, L2, L3, L4])
        cloop2 = model.geo.addCurveLoop([L5, L6, L7, L8])
        
        # surface_1 =
        model.geo.addPlaneSurface([cloop1, cloop2])

        model.geo.synchronize()
        surface_entities = [model[1] for model in model.getEntities(tdim)]

        model.addPhysicalGroup(tdim, surface_entities, tag=1)
        model.setPhysicalName(tdim, 1, "Rectangle surface")

        # Set mesh size via points
        # gmsh.model.mesh.setSize(points, lc)  # heuristic

        # gmsh.model.mesh.optimize("Netgen")

        # Set geometric order of mesh cells
        gmsh.model.mesh.setOrder(order)

        # Define physical groups for subdomains (! target tag > 0)
        # domain = 1
        # gmsh.model.addPhysicalGroup(tdim, [v[1] for v in volumes], domain)
        # gmsh.model.setPhysicalName(tdim, domain, 'domain')
              

        gmsh.model.addPhysicalGroup(tdim - 1, [1], tag=9)
        gmsh.model.setPhysicalName(tdim - 1, 9, "Bottom  of the Plate")
        gmsh.model.addPhysicalGroup(tdim - 1, [4], tag=10)
        gmsh.model.setPhysicalName(tdim - 1, 10, "Top  of the Plate")
        gmsh.model.addPhysicalGroup(tdim - 1, [5], tag=11)
        gmsh.model.setPhysicalName(tdim - 1, 11, "1/2 Top of the TipCrack")
        gmsh.model.addPhysicalGroup(tdim - 1, [6], tag=12)
        gmsh.model.setPhysicalName(tdim - 1, 12, "1/2 Top of the TipCrack")
        gmsh.model.addPhysicalGroup(tdim - 1, [7], tag=13)
        gmsh.model.setPhysicalName(tdim - 1, 13, "1/2 bottom of the TipCrack")
        gmsh.model.addPhysicalGroup(tdim - 1, [8], tag=14)
        gmsh.model.setPhysicalName(tdim - 1, 14, "1/2 bottom of the TipCrack")

        model.mesh.generate(tdim)


        #Generating the mesh
    model.geo.synchronize()
    model.mesh.generate(tdim)

    return gmsh.model

# %%
Lx = parameters.get("geometry").get("Lx")
Ly = parameters.get("geometry").get("Ly")
L0 = parameters.get("geometry").get("L0")
eta = parameters.get("geometry").get("eta")

geom_type = parameters.get("geometry").get("geom_type")

lc=0.02
theta = -45/180 * np.pi

gmsh_model=mesh_kink('mesh', Lx, Ly, L0/2, theta, eta,lc, 2, 1)

mesh, mts = meshes.gmsh_model_to_mesh(gmsh_model,
                               cell_data=False,
                               facet_data=True,
                               gdim=2)


plt.figure()
ax = plot_mesh(mesh)
fig = ax.get_figure()
fig.savefig(f"mesh.png")

# %%
# usedMesh=mesh 
# Enables opportunity to improve mesh at specific places, might lead to deformed elements
# Functional Setting

element_u = ufl.VectorElement("Lagrange", mesh.ufl_cell(),
                              degree=1, dim=2)

element_alpha = ufl.FiniteElement("Lagrange", mesh.ufl_cell(),
                              degree=1)

V_u = dolfinx.fem.FunctionSpace(mesh, element_u) 
V_alpha = dolfinx.fem.FunctionSpace(mesh, element_alpha) 

u = dolfinx.fem.Function(V_u, name="Displacement")
u_ = dolfinx.fem.Function(V_u, name="BoundaryDisplacement")


alpha = dolfinx.fem.Function(V_alpha, name="Damage")

# Pack state
state = {"u": u, "alpha": alpha}

# Bounds
alpha_ub = dolfinx.fem.Function(V_alpha, name="UpperBoundDamage")
alpha_lb = dolfinx.fem.Function(V_alpha, name="LowerBoundDamage")



dx = ufl.Measure("dx", domain = mesh)
ds = ufl.Measure("ds", domain = mesh)


# Boundary sets
dofs_alpha_left = locate_dofs_geometrical(V_alpha, lambda x: np.isclose(x[0], 0.))
dofs_alpha_right = locate_dofs_geometrical(V_alpha, lambda x: np.isclose(x[0], Lx))
dofs_alpha_bottom = locate_dofs_geometrical(V_alpha, lambda x: np.isclose(x[1], 0.))
dofs_alpha_top = locate_dofs_geometrical(V_alpha, lambda x: np.isclose(x[1], Ly))


dofs_u_left = locate_dofs_geometrical(V_u, lambda x: np.isclose(x[0], 0.))
dofs_u_right = locate_dofs_geometrical(V_u, lambda x: np.isclose(x[0], Lx))
dofs_u_top = locate_dofs_geometrical(V_u, lambda x: np.isclose(x[1], Ly))
dofs_u_bottom = locate_dofs_geometrical(V_u, lambda x: np.isclose(x[1], 0))

# Boundary data
u_.interpolate(lambda x: (np.zeros_like(x[0]), np.ones_like(x[1])))

# Bounds (nontrivial)
alpha_lb.interpolate(lambda x: np.zeros_like(x[0]))
alpha_ub.interpolate(lambda x: np.ones_like(x[0]))

# Boundary conditions
bcs_u = [
         dirichletbc(np.array([0., 0.], dtype=PETSc.ScalarType),
                      dofs_u_bottom,
                      V_u),
         dirichletbc(u_, dofs_u_top)
         ]

bcs_alpha = [
             dirichletbc(np.array(0., dtype = PETSc.ScalarType),
                         np.concatenate([dofs_alpha_bottom, dofs_alpha_top]),
                         V_alpha)
]

bcs = {"bcs_u": bcs_u, "bcs_alpha": bcs_alpha}

model = Brittle(parameters["model"])

total_energy = model.total_energy_density(state) * dx
solver = am.AlternateMinimisation(total_energy,
                         state,
                         bcs,
                         parameters.get("solvers"),
                         bounds=(alpha_lb, alpha_ub)
                         )

# %%
# %%time
# Loop for evolution
loads = np.linspace(parameters.get("loading").get("min"),
                    parameters.get("loading").get("max"),
                    parameters.get("loading").get("steps"))

data = {
    'elastic': [],
    'surface': [],
    'total': [],
    'load': []
}
xvfb.start_xvfb(wait=0.05)
pyvista.OFF_SCREEN = True
plotter = pyvista.Plotter(
        title="Displacement",
        window_size=[1600, 600],
        shape=(1, 2),
    )

for (i_t, t) in enumerate(loads):
  # update boundary conditions

  u_.interpolate(lambda x: ( np.zeros_like(x[0]), t*np.ones_like(x[1])))
  u_.vector.ghostUpdate(addv=PETSc.InsertMode.INSERT,
                        mode=PETSc.ScatterMode.FORWARD)

  # update lower bound for damage
  alpha.vector.copy(alpha_lb.vector)
  alpha.vector.ghostUpdate(addv=PETSc.InsertMode.INSERT,
                        mode=PETSc.ScatterMode.FORWARD)

  # solve for current load step
  print(f"Solving timestep {i_t}, load: {t}")

  solver.solve()

  # postprocessing
  # global

  surface_energy = assemble_scalar(dolfinx.fem.form(model.damage_dissipation_density(state) * dx))

  elastic_energy = assemble_scalar(
        dolfinx.fem.form(model.elastic_energy_density(state) * dx))
  
  data.get('elastic').append(elastic_energy)
  data.get('surface').append(surface_energy)
  data.get('total').append(surface_energy+elastic_energy)
  data.get('load').append(t)

  print(f"Solved timestep {i_t}, load: {t}")
  print(f"Elastic Energy {elastic_energy:.3g}, Surface energy: {surface_energy:.3g}")
  print("\n\n")

  _plt = plot_scalar(alpha, plotter, subplot=(0, 0))
  _plt.screenshot(f"large_ell.png")
  if generateStepwiseOutput:
    if(surface_energy>1 and i_t%25==0):
    #if(i_t>1050 and i_t<1100):
        _plt = plot_scalar(alpha, plotter, subplot=(0, 0))
        #_plt.screenshot(f"./plots/s30/alpha"+str(i_t)+".png")
        _plt.screenshot(f"large_ell.png")
    #if i_t>1100:
    #    break
  if(i_t>20 and  elastic_energy<1E-3 and elastic_energy<surface_energy):
      #Brute force approach to determine, whether we have already reached a crack propagation state
      print("fail")
      break

  # savings?
# Out:
# Solving timestep 0, load: 0.0
#   0 SNES Function norm 0.000000000000e+00
#   0 SNES Function norm 0.000000000000e+00
# Solved timestep 0, load: 0.0
# Elastic Energy 0, Surface energy: 0
#
#
#
# Solving timestep 1, load: 0.1111111111111111
#   0 SNES Function norm 9.705961951275e-01
#   1 SNES Function norm 9.148688922811e-01
#   2 SNES Function norm 8.034142865883e-01
#   3 SNES Function norm 5.805050752028e-01
#   4 SNES Function norm 1.346866524317e-01
#   5 SNES Function norm 5.190642174880e-16
#   0 SNES Function norm 0.000000000000e+00
# Solved timestep 1, load: 0.1111111111111111
# Elastic Energy 0.00329, Surface energy: 0
#
#
#
# Solving timestep 2, load: 0.2222222222222222
#   0 SNES Function norm 9.705961951275e-01
#   1 SNES Function norm 7.764769561020e-01
#   2 SNES Function norm 3.882384780510e-01
#   3 SNES Function norm 1.194728719245e-15
#   0 SNES Function norm 2.219674379275e-06
# Solved timestep 2, load: 0.2222222222222222
# Elastic Energy 0.0132, Surface energy: 0
#
#
#
# Solving timestep 3, load: 0.3333333333333333
#   0 SNES Function norm 9.705961951275e-01
#   1 SNES Function norm 5.823577170765e-01
#   2 SNES Function norm 1.877723889931e-15
#   0 SNES Function norm 9.701465460661e-05
#   1 SNES Function norm 2.862470947189e-05
#   2 SNES Function norm 2.998604305027e-20
#   0 SNES Function norm 3.757406911136e-05
#   1 SNES Function norm 1.456373991991e-15
#   0 SNES Function norm 5.275573163283e-07
# Solved timestep 3, load: 0.3333333333333333
# Elastic Energy 0.0296, Surface energy: 6.56e-07
#
#
#
# Solving timestep 4, load: 0.4444444444444444
#   0 SNES Function norm 9.705961951275e-01
#   1 SNES Function norm 3.882384780510e-01
#   2 SNES Function norm 2.024551175526e-15
#   0 SNES Function norm 1.916562146301e-04
#   1 SNES Function norm 1.161735444556e-04
#   2 SNES Function norm 4.356312942889e-05
#   3 SNES Function norm 2.631446006468e-06
#   0 SNES Function norm 1.517830777640e-04
#   1 SNES Function norm 1.833064238737e-15
#   0 SNES Function norm 5.139930773510e-06
# Solved timestep 4, load: 0.4444444444444444
# Elastic Energy 0.0526, Surface energy: 8.51e-06
#
#
#
# Solving timestep 5, load: 0.5555555555555556
#   0 SNES Function norm 9.705961951275e-01
#   1 SNES Function norm 1.941192390255e-01
#   2 SNES Function norm 2.314253118114e-15
#   0 SNES Function norm 3.078543770049e-04
#   0 SNES Function norm 2.456475247132e-04
#   1 SNES Function norm 2.292925028364e-15
#   0 SNES Function norm 6.935774980924e-03
#   1 SNES Function norm 1.927155197655e-04
#   2 SNES Function norm 6.044977333970e-05
#   3 SNES Function norm 3.715155088463e-19
#   0 SNES Function norm 6.010922798117e-04
#   1 SNES Function norm 2.262024358560e-15
#   0 SNES Function norm 2.735805635642e-05
#   1 SNES Function norm 7.297392643392e-06
#   0 SNES Function norm 4.063555986084e-05
#   1 SNES Function norm 2.228988102093e-15
#   0 SNES Function norm 7.518349526424e-06
# Solved timestep 5, load: 0.5555555555555556
# Elastic Energy 0.0822, Surface energy: 6.28e-05
#
#
#
# Solving timestep 6, load: 0.6666666666666666
#   0 SNES Function norm 9.705961951275e-01
#   1 SNES Function norm 3.713524386313e-15
#   0 SNES Function norm 4.442536333059e-04
#   0 SNES Function norm 7.920846955970e-04
#   1 SNES Function norm 2.944627480562e-15
#   0 SNES Function norm 5.942466642823e-03
#   1 SNES Function norm 3.903655567897e-04
#   2 SNES Function norm 1.921978796238e-04
#   3 SNES Function norm 2.144975010082e-05
#   4 SNES Function norm 4.276898752076e-07
#   0 SNES Function norm 1.450300343872e-03
#   1 SNES Function norm 2.984331743954e-15
#   0 SNES Function norm 1.018343916508e-04
#   1 SNES Function norm 5.069217354974e-05
#   2 SNES Function norm 1.145910590814e-18
#   0 SNES Function norm 2.212803684407e-04
#   1 SNES Function norm 2.984605451714e-15
#   0 SNES Function norm 1.676615480125e-05
#   1 SNES Function norm 1.307086524149e-18
#   0 SNES Function norm 3.839009693987e-05
#   1 SNES Function norm 2.822817185455e-15
#   0 SNES Function norm 2.930164223085e-06
# Solved timestep 6, load: 0.6666666666666666
# Elastic Energy 0.118, Surface energy: 0.000348
#
#
#
# Solving timestep 7, load: 0.7777777777777777
#   0 SNES Function norm 9.705961951275e-01
#   1 SNES Function norm 3.962231513201e-15
#   0 SNES Function norm 6.480883890720e-04
#   0 SNES Function norm 2.126572864294e-03
#   1 SNES Function norm 3.514064267038e-15
#   0 SNES Function norm 4.833463323364e-03
#   1 SNES Function norm 6.143682959270e-04
#   2 SNES Function norm 2.291658965469e-04
#   3 SNES Function norm 2.412732754574e-05
#   4 SNES Function norm 2.226495424714e-18
#   0 SNES Function norm 2.990923632109e-03
#   1 SNES Function norm 3.365759686627e-15
#   0 SNES Function norm 3.147625399945e-04
#   1 SNES Function norm 2.076210041002e-04
#   2 SNES Function norm 3.383192393282e-05
#   3 SNES Function norm 2.954816374652e-18
#   0 SNES Function norm 9.252064763548e-04
#   1 SNES Function norm 3.442616284009e-15
#   0 SNES Function norm 1.078867959180e-04
#   1 SNES Function norm 4.766470553731e-05
#   2 SNES Function norm 8.979092599522e-07
#   0 SNES Function norm 3.401398557295e-04
#   1 SNES Function norm 3.440181236780e-15
#   0 SNES Function norm 4.077555379747e-05
#   1 SNES Function norm 1.400812733158e-05
#   2 SNES Function norm 4.831690528053e-07
#   0 SNES Function norm 1.316704568144e-04
#   1 SNES Function norm 3.410981928159e-15
#   0 SNES Function norm 1.596951674036e-05
#   1 SNES Function norm 2.001055140417e-06
#   0 SNES Function norm 5.190989864753e-05
#   1 SNES Function norm 3.468349495347e-15
#   0 SNES Function norm 6.598310455555e-06
# Solved timestep 7, load: 0.7777777777777777
# Elastic Energy 0.159, Surface energy: 0.00191
#
#
#
# Solving timestep 8, load: 0.8888888888888888
#   0 SNES Function norm 9.705961951275e-01
#   1 SNES Function norm 4.131423526605e-15
#   0 SNES Function norm 1.003955335270e-03
#   0 SNES Function norm 5.805603390350e-03
#   1 SNES Function norm 3.611716044742e-15
#   0 SNES Function norm 3.740566899446e-03
#   1 SNES Function norm 1.031646231818e-03
#   2 SNES Function norm 4.752287049387e-04
#   3 SNES Function norm 1.683108891571e-04
#   4 SNES Function norm 5.073088543079e-05
#   5 SNES Function norm 1.369004862927e-05
#   6 SNES Function norm 5.384566079372e-18
#   0 SNES Function norm 5.478249523921e-03
#   1 SNES Function norm 3.520513792200e-15
#   0 SNES Function norm 8.720080243535e-04
#   1 SNES Function norm 6.054972163895e-04
#   2 SNES Function norm 2.283724566648e-04
#   3 SNES Function norm 6.463457572984e-05
#   4 SNES Function norm 1.271494169913e-05
#   5 SNES Function norm 8.163256634102e-18
#   0 SNES Function norm 3.151400625124e-03
#   1 SNES Function norm 3.375024793579e-15
#   0 SNES Function norm 5.945611748991e-04
#   1 SNES Function norm 5.350343444168e-04
#   2 SNES Function norm 1.837100223958e-04
#   3 SNES Function norm 3.885056472072e-05
#   4 SNES Function norm 1.017479456386e-17
#   0 SNES Function norm 2.625416248335e-03
#   1 SNES Function norm 3.478695661728e-15
#   0 SNES Function norm 5.511475660451e-04
#   1 SNES Function norm 2.796166471014e-04
#   2 SNES Function norm 5.441711365002e-05
#   3 SNES Function norm 1.285512386033e-17
#   0 SNES Function norm 2.624848156113e-03
#   1 SNES Function norm 3.430311800928e-15
#   0 SNES Function norm 5.991901939106e-04
#   1 SNES Function norm 2.906793139597e-04
#   2 SNES Function norm 3.735951369373e-05
#   3 SNES Function norm 1.574867795038e-17
#   0 SNES Function norm 2.852942573224e-03
#   1 SNES Function norm 3.360032586027e-15
#   0 SNES Function norm 7.079778965322e-04
#   1 SNES Function norm 2.877711979134e-04
#   2 SNES Function norm 1.931960157659e-05
#   3 SNES Function norm 1.835461216428e-17
#   0 SNES Function norm 3.280489908567e-03
#   1 SNES Function norm 3.284045594189e-15
#   0 SNES Function norm 8.918638375237e-04
#   1 SNES Function norm 2.815298217167e-04
#   2 SNES Function norm 5.751867963443e-07
#   0 SNES Function norm 3.948003886068e-03
#   1 SNES Function norm 3.282467195508e-15
#   0 SNES Function norm 1.193440931248e-03
#   1 SNES Function norm 3.504853731859e-04
#   2 SNES Function norm 2.932331127553e-05
#   3 SNES Function norm 2.598764366657e-17
#   0 SNES Function norm 4.937289954551e-03
#   1 SNES Function norm 3.313247318134e-15
#   0 SNES Function norm 1.702335734826e-03
#   1 SNES Function norm 2.699444163700e-04
#   2 SNES Function norm 2.649397995702e-05
#   3 SNES Function norm 3.150657149206e-17
#   0 SNES Function norm 6.356454331313e-03
#   1 SNES Function norm 3.233062718290e-15
#   0 SNES Function norm 2.603438241540e-03
#   1 SNES Function norm 4.495418454456e-04
#   2 SNES Function norm 5.771553944837e-05
#   3 SNES Function norm 1.169075351141e-06
#   0 SNES Function norm 8.270433275900e-03
#   1 SNES Function norm 3.055103147552e-15
#   0 SNES Function norm 4.292991147439e-03
#   1 SNES Function norm 3.396082407846e-04
#   2 SNES Function norm 6.625754724512e-06
#   0 SNES Function norm 1.049026556561e-02
#   1 SNES Function norm 3.173711534249e-15
#   0 SNES Function norm 7.588112909400e-03
#   1 SNES Function norm 2.369583229472e-04
#   2 SNES Function norm 1.009636554200e-06
#   0 SNES Function norm 1.213348951217e-02
#   1 SNES Function norm 3.084322825598e-15
#   0 SNES Function norm 1.374730924396e-02
#   1 SNES Function norm 3.879374001291e-04
#   2 SNES Function norm 7.647293835826e-05
#   3 SNES Function norm 5.459394017894e-17
#   0 SNES Function norm 1.175485002666e-02
#   1 SNES Function norm 3.271317788282e-15
#   0 SNES Function norm 2.184540158049e-02
#   1 SNES Function norm 7.140744205053e-04
#   2 SNES Function norm 2.759545544832e-04
#   3 SNES Function norm 5.636682522917e-17
#   0 SNES Function norm 8.877496765880e-03
#   1 SNES Function norm 3.063019440213e-15
#   0 SNES Function norm 2.432253903506e-02
#   1 SNES Function norm 2.756000450602e-04
#   2 SNES Function norm 4.510973136776e-05
#   3 SNES Function norm 4.325731474652e-06
#   0 SNES Function norm 4.769001699972e-03
#   1 SNES Function norm 2.997756585346e-15
#   0 SNES Function norm 1.529573698898e-02
#   1 SNES Function norm 4.158733289910e-04
#   2 SNES Function norm 4.188348309277e-06
#   0 SNES Function norm 1.404483155761e-03
#   1 SNES Function norm 3.022160456914e-15
#   0 SNES Function norm 5.269629437728e-03
#   1 SNES Function norm 1.009829950387e-04
#   2 SNES Function norm 1.235437026737e-16
#   0 SNES Function norm 4.118120494728e-04
#   1 SNES Function norm 3.159341144981e-15
#   0 SNES Function norm 1.972996133956e-03
#   1 SNES Function norm 1.316512015921e-16
#   0 SNES Function norm 2.761303769163e-04
#   1 SNES Function norm 3.038496997742e-15
#   0 SNES Function norm 2.026081455055e-03
#   1 SNES Function norm 7.744829071245e-07
#   0 SNES Function norm 3.672959025743e-04
#   1 SNES Function norm 3.061900951409e-15
#   0 SNES Function norm 2.672031634078e-03
#   1 SNES Function norm 4.049657731605e-06
#   0 SNES Function norm 4.475953186655e-04
#   1 SNES Function norm 3.003334824689e-15
#   0 SNES Function norm 3.160004034931e-03
#   1 SNES Function norm 1.338312514830e-05
#   2 SNES Function norm 1.607138014732e-16
#   0 SNES Function norm 4.858503590617e-04
#   1 SNES Function norm 3.084966854514e-15
#   0 SNES Function norm 4.139836533080e-03
#   1 SNES Function norm 8.421464145337e-04
#   2 SNES Function norm 1.209795702340e-16
#   0 SNES Function norm 7.458172803624e-04
#   1 SNES Function norm 2.965102959142e-15
#   0 SNES Function norm 4.563734197943e-03
#   1 SNES Function norm 1.621638268234e-04
#   2 SNES Function norm 1.318467040385e-16
#   0 SNES Function norm 5.479278536793e-04
#   1 SNES Function norm 3.060656791281e-15
#   0 SNES Function norm 1.492828627054e-03
#   1 SNES Function norm 1.367358185389e-16
#   0 SNES Function norm 6.856895223424e-05
#   1 SNES Function norm 3.003749155439e-15
#   0 SNES Function norm 1.856871723805e-04
#   1 SNES Function norm 1.586333076895e-16
#   0 SNES Function norm 7.016604936856e-06
#   1 SNES Function norm 2.989112575297e-15
#   0 SNES Function norm 1.978946290195e-05
#   1 SNES Function norm 1.312033570953e-16
# Solved timestep 8, load: 0.8888888888888888
# Elastic Energy 0.00123, Surface energy: 0.131
#
#
#
# Solving timestep 9, load: 1.0
#   0 SNES Function norm 9.705961951278e-01
#   1 SNES Function norm 3.677335194806e-15
#   0 SNES Function norm 6.400748085958e-03
#   1 SNES Function norm 9.895595589346e-05
#   2 SNES Function norm 1.619479152610e-16
#   0 SNES Function norm 2.175846213571e-04
#   1 SNES Function norm 3.063301433123e-15
#   0 SNES Function norm 7.832304334975e-04
#   1 SNES Function norm 1.600652040779e-16
#   0 SNES Function norm 3.368831569323e-05
#   1 SNES Function norm 3.125467457518e-15
#   0 SNES Function norm 1.374042932404e-04
#   1 SNES Function norm 2.032476101944e-16
#   0 SNES Function norm 8.059386243858e-06
#   1 SNES Function norm 3.071893865671e-15
#   0 SNES Function norm 3.190365353901e-05
#   1 SNES Function norm 1.499691818772e-16
#   0 SNES Function norm 2.612175767974e-06
#   1 SNES Function norm 3.077478266332e-15
#   0 SNES Function norm 9.506095784777e-06
# Solved timestep 9, load: 1.0
# Elastic Energy 0.000998, Surface energy: 0.132
#
#
#
# CPU times: user 1min 44s, sys: 1min 16s, total: 3min
# Wall time: 2min 52s

# %%
plt.figure()
plt.plot(data.get('load'), data.get('surface'), label='surface')
plt.plot(data.get('load'), data.get('elastic'), label='elastic')
# plt.plot(data.get('load'), [1./2. * t**2*Lx for t in data.get('load')], label='anal elast', ls=':', c='k')

plt.title('Kinking in plate under traction energetics')
plt.legend()
# plt.yticks([0, 1/20], [0, '$1/2.\sigma_c^2/E_0$'])
plt.xticks([parameters.get('loading').get("min"), parameters.get('loading').get("max")], [0, parameters.get('loading').get("max")])
plt.savefig("energetics.png")

# # savings?
# plt.figure()
# plt.plot(data.get('load'), data.get('surface'), label='surface')
# plt.plot(data.get('load'), data.get('elastic'), label='elastic')

# plt.title('Last steps')
# plt.legend()
# plt.yticks([0, 1/20], [0, '$1/2.\sigma_c^2/E_0$'])
# plt.xticks([0, 1], [0, 1])
# plt.savefig("lastSteps.png")


#plotter = pyvista.Plotter(
       #  title="Displacement",
        # window_size=[1600, 600],
        # shape=(1, 2), )
#_plt = plot_scalar(u_.sub(0), plotter, subplot=(0, 0))
#_plt = plot_vector(u, plotter, subplot=(0, 1))
#_plt.screenshot(f"displacement_MPI.png")


 #xvfb.start_xvfb(wait=0.05)
 #pyvista.OFF_SCREEN = True

#plotter = pyvista.Plotter(
        # title="Displacement",
      # window_size=[1600, 600],
      #  shape=(1, 2),
   #  )
#
# _plt = plot_scalar(alpha, plotter, subplot=(0, 0))
#_plt.screenshot(f"alpha2.png")
