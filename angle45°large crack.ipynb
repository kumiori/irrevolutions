# %% [markdown]
# <a href="https://colab.research.google.com/github/kumiori/mec647/blob/Assala_T/angle45%C2%B0large%20crack.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
import sys

try:
    import google.colab  # noqa: F401
except ImportError:
    import ufl  # noqa: F401
    import dolfinx  # noqa: F401
else:
    try:
        import ufl
        import dolfinx
    except ImportError:
        # !wget "https://fem-on-colab.github.io/releases/fenicsx-install.sh" -O "/tmp/fenicsx-install.sh" && bash "/tmp/fenicsx-install.sh";
        import ufl  # noqa: F401
        import dolfinx  # noqa: F401

try:
    import pyvista
except ImportError:
    # !{sys.executable} -m pip install --upgrade pyvista itkwidgets;
    import pyvista  # noqa: F401
    from pyvista.utilities import xvfb

try:
    import gmsh
except ImportError:
    # !{sys.executable} -m pip install gmsh
    import gmsh

# !sudo apt install libgl1-mesa-glx xvfb;
# !{sys.executable} -m pip install pythreejs;
# !{sys.executable} -m pip install ipygany;
# !{sys.executable} -m pip install --upgrade PyYAML
# !pip install --ignore-installed PyYAML

# %%
branch_name = 'main'
# branch_name = 'Assala_T'

# !rm -rf mec647
try:
  # !git clone -b {branch_name} https://github.com/kumiori/mec647.git
  sys.path.append('mec647/')

  print()
  print(f'Cloned brach: {branch_name}')
  print(f'Last commit message')
  # !cd mec647/ && git log -n 1 && cd ..
  import mec647
  from mec647 import meshes
  from mec647.meshes import primitives
  # from mec647.algorithms import am
  from mec647.utils.viz import plot_mesh, plot_scalar, plot_vector

except Exception as e:
  print('Something went wrong', e)
  # !rm -rf mec647
  # !git clone https://github.com/kumiori/mec647.git
# Out:
# Cloning into 'mec647'...
# remote: Enumerating objects: 1258, done.
# remote: Counting objects: 100% (1258/1258), done.
# remote: Compressing objects: 100% (932/932), done.
# remote: Total 1258 (delta 642), reused 628 (delta 285), pack-reused 0
# Receiving objects: 100% (1258/1258), 19.70 MiB | 7.56 MiB/s, done.
# Resolving deltas: 100% (642/642), done.
#
# Cloned brach: main
# Last commit message
# commit 25aa48ad32b5c11d7dd6e087bdf09fea88442b28 (HEAD -> main, origin/main, origin/HEAD)
# Merge: 822d5b0 222efb0
# Author: igorassist <igorassist98@gmail.com>
# Date:   Sat Feb 26 14:14:34 2022 +0100
#
#     Merge branch 'main' of https://github.com/kumiori/mec647

# %%
import matplotlib.pyplot as plt
from petsc4py import PETSc
import numpy as np
from mpi4py import MPI

comm = MPI.COMM_WORLD

from dolfinx.fem import (
    Constant,
    Function,
    FunctionSpace,
    assemble_scalar,
    dirichletbc,
    form,
    locate_dofs_geometrical,
    set_bc,
)

# meshes
import meshes
from meshes import primitives

import models
from models import DamageElasticityModel as Brittle

# %%
import numpy as np
import yaml
import json
import sys
import os
from pathlib import Path

from mpi4py import MPI

import petsc4py
from petsc4py import PETSc

import dolfinx
import dolfinx.plot
from dolfinx import log
import ufl

import algorithms
from algorithms import am

from dolfinx.io import XDMFFile

import logging

logging.basicConfig(level=logging.INFO)

import dolfinx
import dolfinx.plot
import dolfinx.io
from dolfinx.fem import (
    Constant,
    Function,
    FunctionSpace,
    assemble_scalar,
    dirichletbc,
    form,
    locate_dofs_geometrical,
    set_bc,
)
import matplotlib.pyplot as plt
import pyvista 
from pyvista.utilities import xvfb


# visualisation
from utils import viz
import matplotlib.pyplot as plt
from utils.viz import plot_mesh, plot_vector, plot_scalar
generateStepwiseOutput=True

# %%
# Parameters
parameters = {
    'loading': {
        'min': 0.0,
        'max': 1.,
        'steps': 10
    },
    'geometry': {
        'geom_type': 'Plate with Kink',
        'Lx': .6,
        'Ly': 1, 
        'L0': 0.5,
        'theta': 45,
        'eta': 0.03,
    },
    'model': {
        'E': 3.e+9,
        'nu': 0.4,
        'w1': 1.,
        'ell': 0.1, 
        'k_res': 1.e-8
    },
    'solvers': {
          'elasticity': {        
            'snes': {
                'snes_type': 'newtontr',
                'snes_stol': 1e-8,
                'snes_atol': 1e-8,
                'snes_rtol': 1e-8,
                'snes_max_it': 250,
                'snes_monitor': "",
                'ksp_type': 'preonly',
                'pc_type': 'lu',
                'pc_factor_mat_solver_type': 'mumps'
            }
        },
          'damage': {        
            'snes': {
                'snes_type': 'vinewtonrsls',
                'snes_stol': 1e-5,
                'snes_atol': 1e-5,
                'snes_rtol': 1e-8,
                'snes_max_it': 100,
                'snes_monitor': "",
                'ksp_type': 'preonly',
                'pc_type': 'lu',
                'pc_factor_mat_solver_type': 'mumps'
            },
        },
          'damage_elasticity': {
            "max_it": 2000,
            "alpha_rtol": 1.0e-4,
            "criterion": "alpha_H1"
          }
    }
}

# %%
def  mesh_kink(name,
                Lx,
                Ly,
                # a,
                # b,
               rad,
               theta,
              # theta
                eta,
                lc,
                tdim,
                order=1,
                msh_file=None,
                comm=MPI.COMM_WORLD):
    """
    Create mesh of 3d tensile test specimen according to ISO 6892-1:2019 using the Python API of Gmsh.
    """
    # Perform Gmsh work only on rank = 0

    if comm.rank == 0:

        import gmsh

        # Initialise gmsh and set options
        gmsh.initialize()
        gmsh.option.setNumber("General.Terminal", 1)

        gmsh.option.setNumber("Mesh.Algorithm", 6)
        model = gmsh.model()
        model.add("Rectangle")
        model.setCurrent("Rectangle")
        # points = [p1, p2, p3, p4, p5, p6, p7, p8,p9,p10,p11]
        p1 = model.geo.addPoint(0.0, 0.0, 0, lc, tag=1)
        p2 = model.geo.addPoint(Lx, 0.0, 0, lc, tag=2)
        p3 = model.geo.addPoint(Lx, Ly, 0.0, lc, tag=3)
        p4 = model.geo.addPoint(0, Ly, 0, lc, tag=4)

        p5 = model.geo.addPoint(Lx/2 + rad*np.cos(theta), Ly/2 + rad*np.sin(theta), 0.0, lc/3, tag=5)
        p7 = model.geo.addPoint(Lx/2 - rad*np.cos(theta), Ly/2 - rad*np.sin(theta), 0.0, lc/3, tag=7)

        # p5 = model.geo.addPoint(Lx/2 +a, Ly/2 +b,0.0, lc/1.5, tag=5)
        p6 = model.geo.addPoint(Lx/2, Ly/2 + eta,0, lc, tag=6)
        # p7 = model.geo.addPoint(Lx/2-a,Ly/2-b,0,lc/1.5, tag=7)
        p8 = model.geo.addPoint(Lx/2,Ly/2 - eta,0, lc, tag=8)

        # Lines = [L1, L2, L3, L4, L5, L6, L7, L8]
        L1 = model.geo.addLine(p1, p2, tag=1)
        L2 = model.geo.addLine(p2, p3, tag=2)
        L3 = model.geo.addLine(p3, p4, tag=3)
        L4 = model.geo.addLine(p4, p1, tag=4)
        L5 = model.geo.addLine(p5, p6, tag=5)
        L6 = model.geo.addLine(p6, p7, tag=6)
        L7 = model.geo.addLine(p7, p8, tag=7)
        L8 = model.geo.addLine(p8, p5, tag=8)


        
        cloop1 = model.geo.addCurveLoop([L1, L2, L3, L4])
        cloop2 = model.geo.addCurveLoop([L5, L6, L7, L8])
        
        # surface_1 =
        model.geo.addPlaneSurface([cloop1, cloop2])

        model.geo.synchronize()
        surface_entities = [model[1] for model in model.getEntities(tdim)]

        model.addPhysicalGroup(tdim, surface_entities, tag=1)
        model.setPhysicalName(tdim, 1, "Rectangle surface")

        # Set mesh size via points
        # gmsh.model.mesh.setSize(points, lc)  # heuristic

        # gmsh.model.mesh.optimize("Netgen")

        # Set geometric order of mesh cells
        gmsh.model.mesh.setOrder(order)

        # Define physical groups for subdomains (! target tag > 0)
        # domain = 1
        # gmsh.model.addPhysicalGroup(tdim, [v[1] for v in volumes], domain)
        # gmsh.model.setPhysicalName(tdim, domain, 'domain')
              

        gmsh.model.addPhysicalGroup(tdim - 1, [1], tag=9)
        gmsh.model.setPhysicalName(tdim - 1, 9, "Bottom  of the Plate")
        gmsh.model.addPhysicalGroup(tdim - 1, [4], tag=10)
        gmsh.model.setPhysicalName(tdim - 1, 10, "Top  of the Plate")
        gmsh.model.addPhysicalGroup(tdim - 1, [5], tag=11)
        gmsh.model.setPhysicalName(tdim - 1, 11, "1/2 Top of the TipCrack")
        gmsh.model.addPhysicalGroup(tdim - 1, [6], tag=12)
        gmsh.model.setPhysicalName(tdim - 1, 12, "1/2 Top of the TipCrack")
        gmsh.model.addPhysicalGroup(tdim - 1, [7], tag=13)
        gmsh.model.setPhysicalName(tdim - 1, 13, "1/2 bottom of the TipCrack")
        gmsh.model.addPhysicalGroup(tdim - 1, [8], tag=14)
        gmsh.model.setPhysicalName(tdim - 1, 14, "1/2 bottom of the TipCrack")

        model.mesh.generate(tdim)


        #Generating the mesh
    model.geo.synchronize()
    model.mesh.generate(tdim)

    return gmsh.model

# %%
Lx = parameters.get("geometry").get("Lx")
Ly = parameters.get("geometry").get("Ly")
L0 = parameters.get("geometry").get("L0")
eta = parameters.get("geometry").get("eta")

geom_type = parameters.get("geometry").get("geom_type")

lc=0.02
theta = 45/180 * np.pi

gmsh_model=mesh_kink('mesh', Lx, Ly, L0/2, theta, eta,lc, 2, 1)

mesh, mts = meshes.gmsh_model_to_mesh(gmsh_model,
                               cell_data=False,
                               facet_data=True,
                               gdim=2)


plt.figure()
ax = plot_mesh(mesh)
fig = ax.get_figure()
fig.savefig(f"mesh.png")

# %%
# usedMesh=mesh 
# Enables opportunity to improve mesh at specific places, might lead to deformed elements
# Functional Setting

element_u = ufl.VectorElement("Lagrange", mesh.ufl_cell(),
                              degree=1, dim=2)

element_alpha = ufl.FiniteElement("Lagrange", mesh.ufl_cell(),
                              degree=1)

V_u = dolfinx.fem.FunctionSpace(mesh, element_u) 
V_alpha = dolfinx.fem.FunctionSpace(mesh, element_alpha) 

u = dolfinx.fem.Function(V_u, name="Displacement")
u_ = dolfinx.fem.Function(V_u, name="BoundaryDisplacement")


alpha = dolfinx.fem.Function(V_alpha, name="Damage")

# Pack state
state = {"u": u, "alpha": alpha}

# Bounds
alpha_ub = dolfinx.fem.Function(V_alpha, name="UpperBoundDamage")
alpha_lb = dolfinx.fem.Function(V_alpha, name="LowerBoundDamage")



dx = ufl.Measure("dx", domain = mesh)
ds = ufl.Measure("ds", domain = mesh)


# Boundary sets
dofs_alpha_left = locate_dofs_geometrical(V_alpha, lambda x: np.isclose(x[0], 0.))
dofs_alpha_right = locate_dofs_geometrical(V_alpha, lambda x: np.isclose(x[0], Lx))
dofs_alpha_bottom = locate_dofs_geometrical(V_alpha, lambda x: np.isclose(x[1], 0.))
dofs_alpha_top = locate_dofs_geometrical(V_alpha, lambda x: np.isclose(x[1], Ly))


dofs_u_left = locate_dofs_geometrical(V_u, lambda x: np.isclose(x[0], 0.))
dofs_u_right = locate_dofs_geometrical(V_u, lambda x: np.isclose(x[0], Lx))
dofs_u_top = locate_dofs_geometrical(V_u, lambda x: np.isclose(x[1], Ly))
dofs_u_bottom = locate_dofs_geometrical(V_u, lambda x: np.isclose(x[1], 0))

# Boundary data
u_.interpolate(lambda x: (np.zeros_like(x[0]), np.ones_like(x[1])))

# Bounds (nontrivial)
alpha_lb.interpolate(lambda x: np.zeros_like(x[0]))
alpha_ub.interpolate(lambda x: np.ones_like(x[0]))

# Boundary conditions
bcs_u = [
         dirichletbc(np.array([0., 0.], dtype=PETSc.ScalarType),
                      dofs_u_bottom,
                      V_u),
         dirichletbc(u_, dofs_u_top)
         ]

bcs_alpha = [
             dirichletbc(np.array(0., dtype = PETSc.ScalarType),
                         np.concatenate([dofs_alpha_bottom, dofs_alpha_top]),
                         V_alpha)
]

bcs = {"bcs_u": bcs_u, "bcs_alpha": bcs_alpha}

model = Brittle(parameters["model"])

total_energy = model.total_energy_density(state) * dx
solver = am.AlternateMinimisation(total_energy,
                         state,
                         bcs,
                         parameters.get("solvers"),
                         bounds=(alpha_lb, alpha_ub)
                         )

# %%
# %%time
# Loop for evolution
loads = np.linspace(parameters.get("loading").get("min"),
                    parameters.get("loading").get("max"),
                    parameters.get("loading").get("steps"))

data = {
    'elastic': [],
    'surface': [],
    'total': [],
    'load': []
}
xvfb.start_xvfb(wait=0.05)
pyvista.OFF_SCREEN = True
plotter = pyvista.Plotter(
        title="Displacement",
        window_size=[1600, 600],
        shape=(1, 2),
    )

for (i_t, t) in enumerate(loads):
  # update boundary conditions

  u_.interpolate(lambda x: ( np.zeros_like(x[0]), t*np.ones_like(x[1])))
  u_.vector.ghostUpdate(addv=PETSc.InsertMode.INSERT,
                        mode=PETSc.ScatterMode.FORWARD)

  # update lower bound for damage
  alpha.vector.copy(alpha_lb.vector)
  alpha.vector.ghostUpdate(addv=PETSc.InsertMode.INSERT,
                        mode=PETSc.ScatterMode.FORWARD)

  # solve for current load step
  print(f"Solving timestep {i_t}, load: {t}")

  solver.solve()

  # postprocessing
  # global

  surface_energy = assemble_scalar(dolfinx.fem.form(model.damage_dissipation_density(state) * dx))

  elastic_energy = assemble_scalar(
        dolfinx.fem.form(model.elastic_energy_density(state) * dx))
  
  data.get('elastic').append(elastic_energy)
  data.get('surface').append(surface_energy)
  data.get('total').append(surface_energy+elastic_energy)
  data.get('load').append(t)

  print(f"Solved timestep {i_t}, load: {t}")
  print(f"Elastic Energy {elastic_energy:.3g}, Surface energy: {surface_energy:.3g}")
  print("\n\n")

  _plt = plot_scalar(alpha, plotter, subplot=(0, 0))
  _plt.screenshot(f"large_ell.png")
  if generateStepwiseOutput:
    if(surface_energy>1 and i_t%25==0):
    #if(i_t>1050 and i_t<1100):
        _plt = plot_scalar(alpha, plotter, subplot=(0, 0))
        #_plt.screenshot(f"./plots/s30/alpha"+str(i_t)+".png")
        _plt.screenshot(f"large_ell.png")
    #if i_t>1100:
    #    break
  if(i_t>20 and  elastic_energy<1E-3 and elastic_energy<surface_energy):
      #Brute force approach to determine, whether we have already reached a crack propagation state
      print("fail")
      break

  # savings?
# Out:
# Solving timestep 0, load: 0.0
#   0 SNES Function norm 0.000000000000e+00
#   0 SNES Function norm 0.000000000000e+00
# Solved timestep 0, load: 0.0
# Elastic Energy 0, Surface energy: 0
#
#
#
# Solving timestep 1, load: 0.1111111111111111
#   0 SNES Function norm 9.546301844294e-01
#   1 SNES Function norm 9.003219586602e-01
#   2 SNES Function norm 7.917055071217e-01
#   3 SNES Function norm 5.744726040447e-01
#   4 SNES Function norm 1.400067978908e-01
#   5 SNES Function norm 5.170362662756e-16
#   0 SNES Function norm 0.000000000000e+00
# Solved timestep 1, load: 0.1111111111111111
# Elastic Energy 0.0026, Surface energy: 0
#
#
#
# Solving timestep 2, load: 0.2222222222222222
#   0 SNES Function norm 9.546301844294e-01
#   1 SNES Function norm 7.637041475435e-01
#   2 SNES Function norm 3.818520737718e-01
#   3 SNES Function norm 1.147245016824e-15
#   0 SNES Function norm 3.153364917693e-05
#   1 SNES Function norm 6.998441535448e-21
#   0 SNES Function norm 7.553355985778e-06
#   1 SNES Function norm 8.725979275501e-16
#   0 SNES Function norm 6.689382404312e-08
# Solved timestep 2, load: 0.2222222222222222
# Elastic Energy 0.0104, Surface energy: 8.11e-08
#
#
#
# Solving timestep 3, load: 0.3333333333333333
#   0 SNES Function norm 9.546301844294e-01
#   1 SNES Function norm 5.727781106576e-01
#   2 SNES Function norm 1.956700169256e-15
#   0 SNES Function norm 1.568041943294e-04
#   1 SNES Function norm 1.027845674263e-04
#   2 SNES Function norm 8.175493262209e-06
#   0 SNES Function norm 1.005738604026e-04
#   1 SNES Function norm 1.544707301786e-15
#   0 SNES Function norm 8.359384572852e-06
# Solved timestep 3, load: 0.3333333333333333
# Elastic Energy 0.0234, Surface energy: 3.27e-06
#
#
#
# Solving timestep 4, load: 0.4444444444444444
#   0 SNES Function norm 9.546301844294e-01
#   1 SNES Function norm 3.818520737718e-01
#   2 SNES Function norm 1.937862086626e-15
#   0 SNES Function norm 3.127621245074e-04
#   1 SNES Function norm 2.969400099581e-04
#   2 SNES Function norm 1.318593487965e-04
#   3 SNES Function norm 2.970406818263e-05
#   4 SNES Function norm 3.537901090455e-07
#   0 SNES Function norm 3.675708380956e-04
#   1 SNES Function norm 1.697684129062e-15
#   0 SNES Function norm 1.552452646878e-05
#   1 SNES Function norm 3.926957104388e-06
#   0 SNES Function norm 2.181725770081e-05
#   1 SNES Function norm 1.750359819987e-15
#   0 SNES Function norm 4.006246055737e-06
# Solved timestep 4, load: 0.4444444444444444
# Elastic Energy 0.0416, Surface energy: 4.16e-05
#
#
#
# Solving timestep 5, load: 0.5555555555555556
#   0 SNES Function norm 9.546301844294e-01
#   1 SNES Function norm 1.909260368859e-01
#   2 SNES Function norm 2.349044914114e-15
#   0 SNES Function norm 4.849204300520e-04
#   0 SNES Function norm 6.510751079541e-04
#   1 SNES Function norm 2.267063552360e-15
#   0 SNES Function norm 7.820997063623e-03
#   1 SNES Function norm 5.249667636288e-04
#   2 SNES Function norm 2.541612101112e-04
#   3 SNES Function norm 3.981005448230e-05
#   4 SNES Function norm 8.033951224045e-19
#   0 SNES Function norm 1.369177585320e-03
#   1 SNES Function norm 2.374638013510e-15
#   0 SNES Function norm 9.096424995044e-05
#   1 SNES Function norm 3.523938314832e-05
#   2 SNES Function norm 9.236811275546e-19
#   0 SNES Function norm 1.899739847895e-04
#   1 SNES Function norm 2.298957997637e-15
#   0 SNES Function norm 1.328159245554e-05
#   1 SNES Function norm 9.980856935408e-19
#   0 SNES Function norm 2.872894777347e-05
#   1 SNES Function norm 2.265692731481e-15
#   0 SNES Function norm 2.018699196269e-06
# Solved timestep 5, load: 0.5555555555555556
# Elastic Energy 0.0647, Surface energy: 0.000292
#
#
#
# Solving timestep 6, load: 0.6666666666666666
#   0 SNES Function norm 9.546301844294e-01
#   1 SNES Function norm 3.568763954048e-15
#   0 SNES Function norm 7.199267029586e-04
#   0 SNES Function norm 2.028051406579e-03
#   1 SNES Function norm 3.133174959524e-15
#   0 SNES Function norm 7.158060370540e-03
#   1 SNES Function norm 6.090940242179e-04
#   2 SNES Function norm 2.867886112012e-04
#   3 SNES Function norm 5.342931212846e-05
#   4 SNES Function norm 8.305444640271e-07
#   0 SNES Function norm 3.051500972568e-03
#   1 SNES Function norm 3.017667103838e-15
#   0 SNES Function norm 3.097582535015e-04
#   1 SNES Function norm 9.632143658338e-05
#   2 SNES Function norm 1.229480688572e-05
#   3 SNES Function norm 2.879352099741e-18
#   0 SNES Function norm 8.671350790609e-04
#   1 SNES Function norm 3.121447781796e-15
#   0 SNES Function norm 9.446235453180e-05
#   1 SNES Function norm 4.580626675533e-05
#   2 SNES Function norm 2.962802382818e-18
#   0 SNES Function norm 2.825325085629e-04
#   1 SNES Function norm 3.054442431378e-15
#   0 SNES Function norm 3.137786865168e-05
#   1 SNES Function norm 8.902741597801e-06
#   0 SNES Function norm 9.554507952091e-05
#   1 SNES Function norm 3.203343608261e-15
#   0 SNES Function norm 1.410242240892e-05
#   1 SNES Function norm 1.503435655860e-06
#   0 SNES Function norm 3.356506922994e-05
#   1 SNES Function norm 3.098783837256e-15
#   0 SNES Function norm 4.042317127783e-06
# Solved timestep 6, load: 0.6666666666666666
# Elastic Energy 0.0916, Surface energy: 0.0016
#
#
#
# Solving timestep 7, load: 0.7777777777777777
#   0 SNES Function norm 9.546301844294e-01
#   1 SNES Function norm 3.783967074741e-15
#   0 SNES Function norm 1.051909616418e-03
#   0 SNES Function norm 5.799466914219e-03
#   1 SNES Function norm 3.339039213930e-15
#   0 SNES Function norm 6.427719252194e-03
#   1 SNES Function norm 7.425799021867e-04
#   2 SNES Function norm 3.304052289193e-04
#   3 SNES Function norm 1.030679339003e-04
#   4 SNES Function norm 4.600803478718e-18
#   0 SNES Function norm 5.651870458562e-03
#   1 SNES Function norm 3.248468257041e-15
#   0 SNES Function norm 8.424465941976e-04
#   1 SNES Function norm 7.179213811481e-04
#   2 SNES Function norm 3.766000206382e-04
#   3 SNES Function norm 1.450803582596e-04
#   4 SNES Function norm 6.013676577737e-05
#   5 SNES Function norm 4.584804363194e-07
#   0 SNES Function norm 3.245076941985e-03
#   1 SNES Function norm 3.326723231909e-15
#   0 SNES Function norm 5.743761784903e-04
#   1 SNES Function norm 3.761904947371e-04
#   2 SNES Function norm 9.312269172259e-05
#   3 SNES Function norm 9.393657001570e-06
#   0 SNES Function norm 2.516333395377e-03
#   1 SNES Function norm 3.265706820241e-15
#   0 SNES Function norm 4.972790658453e-04
#   1 SNES Function norm 2.453942102541e-04
#   2 SNES Function norm 2.280433893566e-05
#   3 SNES Function norm 1.154900336985e-17
#   0 SNES Function norm 2.212767325797e-03
#   1 SNES Function norm 3.244201177031e-15
#   0 SNES Function norm 4.745089674154e-04
#   1 SNES Function norm 2.177579166394e-04
#   2 SNES Function norm 2.944111811583e-05
#   3 SNES Function norm 1.386061991841e-17
#   0 SNES Function norm 2.098312600324e-03
#   1 SNES Function norm 3.211766178468e-15
#   0 SNES Function norm 4.823774390852e-04
#   1 SNES Function norm 1.375667931083e-04
#   2 SNES Function norm 2.450435097899e-07
#   0 SNES Function norm 2.103558248081e-03
#   1 SNES Function norm 3.236586657265e-15
#   0 SNES Function norm 5.151428395299e-04
#   1 SNES Function norm 1.728098822985e-04
#   2 SNES Function norm 1.738756805020e-05
#   3 SNES Function norm 1.789829757713e-17
#   0 SNES Function norm 2.196336693763e-03
#   1 SNES Function norm 3.098686253744e-15
#   0 SNES Function norm 5.748995673980e-04
#   1 SNES Function norm 1.267223913041e-04
#   2 SNES Function norm 1.959141980118e-17
#   0 SNES Function norm 2.384971492866e-03
#   1 SNES Function norm 3.172921730532e-15
#   0 SNES Function norm 6.687525495957e-04
#   1 SNES Function norm 1.087493405059e-04
#   2 SNES Function norm 6.870203270495e-06
#   0 SNES Function norm 2.679431071864e-03
#   1 SNES Function norm 3.070499606488e-15
#   0 SNES Function norm 8.105492394317e-04
#   1 SNES Function norm 1.877028592939e-04
#   2 SNES Function norm 2.091142345820e-06
#   0 SNES Function norm 3.099605449356e-03
#   1 SNES Function norm 3.043461838591e-15
#   0 SNES Function norm 1.026694101933e-03
#   1 SNES Function norm 2.171589012322e-04
#   2 SNES Function norm 2.757383541551e-17
#   0 SNES Function norm 3.687092256062e-03
#   1 SNES Function norm 3.103851294443e-15
#   0 SNES Function norm 1.361934192969e-03
#   1 SNES Function norm 2.336363740525e-04
#   2 SNES Function norm 7.426800899440e-06
#   0 SNES Function norm 4.485181099412e-03
#   1 SNES Function norm 3.068548898249e-15
#   0 SNES Function norm 1.897105360406e-03
#   1 SNES Function norm 1.435510479479e-04
#   2 SNES Function norm 8.410950487731e-06
#   0 SNES Function norm 5.516232579078e-03
#   1 SNES Function norm 3.120680340648e-15
#   0 SNES Function norm 2.781653822254e-03
#   1 SNES Function norm 1.415604379161e-04
#   2 SNES Function norm 8.112019432716e-06
#   0 SNES Function norm 6.734682118086e-03
#   1 SNES Function norm 3.162036949893e-15
#   0 SNES Function norm 4.285856138279e-03
#   1 SNES Function norm 6.135356875943e-06
#   0 SNES Function norm 7.920966721315e-03
#   1 SNES Function norm 3.002306698922e-15
#   0 SNES Function norm 6.832576779707e-03
#   1 SNES Function norm 5.538592896315e-05
#   2 SNES Function norm 4.494786376086e-17
#   0 SNES Function norm 8.598470706437e-03
#   1 SNES Function norm 3.009192455225e-15
#   0 SNES Function norm 1.070136721066e-02
#   1 SNES Function norm 8.994356139660e-05
#   2 SNES Function norm 4.215226202880e-17
#   0 SNES Function norm 8.157610792212e-03
#   1 SNES Function norm 3.074547415227e-15
#   0 SNES Function norm 1.454646835274e-02
#   1 SNES Function norm 1.780676601562e-04
#   2 SNES Function norm 4.670057758824e-17
#   0 SNES Function norm 6.205245944760e-03
#   1 SNES Function norm 3.053779567598e-15
#   0 SNES Function norm 1.382166606671e-02
#   1 SNES Function norm 8.914931314157e-05
#   2 SNES Function norm 3.025788993427e-06
#   0 SNES Function norm 3.192678150084e-03
#   1 SNES Function norm 2.959775798138e-15
#   0 SNES Function norm 8.180314223848e-03
#   1 SNES Function norm 1.844917357562e-05
#   2 SNES Function norm 6.245196870257e-17
#   0 SNES Function norm 1.166872141704e-03
#   1 SNES Function norm 3.134076796405e-15
#   0 SNES Function norm 4.449163683930e-03
#   1 SNES Function norm 3.812429892641e-05
#   2 SNES Function norm 7.263870699870e-17
#   0 SNES Function norm 7.330828192566e-04
#   1 SNES Function norm 2.958654308407e-15
#   0 SNES Function norm 3.037197166294e-03
#   1 SNES Function norm 1.200528963952e-04
#   2 SNES Function norm 6.914053623320e-17
#   0 SNES Function norm 5.586271104799e-04
#   1 SNES Function norm 2.988862375347e-15
#   0 SNES Function norm 2.197573953391e-03
#   1 SNES Function norm 3.406046224251e-05
#   2 SNES Function norm 6.919584782533e-17
#   0 SNES Function norm 3.755259140108e-04
#   1 SNES Function norm 2.882853885092e-15
#   0 SNES Function norm 1.502867094976e-03
#   1 SNES Function norm 1.438777426258e-05
#   2 SNES Function norm 7.218297223632e-17
#   0 SNES Function norm 2.235940594134e-04
#   1 SNES Function norm 3.069582976290e-15
#   0 SNES Function norm 1.079034565013e-03
#   1 SNES Function norm 7.371286827773e-17
#   0 SNES Function norm 1.782331101135e-04
#   1 SNES Function norm 3.019909775955e-15
#   0 SNES Function norm 1.123890132553e-03
#   1 SNES Function norm 8.050316019869e-17
#   0 SNES Function norm 2.211724836152e-04
#   1 SNES Function norm 2.945356043517e-15
#   0 SNES Function norm 1.404153769275e-03
#   1 SNES Function norm 1.561620919615e-04
#   2 SNES Function norm 7.404566432504e-17
#   0 SNES Function norm 2.803565446231e-04
#   1 SNES Function norm 3.058601416710e-15
#   0 SNES Function norm 1.566157111661e-03
#   1 SNES Function norm 8.431519547517e-17
#   0 SNES Function norm 2.828667035363e-04
#   1 SNES Function norm 2.966285705862e-15
#   0 SNES Function norm 1.376373239461e-03
#   1 SNES Function norm 7.820210822409e-17
#   0 SNES Function norm 2.220953655465e-04
#   1 SNES Function norm 3.041280004714e-15
#   0 SNES Function norm 1.100185665348e-03
#   1 SNES Function norm 1.033497969860e-16
#   0 SNES Function norm 1.840457312503e-04
#   1 SNES Function norm 3.047892776387e-15
#   0 SNES Function norm 1.044047844521e-03
#   1 SNES Function norm 8.220006646169e-17
#   0 SNES Function norm 1.930316584011e-04
#   1 SNES Function norm 3.008498000409e-15
#   0 SNES Function norm 1.196784941032e-03
#   1 SNES Function norm 9.763841173690e-17
#   0 SNES Function norm 2.400797120550e-04
#   1 SNES Function norm 3.022780983925e-15
#   0 SNES Function norm 1.534565637681e-03
#   1 SNES Function norm 1.104450167108e-16
#   0 SNES Function norm 3.249645316318e-04
#   1 SNES Function norm 3.009934033036e-15
#   0 SNES Function norm 1.998579192813e-03
#   1 SNES Function norm 9.965066179189e-17
#   0 SNES Function norm 4.148367056854e-04
#   1 SNES Function norm 3.016366299183e-15
#   0 SNES Function norm 2.176006412299e-03
#   1 SNES Function norm 1.934997833340e-04
#   2 SNES Function norm 7.095571474532e-17
#   0 SNES Function norm 3.804972181069e-04
#   1 SNES Function norm 2.967072408407e-15
#   0 SNES Function norm 1.565488657624e-03
#   1 SNES Function norm 2.594420800828e-06
#   0 SNES Function norm 2.035393209037e-04
#   1 SNES Function norm 2.982408525450e-15
#   0 SNES Function norm 7.338299228378e-04
#   1 SNES Function norm 1.022731998724e-16
#   0 SNES Function norm 8.371184940475e-05
#   1 SNES Function norm 3.076188904048e-15
#   0 SNES Function norm 3.156720520018e-04
#   1 SNES Function norm 8.909317113772e-17
#   0 SNES Function norm 3.819492574406e-05
#   1 SNES Function norm 3.177086144471e-15
#   0 SNES Function norm 1.620376707373e-04
#   1 SNES Function norm 9.190030455995e-17
#   0 SNES Function norm 2.070280425455e-05
#   1 SNES Function norm 3.060585246703e-15
#   0 SNES Function norm 9.499874919909e-05
#   1 SNES Function norm 8.546714774768e-17
#   0 SNES Function norm 1.232312040549e-05
#   1 SNES Function norm 2.939144606072e-15
#   0 SNES Function norm 5.856503948818e-05
#   1 SNES Function norm 8.966460845568e-17
#   0 SNES Function norm 7.645714389625e-06
#   1 SNES Function norm 2.920763934271e-15
#   0 SNES Function norm 3.688757789306e-05
#   1 SNES Function norm 7.819944324032e-17
#   0 SNES Function norm 4.842580659347e-06
#   1 SNES Function norm 3.076893732653e-15
#   0 SNES Function norm 2.352475642021e-05
#   1 SNES Function norm 7.840496315527e-17
#   0 SNES Function norm 3.103137679016e-06
#   1 SNES Function norm 3.041754761269e-15
#   0 SNES Function norm 1.512579872140e-05
#   1 SNES Function norm 8.247990493329e-17
#   0 SNES Function norm 2.002577948965e-06
#   1 SNES Function norm 3.071476684385e-15
#   0 SNES Function norm 9.778797700463e-06
# Solved timestep 7, load: 0.7777777777777777
# Elastic Energy 0.00148, Surface energy: 0.0908
#
#
#
# Solving timestep 8, load: 0.8888888888888888
#   0 SNES Function norm 9.546301844294e-01
#   1 SNES Function norm 3.641959147165e-15
#   0 SNES Function norm 6.124517179970e-03
#   1 SNES Function norm 2.030264616628e-04
#   2 SNES Function norm 6.905373082723e-06
#   0 SNES Function norm 3.293852522377e-04
#   1 SNES Function norm 2.963785481945e-15
#   0 SNES Function norm 1.148891799933e-03
#   1 SNES Function norm 9.909996515273e-17
#   0 SNES Function norm 7.969072430892e-05
#   1 SNES Function norm 3.018645408354e-15
#   0 SNES Function norm 3.282540039539e-04
#   1 SNES Function norm 9.528717982945e-17
#   0 SNES Function norm 2.664612419757e-05
#   1 SNES Function norm 2.965058886605e-15
#   0 SNES Function norm 1.264938073729e-04
#   1 SNES Function norm 9.215550345000e-17
#   0 SNES Function norm 1.122202541046e-05
#   1 SNES Function norm 2.900235181772e-15
#   0 SNES Function norm 5.603126980884e-05
#   1 SNES Function norm 1.014306202638e-16
#   0 SNES Function norm 5.087701879855e-06
#   1 SNES Function norm 3.012858374681e-15
#   0 SNES Function norm 2.565125294784e-05
#   1 SNES Function norm 9.943576643440e-17
#   0 SNES Function norm 2.334392752358e-06
#   1 SNES Function norm 3.094630138067e-15
#   0 SNES Function norm 1.177964289644e-05
#   1 SNES Function norm 1.071330179115e-16
#   0 SNES Function norm 1.070494976914e-06
#   1 SNES Function norm 3.016013934871e-15
#   0 SNES Function norm 5.399796024241e-06
# Solved timestep 8, load: 0.8888888888888888
# Elastic Energy 0.0012, Surface energy: 0.0914
#
#
#
# Solving timestep 9, load: 1.0
#   0 SNES Function norm 9.546301844294e-01
#   1 SNES Function norm 3.519446958471e-15
#   0 SNES Function norm 4.804756007003e-03
#   1 SNES Function norm 6.029726769634e-05
#   2 SNES Function norm 1.406986989581e-16
#   0 SNES Function norm 2.219166121168e-04
#   1 SNES Function norm 2.921293667996e-15
#   0 SNES Function norm 7.817791648557e-04
#   1 SNES Function norm 1.570822848524e-16
#   0 SNES Function norm 4.217668712505e-05
#   1 SNES Function norm 2.983265491662e-15
#   0 SNES Function norm 1.691835220850e-04
#   1 SNES Function norm 8.019965805316e-17
#   0 SNES Function norm 1.006708884660e-05
#   1 SNES Function norm 3.082834170742e-15
#   0 SNES Function norm 4.579487524432e-05
#   1 SNES Function norm 1.226670251117e-16
#   0 SNES Function norm 2.938743214375e-06
#   1 SNES Function norm 2.999518371415e-15
#   0 SNES Function norm 1.433319169152e-05
#   1 SNES Function norm 1.360145622631e-16
#   0 SNES Function norm 9.542123761877e-07
#   1 SNES Function norm 3.202066174836e-15
#   0 SNES Function norm 4.774932305398e-06
# Solved timestep 9, load: 1.0
# Elastic Energy 0.00101, Surface energy: 0.0919
#
#
#
# CPU times: user 2min 23s, sys: 1min 46s, total: 4min 9s
# Wall time: 4min 4s

# %%
plt.figure()
plt.plot(data.get('load'), data.get('surface'), label='surface')
plt.plot(data.get('load'), data.get('elastic'), label='elastic')
# plt.plot(data.get('load'), [1./2. * t**2*Lx for t in data.get('load')], label='anal elast', ls=':', c='k')

plt.title('Kinking in plate under traction energetics')
plt.legend()
# plt.yticks([0, 1/20], [0, '$1/2.\sigma_c^2/E_0$'])
plt.xticks([parameters.get('loading').get("min"), parameters.get('loading').get("max")], [0, parameters.get('loading').get("max")])
plt.savefig("energetics.png")

# # savings?
# plt.figure()
# plt.plot(data.get('load'), data.get('surface'), label='surface')
# plt.plot(data.get('load'), data.get('elastic'), label='elastic')

# plt.title('Last steps')
# plt.legend()
# plt.yticks([0, 1/20], [0, '$1/2.\sigma_c^2/E_0$'])
# plt.xticks([0, 1], [0, 1])
# plt.savefig("lastSteps.png")


#plotter = pyvista.Plotter(
       #  title="Displacement",
        # window_size=[1600, 600],
        # shape=(1, 2), )
#_plt = plot_scalar(u_.sub(0), plotter, subplot=(0, 0))
#_plt = plot_vector(u, plotter, subplot=(0, 1))
#_plt.screenshot(f"displacement_MPI.png")


 #xvfb.start_xvfb(wait=0.05)
 #pyvista.OFF_SCREEN = True

#plotter = pyvista.Plotter(
        # title="Displacement",
      # window_size=[1600, 600],
      #  shape=(1, 2),
   #  )
#
# _plt = plot_scalar(alpha, plotter, subplot=(0, 0))
#_plt.screenshot(f"alpha2.png")
