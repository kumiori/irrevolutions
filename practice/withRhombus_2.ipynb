# %% [markdown]
# <a href="https://colab.research.google.com/github/kumiori/mec647/blob/fran%C3%A7ois/practice/withRhombus_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
import sys

try:
    import google.colab  # noqa: F401
except ImportError:
    import ufl  # noqa: F401
    import dolfinx  # noqa: F401
else:
    try:
        import ufl
        import dolfinx
    except ImportError:
        # !wget "https://fem-on-colab.github.io/releases/fenicsx-install.sh" -O "/tmp/fenicsx-install.sh" && bash "/tmp/fenicsx-install.sh";
        import ufl  # noqa: F401
        import dolfinx  # noqa: F401

try:
    import pyvista
except ImportError:
    # !{sys.executable} -m pip install --upgrade pyvista itkwidgets;
    import pyvista  # noqa: F401
    from pyvista.utilities import xvfb

try:
    import gmsh
except ImportError:
    # !{sys.executable} -m pip install gmsh
    import gmsh

# !sudo apt install libgl1-mesa-glx xvfb;
# !{sys.executable} -m pip install pythreejs;
# !{sys.executable} -m pip install ipygany;
# !{sys.executable} -m pip install --upgrade PyYAML
# !pip install --ignore-installed PyYAML

# %%
branch_name = 'main'

# !rm -rf mec647
try:
  # !git clone -b {branch_name} https://github.com/kumiori/mec647.git
except Exception:
  print('Something went wrong')
  # !rm -rf mec647
  # !git clone https://github.com/kumiori/mec647.git
# Out:
# Cloning into 'mec647'...
# remote: Enumerating objects: 1153, done.
# remote: Counting objects: 100% (1153/1153), done.
# remote: Compressing objects: 100% (857/857), done.
# remote: Total 1153 (delta 584), reused 581 (delta 260), pack-reused 0
# Receiving objects: 100% (1153/1153), 19.13 MiB | 8.56 MiB/s, done.
# Resolving deltas: 100% (584/584), done.

# %%
sys.path.append('mec647/')

# %%
import matplotlib.pyplot as plt
from petsc4py import PETSc
import numpy as np
from mpi4py import MPI

comm = MPI.COMM_WORLD

from dolfinx.fem import (
    Constant,
    Function,
    FunctionSpace,
    assemble_scalar,
    dirichletbc,
    form,
    locate_dofs_geometrical,
    set_bc,
)

# meshes
import meshes
from meshes import primitives

import models
from models import DamageElasticityModel as Brittle

# %%
import numpy as np
import yaml
import json
import sys
import os
from pathlib import Path

from mpi4py import MPI

import petsc4py
from petsc4py import PETSc

import dolfinx
import dolfinx.plot
from dolfinx import log
import ufl

import algorithms
from algorithms import am

from dolfinx.io import XDMFFile

import logging

logging.basicConfig(level=logging.INFO)

import dolfinx
import dolfinx.plot
import dolfinx.io
from dolfinx.fem import (
    Constant,
    Function,
    FunctionSpace,
    assemble_scalar,
    dirichletbc,
    form,
    locate_dofs_geometrical,
    set_bc,
)
import matplotlib.pyplot as plt
import pyvista 
from pyvista.utilities import xvfb


# visualisation
from utils import viz
import matplotlib.pyplot as plt
from utils.viz import plot_mesh, plot_vector, plot_scalar
generateStepwiseOutput=True

# %%
# Parameters
parameters = {
    'loading': {
        'min': 0.0,
        'max': 1.,
        'steps': 10
    },
    'geometry': {
        'geom_type': 'bar',
        'Lx': 0.6,
        'Ly': 1, 
        'theta':np.pi/4,
        's':0.1,
    },
    'model': {
        'E': 1,
        'nu': 0.37,
        'w1': 1.,
        'ell': 0.1, # 100/35,
        'k_res': 1.e-8
    },
    'solvers': {
          'elasticity': {        
            'snes': {
                'snes_type': 'newtontr',
                'snes_stol': 1e-8,
                'snes_atol': 1e-8,
                'snes_rtol': 1e-8,
                'snes_max_it': 250,
                'snes_monitor': "",
                'ksp_type': 'preonly',
                'pc_type': 'lu',
                'pc_factor_mat_solver_type': 'mumps'
            }
        },
          'damage': {        
            'snes': {
                'snes_type': 'vinewtonrsls',
                'snes_stol': 1e-5,
                'snes_atol': 1e-5,
                'snes_rtol': 1e-8,
                'snes_max_it': 100,
                'snes_monitor': "",
                'ksp_type': 'preonly',
                'pc_type': 'lu',
                'pc_factor_mat_solver_type': 'mumps'
            },
        },
          'damage_elasticity': {
            "max_it": 2000,
            "alpha_rtol": 1.0e-4,
            "criterion": "alpha_H1"
          }
    }
}

# %%
def  mesh_rh(name,
                     Lx,
                     Ly,
                     a,
                     b,
                     lc,
                     tdim,
                     order=1,
                     msh_file=None,
                     comm=MPI.COMM_WORLD):
    """
    Create mesh of 3d tensile test specimen according to ISO 6892-1:2019 using the Python API of Gmsh.
    """
    # Perform Gmsh work only on rank = 0

    if comm.rank == 0:

        import gmsh

        # Initialise gmsh and set options
        gmsh.initialize()
        gmsh.option.setNumber("General.Terminal", 1)

        gmsh.option.setNumber("Mesh.Algorithm", 6)
        model = gmsh.model()
        model.add("Rectangle")
        model.setCurrent("Rectangle")
        # points = [p1, p2, p3, p4, p5, p6, p7, p8,p9,p10,p11]
        p1 = model.geo.addPoint(0.0, 0.0, 0, lc, tag=1)
        p2 = model.geo.addPoint(Lx, 0.0, 0, lc, tag=2)
        p3 = model.geo.addPoint(Lx, Ly, 0.0, lc, tag=3)
        p4 = model.geo.addPoint(0, Ly, 0, lc, tag=4)
        p5 = model.geo.addPoint(Lx/2+b, Ly/2, 0.0, lc, tag=5)
        p6 = model.geo.addPoint(Lx/2, Ly/2+a, 0, lc/3, tag=6)
        p7 = model.geo.addPoint(Lx/2-b, Ly/2, 0.0, lc, tag=7)
        p8 = model.geo.addPoint(Lx/2, Ly/2-a, 0, lc/3 , tag=8)

        # Lines = [L1, L2, L3, L4, L5, L6, L7, L8]
        L1 = model.geo.addLine(p1, p2, tag=1)
        L2 = model.geo.addLine(p2, p3, tag=2)
        L3 = model.geo.addLine(p3, p4, tag=3)
        L4 = model.geo.addLine(p4, p1, tag=4)
        L5 = model.geo.addLine(p5, p6, tag=5)
        L6 = model.geo.addLine(p6, p7, tag=6)
        L7 = model.geo.addLine(p7, p8, tag=7)
        L8 = model.geo.addLine(p8, p5, tag=8)


        
        cloop1 = model.geo.addCurveLoop([L1, L2, L3, L4])
        cloop2 = model.geo.addCurveLoop([L5, L6, L7, L8])
        
        # surface_1 =
        model.geo.addPlaneSurface([cloop1, cloop2])

        model.geo.synchronize()
        surface_entities = [model[1] for model in model.getEntities(tdim)]

        model.addPhysicalGroup(tdim, surface_entities, tag=1)
        model.setPhysicalName(tdim, 1, "Rectangle surface")

        # Set mesh size via points
        # gmsh.model.mesh.setSize(points, lc)  # heuristic

        # gmsh.model.mesh.optimize("Netgen")

        # Set geometric order of mesh cells
        gmsh.model.mesh.setOrder(order)

        # Define physical groups for subdomains (! target tag > 0)
        # domain = 1
        # gmsh.model.addPhysicalGroup(tdim, [v[1] for v in volumes], domain)
        # gmsh.model.setPhysicalName(tdim, domain, 'domain')
              

        gmsh.model.addPhysicalGroup(tdim - 1, [1], tag=9)
        gmsh.model.setPhysicalName(tdim - 1, 9, "Bottom  of the Plate")
        gmsh.model.addPhysicalGroup(tdim - 1, [4], tag=10)
        gmsh.model.setPhysicalName(tdim - 1, 10, "Top  of the Plate")
        gmsh.model.addPhysicalGroup(tdim - 1, [5], tag=11)
        gmsh.model.setPhysicalName(tdim - 1, 11, "1/2 Top of the TipCrack")
        gmsh.model.addPhysicalGroup(tdim - 1, [6], tag=12)
        gmsh.model.setPhysicalName(tdim - 1, 12, "1/2 Top of the TipCrack")
        gmsh.model.addPhysicalGroup(tdim - 1, [7], tag=13)
        gmsh.model.setPhysicalName(tdim - 1, 13, "1/2 bottom of the TipCrack")
        gmsh.model.addPhysicalGroup(tdim - 1, [8], tag=14)
        gmsh.model.setPhysicalName(tdim - 1, 14, "1/2 bottom of the TipCrack")

        model.mesh.generate(tdim)


        #Generating the mesh
    model.geo.synchronize()
    model.mesh.generate(tdim)

    return gmsh.model

# %%
# Mesh

Lx = parameters.get("geometry").get("Lx")
Ly = parameters.get("geometry").get("Ly")
theta = parameters.get("geometry").get("theta")
s = parameters.get("geometry").get("s")

geom_type = parameters.get("geometry").get("geom_type")

lc=0.05

a=s* np.cos(theta/2)
b=s* np.sin(theta/2)


gmsh_model=mesh_rh('mesh', Lx, Ly, a,b,lc, 2, 1)


mesh, mts = meshes.gmsh_model_to_mesh(gmsh_model,
                               cell_data=False,
                               facet_data=True,
                               gdim=2)


plt.figure()
ax = plot_mesh(mesh)
fig = ax.get_figure()
fig.savefig(f"mesh.png")

# %%
# usedMesh=mesh 
# Enables opportunity to improve mesh at specific places, might lead to deformed elements
# Functional Setting

element_u = ufl.VectorElement("Lagrange", mesh.ufl_cell(),
                              degree=1, dim=2)

element_alpha = ufl.FiniteElement("Lagrange", mesh.ufl_cell(),
                              degree=1)

V_u = dolfinx.fem.FunctionSpace(mesh, element_u) 
V_alpha = dolfinx.fem.FunctionSpace(mesh, element_alpha) 

u = dolfinx.fem.Function(V_u, name="Displacement")
u_ = dolfinx.fem.Function(V_u, name="BoundaryDisplacement")


alpha = dolfinx.fem.Function(V_alpha, name="Damage")

# Pack state
state = {"u": u, "alpha": alpha}

# Bounds
alpha_ub = dolfinx.fem.Function(V_alpha, name="UpperBoundDamage")
alpha_lb = dolfinx.fem.Function(V_alpha, name="LowerBoundDamage")



dx = ufl.Measure("dx", domain = mesh)
ds = ufl.Measure("ds", domain = mesh)


# Boundary sets
dofs_alpha_left = locate_dofs_geometrical(V_alpha, lambda x: np.isclose(x[0], 0.))
dofs_alpha_right = locate_dofs_geometrical(V_alpha, lambda x: np.isclose(x[0], Lx))
dofs_alpha_bottom = locate_dofs_geometrical(V_alpha, lambda x: np.isclose(x[1], 0.))
dofs_alpha_top = locate_dofs_geometrical(V_alpha, lambda x: np.isclose(x[1], Ly))


dofs_u_left = locate_dofs_geometrical(V_u, lambda x: np.isclose(x[0], 0.))
dofs_u_right = locate_dofs_geometrical(V_u, lambda x: np.isclose(x[0], Lx))
dofs_u_top = locate_dofs_geometrical(V_u, lambda x: np.isclose(x[1], Ly))
dofs_u_bottom = locate_dofs_geometrical(V_u, lambda x: np.isclose(x[1], 0))

# Boundary data
u_.interpolate(lambda x: (np.zeros_like(x[0]), np.ones_like(x[1])))

# Bounds (nontrivial)
alpha_lb.interpolate(lambda x: np.zeros_like(x[0]))
alpha_ub.interpolate(lambda x: np.ones_like(x[0]))

# Boundary conditions
bcs_u = [
         dirichletbc(np.array([0., 0.], dtype=PETSc.ScalarType),
                      #dofs_u_bottom,
                      dofs_u_right,
                      V_u),
         #dirichletbc(u_, dofs_u_top)
         dirichletbc(u_, dofs_u_left)
         ]

bcs_alpha = [
             dirichletbc(np.array(0., dtype = PETSc.ScalarType),
                         np.concatenate([dofs_alpha_bottom, dofs_alpha_top]),
                         V_alpha)
]

bcs = {"bcs_u": bcs_u, "bcs_alpha": bcs_alpha}

model = Brittle(parameters["model"])

total_energy = model.total_energy_density(state) * dx
solver = am.AlternateMinimisation(total_energy,
                         state,
                         bcs,
                         parameters.get("solvers"),
                         bounds=(alpha_lb, alpha_ub)
                         )

# %%
# %%time
# Loop for evolution
loads = np.linspace(parameters.get("loading").get("min"),
                    parameters.get("loading").get("max"),
                    parameters.get("loading").get("steps"))

data = {
    'elastic': [],
    'surface': [],
    'total': [],
    'load': []
}
xvfb.start_xvfb(wait=0.05)
pyvista.OFF_SCREEN = True
plotter = pyvista.Plotter(
        title="Displacement",
        window_size=[1600, 600],
        shape=(1, 2),
    )

for (i_t, t) in enumerate(loads):
  # update boundary conditions

  u_.interpolate(lambda x: ( np.zeros_like(x[0]), t*np.ones_like(x[1])))
  u_.vector.ghostUpdate(addv=PETSc.InsertMode.INSERT,
                        mode=PETSc.ScatterMode.FORWARD)

  # update lower bound for damage
  alpha.vector.copy(alpha_lb.vector)
  alpha.vector.ghostUpdate(addv=PETSc.InsertMode.INSERT,
                        mode=PETSc.ScatterMode.FORWARD)

  # solve for current load step
  print(f"Solving timestep {i_t}, load: {t}")

  solver.solve()

  # postprocessing
  # global

  surface_energy = assemble_scalar(dolfinx.fem.form(model.damage_dissipation_density(state) * dx))

  elastic_energy = assemble_scalar(
        dolfinx.fem.form(model.elastic_energy_density(state) * dx))
  
  data.get('elastic').append(elastic_energy)
  data.get('surface').append(surface_energy)
  data.get('total').append(surface_energy+elastic_energy)
  data.get('load').append(t)

  print(f"Solved timestep {i_t}, load: {t}")
  print(f"Elastic Energy {elastic_energy:.3g}, Surface energy: {surface_energy:.3g}")
  print("\n\n")

  _plt = plot_scalar(alpha, plotter, subplot=(0, 0))
  _plt.screenshot(f"large_ell.png")
  if generateStepwiseOutput:
    if(surface_energy>1 and i_t%25==0):
    #if(i_t>1050 and i_t<1100):
        _plt = plot_scalar(alpha, plotter, subplot=(0, 0))
        #_plt.screenshot(f"./plots/s30/alpha"+str(i_t)+".png")
        _plt.screenshot(f"large_ell.png")
    #if i_t>1100:
    #    break
  if(i_t>20 and  elastic_energy<1E-3 and elastic_energy<surface_energy):
      #Brute force approach to determine, whether we have already reached a crack propagation state
      print("fail")
      break

  # savings?
# Out:
# Solving timestep 0, load: 0.0
#   0 SNES Function norm 0.000000000000e+00
#   0 SNES Function norm 0.000000000000e+00
# Solved timestep 0, load: 0.0
# Elastic Energy 0, Surface energy: 0
#
#
#
# Solving timestep 1, load: 0.1111111111111111
#   0 SNES Function norm 5.988763667275e-01
#   1 SNES Function norm 5.173631930385e-01
#   2 SNES Function norm 3.543368456605e-01
#   3 SNES Function norm 2.828415090444e-02
#   4 SNES Function norm 1.937694238895e-16
#   0 SNES Function norm 0.000000000000e+00
# Solved timestep 1, load: 0.1111111111111111
# Elastic Energy 0.00367, Surface energy: 0
#
#
#
# Solving timestep 2, load: 0.2222222222222222
#   0 SNES Function norm 5.988763667275e-01
#   1 SNES Function norm 4.791010933820e-01
#   2 SNES Function norm 2.395505466910e-01
#   3 SNES Function norm 4.759476372218e-16
#   0 SNES Function norm 0.000000000000e+00
# Solved timestep 2, load: 0.2222222222222222
# Elastic Energy 0.0147, Surface energy: 0
#
#
#
# Solving timestep 3, load: 0.3333333333333333
#   0 SNES Function norm 5.988763667275e-01
#   1 SNES Function norm 3.593258200365e-01
#   2 SNES Function norm 7.235179573165e-16
#   0 SNES Function norm 0.000000000000e+00
# Solved timestep 3, load: 0.3333333333333333
# Elastic Energy 0.033, Surface energy: 0
#
#
#
# Solving timestep 4, load: 0.4444444444444444
#   0 SNES Function norm 5.988763667275e-01
#   1 SNES Function norm 2.395505466910e-01
#   2 SNES Function norm 8.069290201256e-16
#   0 SNES Function norm 1.017013559689e-04
#   1 SNES Function norm 1.991878615767e-20
#   0 SNES Function norm 2.784741519413e-05
#   1 SNES Function norm 7.007531067436e-16
#   0 SNES Function norm 6.510470174777e-07
# Solved timestep 4, load: 0.4444444444444444
# Elastic Energy 0.0587, Surface energy: 1.24e-06
#
#
#
# Solving timestep 5, load: 0.5555555555555556
#   0 SNES Function norm 5.988763667275e-01
#   1 SNES Function norm 1.197752733455e-01
#   2 SNES Function norm 9.388303128182e-16
#   0 SNES Function norm 3.250985775704e-04
#   1 SNES Function norm 2.212358682012e-04
#   2 SNES Function norm 1.530014442498e-19
#   0 SNES Function norm 2.386687247119e-04
#   1 SNES Function norm 8.886018025896e-16
#   0 SNES Function norm 1.072553333187e-05
#   1 SNES Function norm 1.198993013858e-19
#   0 SNES Function norm 8.954989912376e-06
#   1 SNES Function norm 9.168531324841e-16
#   0 SNES Function norm 4.128025497371e-07
# Solved timestep 5, load: 0.5555555555555556
# Elastic Energy 0.0918, Surface energy: 2.09e-05
#
#
#
# Solving timestep 6, load: 0.6666666666666666
#   0 SNES Function norm 5.988763667275e-01
#   1 SNES Function norm 1.723988932736e-15
#   0 SNES Function norm 6.144149944441e-04
#   1 SNES Function norm 4.803663730536e-04
#   2 SNES Function norm 1.026054397207e-04
#   3 SNES Function norm 3.516686577917e-19
#   0 SNES Function norm 8.068075340069e-04
#   1 SNES Function norm 1.156039624883e-15
#   0 SNES Function norm 5.373405494954e-05
#   1 SNES Function norm 4.066296330053e-19
#   0 SNES Function norm 8.388193098917e-05
#   1 SNES Function norm 1.218441067578e-15
#   0 SNES Function norm 5.841739786146e-06
# Solved timestep 6, load: 0.6666666666666666
# Elastic Energy 0.132, Surface energy: 0.00015
#
#
#
# Solving timestep 7, load: 0.7777777777777777
#   0 SNES Function norm 5.988613773608e-01
#   1 SNES Function norm 1.634813312155e-15
#   0 SNES Function norm 1.445707192519e-03
#   1 SNES Function norm 8.763966966010e-04
#   2 SNES Function norm 2.068235224345e-04
#   3 SNES Function norm 1.254099874284e-05
#   4 SNES Function norm 1.097254601002e-18
#   0 SNES Function norm 2.269578495255e-03
#   1 SNES Function norm 1.362256353812e-15
#   0 SNES Function norm 2.059144117639e-04
#   1 SNES Function norm 1.142100637179e-04
#   2 SNES Function norm 1.143052132236e-18
#   0 SNES Function norm 5.616638136729e-04
#   1 SNES Function norm 1.373991359701e-15
#   0 SNES Function norm 5.803171557490e-05
#   1 SNES Function norm 1.295149176710e-18
#   0 SNES Function norm 1.649308857275e-04
#   1 SNES Function norm 1.317871685652e-15
#   0 SNES Function norm 1.726224952420e-05
#   1 SNES Function norm 1.177824212190e-18
#   0 SNES Function norm 4.917565437337e-05
#   1 SNES Function norm 1.343542202949e-15
#   0 SNES Function norm 5.157088373662e-06
# Solved timestep 7, load: 0.7777777777777777
# Elastic Energy 0.179, Surface energy: 0.00104
#
#
#
# Solving timestep 8, load: 0.8888888888888888
#   0 SNES Function norm 5.985663299945e-01
#   1 SNES Function norm 1.746075790241e-15
#   0 SNES Function norm 2.241689373715e-03
#   0 SNES Function norm 4.927099595433e-03
#   1 SNES Function norm 1.600043251806e-15
#   0 SNES Function norm 8.906660426021e-03
#   1 SNES Function norm 1.686292121491e-03
#   2 SNES Function norm 5.045926164780e-04
#   3 SNES Function norm 4.145250932549e-05
#   4 SNES Function norm 2.650519170674e-18
#   0 SNES Function norm 7.572258513364e-03
#   1 SNES Function norm 1.388327548375e-15
#   0 SNES Function norm 1.025437272906e-03
#   1 SNES Function norm 7.319933499457e-04
#   2 SNES Function norm 1.288175461348e-05
#   3 SNES Function norm 4.128141269818e-18
#   0 SNES Function norm 3.942888910354e-03
#   1 SNES Function norm 1.369045144346e-15
#   0 SNES Function norm 6.436531910159e-04
#   1 SNES Function norm 3.825783567354e-04
#   2 SNES Function norm 3.112071784243e-05
#   3 SNES Function norm 4.848516327039e-18
#   0 SNES Function norm 2.605141244706e-03
#   1 SNES Function norm 1.398335167027e-15
#   0 SNES Function norm 4.499157056863e-04
#   1 SNES Function norm 2.318589822313e-04
#   2 SNES Function norm 1.708373339457e-05
#   3 SNES Function norm 5.143732481019e-18
#   0 SNES Function norm 1.852793503659e-03
#   1 SNES Function norm 1.367100222390e-15
#   0 SNES Function norm 3.304197633935e-04
#   1 SNES Function norm 6.733922332122e-18
#   0 SNES Function norm 1.364358983340e-03
#   1 SNES Function norm 1.405071283141e-15
#   0 SNES Function norm 2.491435202036e-04
#   1 SNES Function norm 6.282698276764e-18
#   0 SNES Function norm 1.021038070589e-03
#   1 SNES Function norm 1.325359798833e-15
#   0 SNES Function norm 1.896938493349e-04
#   1 SNES Function norm 6.944623331478e-18
#   0 SNES Function norm 7.713557810004e-04
#   1 SNES Function norm 1.477717972499e-15
#   0 SNES Function norm 1.452700228100e-04
#   1 SNES Function norm 3.085062532153e-06
#   0 SNES Function norm 5.868343867430e-04
#   1 SNES Function norm 1.325361582988e-15
#   0 SNES Function norm 1.116950064629e-04
#   1 SNES Function norm 8.247508921572e-06
#   0 SNES Function norm 4.500361845235e-04
#   1 SNES Function norm 1.377879270124e-15
#   0 SNES Function norm 8.665747279027e-05
#   1 SNES Function norm 6.791411289991e-18
#   0 SNES Function norm 3.473377838480e-04
#   1 SNES Function norm 1.375747826115e-15
#   0 SNES Function norm 6.725581005505e-05
#   1 SNES Function norm 7.340656903612e-06
#   0 SNES Function norm 2.688075296911e-04
#   1 SNES Function norm 1.390789881299e-15
#   0 SNES Function norm 5.239874152360e-05
#   1 SNES Function norm 7.729651452709e-18
#   0 SNES Function norm 2.090964649266e-04
#   1 SNES Function norm 1.337925577106e-15
#   0 SNES Function norm 4.080766511454e-05
#   1 SNES Function norm 7.416779520790e-18
#   0 SNES Function norm 1.629266723543e-04
#   1 SNES Function norm 1.296180510865e-15
#   0 SNES Function norm 3.189653718703e-05
#   1 SNES Function norm 6.780173624579e-18
#   0 SNES Function norm 1.271003897242e-04
#   1 SNES Function norm 1.367896845437e-15
#   0 SNES Function norm 2.494018586840e-05
#   1 SNES Function norm 7.187546524487e-18
#   0 SNES Function norm 9.925167565419e-05
#   1 SNES Function norm 1.395060973724e-15
#   0 SNES Function norm 1.951028260814e-05
#   1 SNES Function norm 7.825863183844e-18
#   0 SNES Function norm 7.756629477322e-05
#   1 SNES Function norm 1.369962316925e-15
#   0 SNES Function norm 1.526864118115e-05
#   1 SNES Function norm 8.232700989273e-18
#   0 SNES Function norm 6.065675300857e-05
#   1 SNES Function norm 1.323519624762e-15
#   0 SNES Function norm 1.195297887801e-05
#   1 SNES Function norm 7.715502555908e-18
#   0 SNES Function norm 4.745682843965e-05
#   1 SNES Function norm 1.293598295034e-15
#   0 SNES Function norm 9.359718146284e-06
# Solved timestep 8, load: 0.8888888888888888
# Elastic Energy 0.216, Surface energy: 0.0173
#
#
#
# Solving timestep 9, load: 1.0
#   0 SNES Function norm 5.980063220196e-01
#   1 SNES Function norm 1.556046662165e-15
#   0 SNES Function norm 4.234485245391e-03
#   0 SNES Function norm 2.807283542322e-02
#   1 SNES Function norm 1.685010609090e-15
#   0 SNES Function norm 7.752065027459e-03
#   1 SNES Function norm 3.208378152865e-03
#   2 SNES Function norm 1.651504183747e-03
#   3 SNES Function norm 6.223351928221e-04
#   4 SNES Function norm 1.352779947767e-04
#   5 SNES Function norm 4.979125188273e-06
#   0 SNES Function norm 1.936170707836e-02
#   1 SNES Function norm 1.294375742514e-15
#   0 SNES Function norm 3.453901397085e-03
#   1 SNES Function norm 6.813425954558e-04
#   2 SNES Function norm 2.194838844887e-04
#   3 SNES Function norm 1.417230865877e-17
#   0 SNES Function norm 1.119875505550e-02
#   1 SNES Function norm 1.326091349508e-15
#   0 SNES Function norm 2.825092687984e-03
#   1 SNES Function norm 4.009322482933e-04
#   2 SNES Function norm 1.514961255542e-17
#   0 SNES Function norm 9.935169666114e-03
#   1 SNES Function norm 1.236031646426e-15
#   0 SNES Function norm 2.785814594132e-03
#   1 SNES Function norm 6.882175262055e-04
#   2 SNES Function norm 1.696753278895e-17
#   0 SNES Function norm 9.453214538261e-03
#   1 SNES Function norm 1.240398506014e-15
#   0 SNES Function norm 2.997852782583e-03
#   1 SNES Function norm 6.281284976289e-04
#   2 SNES Function norm 2.545900441928e-05
#   3 SNES Function norm 2.258976214713e-17
#   0 SNES Function norm 8.961715358976e-03
#   1 SNES Function norm 1.178902613193e-15
#   0 SNES Function norm 3.354687803337e-03
#   1 SNES Function norm 5.563285067444e-04
#   2 SNES Function norm 2.354075972433e-17
#   0 SNES Function norm 8.948661850626e-03
#   1 SNES Function norm 1.130157574812e-15
#   0 SNES Function norm 3.935838729690e-03
#   1 SNES Function norm 2.197232314004e-04
#   2 SNES Function norm 2.325590090035e-17
#   0 SNES Function norm 9.130773467670e-03
#   1 SNES Function norm 1.065713282939e-15
#   0 SNES Function norm 4.760040576777e-03
#   1 SNES Function norm 1.352530734010e-04
#   2 SNES Function norm 2.599215189405e-17
#   0 SNES Function norm 9.372972405189e-03
#   1 SNES Function norm 1.088711731949e-15
#   0 SNES Function norm 5.768204051831e-03
#   1 SNES Function norm 2.533779515014e-04
#   2 SNES Function norm 2.851057196048e-17
#   0 SNES Function norm 9.382125951987e-03
#   1 SNES Function norm 1.203742438446e-15
#   0 SNES Function norm 6.655520274528e-03
#   1 SNES Function norm 1.500093316288e-04
#   2 SNES Function norm 2.896621524507e-17
#   0 SNES Function norm 8.861777577124e-03
#   1 SNES Function norm 1.059872710488e-15
#   0 SNES Function norm 6.999232564882e-03
#   1 SNES Function norm 4.039564380789e-04
#   2 SNES Function norm 5.807055581843e-06
#   0 SNES Function norm 7.864998621031e-03
#   1 SNES Function norm 1.135659303690e-15
#   0 SNES Function norm 6.702648296079e-03
#   1 SNES Function norm 2.869295509045e-04
#   2 SNES Function norm 3.280954532094e-17
#   0 SNES Function norm 6.806899839929e-03
#   1 SNES Function norm 1.124133902822e-15
#   0 SNES Function norm 5.812100404018e-03
#   1 SNES Function norm 1.438996040303e-04
#   2 SNES Function norm 3.591053008263e-17
#   0 SNES Function norm 5.920220254179e-03
#   1 SNES Function norm 1.112727825125e-15
#   0 SNES Function norm 4.746333483933e-03
#   1 SNES Function norm 2.742826793016e-05
#   2 SNES Function norm 3.355015383000e-17
#   0 SNES Function norm 5.152400886525e-03
#   1 SNES Function norm 1.105303573409e-15
#   0 SNES Function norm 4.028114214271e-03
#   1 SNES Function norm 6.631496859249e-05
#   2 SNES Function norm 3.941566279448e-17
#   0 SNES Function norm 4.519336512035e-03
#   1 SNES Function norm 1.029193192853e-15
#   0 SNES Function norm 3.691200052789e-03
#   1 SNES Function norm 2.807524912343e-05
#   2 SNES Function norm 3.318145673304e-17
#   0 SNES Function norm 4.028106929830e-03
#   1 SNES Function norm 1.122233025395e-15
#   0 SNES Function norm 3.621819066655e-03
#   1 SNES Function norm 9.666651706508e-05
#   2 SNES Function norm 4.019665061233e-17
#   0 SNES Function norm 3.694662052920e-03
#   1 SNES Function norm 1.080084200865e-15
#   0 SNES Function norm 3.827598371680e-03
#   1 SNES Function norm 8.737840296233e-05
#   2 SNES Function norm 3.533016918574e-17
#   0 SNES Function norm 3.518435841910e-03
#   1 SNES Function norm 1.041717838259e-15
#   0 SNES Function norm 4.037813029308e-03
#   1 SNES Function norm 1.586067713622e-05
#   2 SNES Function norm 5.078748399997e-17
#   0 SNES Function norm 3.176865282349e-03
#   1 SNES Function norm 1.034142697407e-15
#   0 SNES Function norm 3.465985408133e-03
#   1 SNES Function norm 5.751684513910e-05
#   2 SNES Function norm 4.629307311321e-17
#   0 SNES Function norm 2.609462956672e-03
#   1 SNES Function norm 1.161961195360e-15
#   0 SNES Function norm 2.837010327241e-03
#   1 SNES Function norm 4.521823762229e-17
#   0 SNES Function norm 2.310705406501e-03
#   1 SNES Function norm 1.065095417184e-15
#   0 SNES Function norm 2.823714243953e-03
#   1 SNES Function norm 1.025384580509e-05
#   2 SNES Function norm 4.564099804190e-17
#   0 SNES Function norm 2.270072359737e-03
#   1 SNES Function norm 1.054348577014e-15
#   0 SNES Function norm 3.225190267111e-03
#   1 SNES Function norm 5.530454109492e-17
#   0 SNES Function norm 2.346621204028e-03
#   1 SNES Function norm 1.135207647811e-15
#   0 SNES Function norm 3.354365232348e-03
#   1 SNES Function norm 1.835126066289e-05
#   2 SNES Function norm 5.576485311363e-17
#   0 SNES Function norm 1.938400883511e-03
#   1 SNES Function norm 1.097167096182e-15
#   0 SNES Function norm 2.570217534059e-03
#   1 SNES Function norm 1.865170066012e-06
#   0 SNES Function norm 1.418177193189e-03
#   1 SNES Function norm 1.094362937056e-15
#   0 SNES Function norm 1.980558416879e-03
#   1 SNES Function norm 3.190336501665e-05
#   2 SNES Function norm 5.560661347213e-17
#   0 SNES Function norm 1.181873337478e-03
#   1 SNES Function norm 1.022761680494e-15
#   0 SNES Function norm 1.576339463346e-03
#   1 SNES Function norm 4.705806819989e-17
#   0 SNES Function norm 1.003195248602e-03
#   1 SNES Function norm 9.394333646869e-16
#   0 SNES Function norm 1.063837468806e-03
#   1 SNES Function norm 6.302457733955e-17
#   0 SNES Function norm 8.555556272676e-04
#   1 SNES Function norm 1.052025226196e-15
#   0 SNES Function norm 6.809017194471e-04
#   1 SNES Function norm 1.348704748054e-06
#   0 SNES Function norm 7.432039499506e-04
#   1 SNES Function norm 1.098057055703e-15
#   0 SNES Function norm 5.001979855204e-04
#   1 SNES Function norm 2.998098352213e-07
#   0 SNES Function norm 6.518277318708e-04
#   1 SNES Function norm 1.037243202192e-15
#   0 SNES Function norm 4.173896315801e-04
#   1 SNES Function norm 1.351267270805e-07
#   0 SNES Function norm 5.735716355438e-04
#   1 SNES Function norm 1.035578393632e-15
#   0 SNES Function norm 3.655419005296e-04
#   1 SNES Function norm 5.145505138810e-17
#   0 SNES Function norm 5.052712796847e-04
#   1 SNES Function norm 1.029791858829e-15
#   0 SNES Function norm 3.236634046291e-04
#   1 SNES Function norm 1.267732135233e-06
#   0 SNES Function norm 4.453895239398e-04
#   1 SNES Function norm 1.116198429058e-15
#   0 SNES Function norm 2.871343316322e-04
#   1 SNES Function norm 5.165082175595e-17
#   0 SNES Function norm 3.925894824933e-04
#   1 SNES Function norm 1.110764128227e-15
#   0 SNES Function norm 2.547723827319e-04
#   1 SNES Function norm 6.620811987207e-17
#   0 SNES Function norm 3.464384693647e-04
#   1 SNES Function norm 1.008111746743e-15
#   0 SNES Function norm 2.260248828887e-04
#   1 SNES Function norm 5.449571439033e-17
#   0 SNES Function norm 3.058766649362e-04
#   1 SNES Function norm 1.140259179072e-15
#   0 SNES Function norm 2.004917603991e-04
#   1 SNES Function norm 6.779600913055e-17
#   0 SNES Function norm 2.702112341523e-04
#   1 SNES Function norm 9.991091833694e-16
#   0 SNES Function norm 1.778249381750e-04
#   1 SNES Function norm 6.158032465231e-17
#   0 SNES Function norm 2.388291580369e-04
#   1 SNES Function norm 1.134946024914e-15
#   0 SNES Function norm 1.577138417712e-04
#   1 SNES Function norm 5.485905050664e-17
#   0 SNES Function norm 2.111967964169e-04
#   1 SNES Function norm 1.012796771931e-15
#   0 SNES Function norm 1.398799499523e-04
#   1 SNES Function norm 5.947140592871e-17
#   0 SNES Function norm 1.868505749097e-04
#   1 SNES Function norm 1.114840457450e-15
#   0 SNES Function norm 1.240734444561e-04
#   1 SNES Function norm 5.102014449212e-17
#   0 SNES Function norm 1.653874005739e-04
#   1 SNES Function norm 9.640988669142e-16
#   0 SNES Function norm 1.100703952225e-04
#   1 SNES Function norm 4.747204113886e-17
#   0 SNES Function norm 1.464561741934e-04
#   1 SNES Function norm 1.035679204580e-15
#   0 SNES Function norm 9.767023932406e-05
#   1 SNES Function norm 1.305319376087e-06
#   0 SNES Function norm 1.297505294176e-04
#   1 SNES Function norm 9.772306822734e-16
#   0 SNES Function norm 8.670876799447e-05
#   1 SNES Function norm 5.110416925266e-17
#   0 SNES Function norm 1.150796472986e-04
#   1 SNES Function norm 1.116483062747e-15
#   0 SNES Function norm 7.710431668982e-05
#   1 SNES Function norm 5.683218177470e-17
#   0 SNES Function norm 1.023764874536e-04
#   1 SNES Function norm 9.655072731967e-16
#   0 SNES Function norm 6.863405271748e-05
#   1 SNES Function norm 5.206782031074e-17
#   0 SNES Function norm 9.110214194546e-05
#   1 SNES Function norm 1.061671392995e-15
#   0 SNES Function norm 6.114109933335e-05
#   1 SNES Function norm 5.025196559380e-07
#   0 SNES Function norm 8.109990396303e-05
#   1 SNES Function norm 1.057300223702e-15
#   0 SNES Function norm 5.450199455822e-05
#   1 SNES Function norm 6.457973800087e-17
#   0 SNES Function norm 7.214432928716e-05
#   1 SNES Function norm 1.101124370192e-15
#   0 SNES Function norm 4.861298342197e-05
#   1 SNES Function norm 2.109095755747e-07
#   0 SNES Function norm 6.427281467676e-05
#   1 SNES Function norm 1.071077984745e-15
#   0 SNES Function norm 4.339617859784e-05
#   1 SNES Function norm 5.313298486362e-17
#   0 SNES Function norm 5.733171725205e-05
#   1 SNES Function norm 1.042185053039e-15
#   0 SNES Function norm 3.881102015152e-05
#   1 SNES Function norm 6.289670845603e-17
#   0 SNES Function norm 5.124662961485e-05
#   1 SNES Function norm 1.043644378572e-15
#   0 SNES Function norm 3.475498830660e-05
#   1 SNES Function norm 1.210915245420e-06
#   0 SNES Function norm 4.583446477662e-05
#   1 SNES Function norm 1.049458377787e-15
#   0 SNES Function norm 3.118742624624e-05
#   1 SNES Function norm 4.437481009868e-17
#   0 SNES Function norm 4.108039218638e-05
#   1 SNES Function norm 1.100955320521e-15
#   0 SNES Function norm 2.801762953803e-05
#   1 SNES Function norm 5.300857388472e-17
#   0 SNES Function norm 3.689752224992e-05
#   1 SNES Function norm 1.061143736156e-15
#   0 SNES Function norm 2.522059820217e-05
#   1 SNES Function norm 5.394122722933e-17

# %%
plt.figure()
plt.plot(data.get('load'), data.get('surface'), label='surface')
plt.plot(data.get('load'), data.get('elastic'), label='elastic')
# plt.plot(data.get('load'), [1./2. * t**2*Lx for t in data.get('load')], label='anal elast', ls=':', c='k')

plt.title('Traction bar energetics')
plt.legend()
# plt.yticks([0, 1/20], [0, '$1/2.\sigma_c^2/E_0$'])
plt.xticks([parameters.get('loading').get("min"), parameters.get('loading').get("max")], [0, parameters.get('loading').get("max")])
plt.savefig("energetics.png")
