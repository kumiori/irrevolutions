# %% [markdown]
# <a href="https://colab.research.google.com/github/kumiori/mec647/blob/fran%C3%A7ois/practice/withRhombus_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
import sys

try:
    import google.colab  # noqa: F401
except ImportError:
    import ufl  # noqa: F401
    import dolfinx  # noqa: F401
else:
    try:
        import ufl
        import dolfinx
    except ImportError:
        # !wget "https://fem-on-colab.github.io/releases/fenicsx-install.sh" -O "/tmp/fenicsx-install.sh" && bash "/tmp/fenicsx-install.sh";
        import ufl  # noqa: F401
        import dolfinx  # noqa: F401

try:
    import pyvista
except ImportError:
    # !{sys.executable} -m pip install --upgrade pyvista itkwidgets;
    import pyvista  # noqa: F401
    from pyvista.utilities import xvfb

try:
    import gmsh
except ImportError:
    # !{sys.executable} -m pip install gmsh
    import gmsh

# !sudo apt install libgl1-mesa-glx xvfb;
# !{sys.executable} -m pip install pythreejs;
# !{sys.executable} -m pip install ipygany;
# !{sys.executable} -m pip install --upgrade PyYAML
# !pip install --ignore-installed PyYAML

# %%
branch_name = 'main'

# !rm -rf mec647
try:
  # !git clone -b {branch_name} https://github.com/kumiori/mec647.git
except Exception:
  print('Something went wrong')
  # !rm -rf mec647
  # !git clone https://github.com/kumiori/mec647.git
# Out:
# Cloning into 'mec647'...
# remote: Enumerating objects: 1264, done.
# remote: Counting objects: 100% (1264/1264), done.
# remote: Compressing objects: 100% (938/938), done.
# remote: Total 1264 (delta 645), reused 628 (delta 285), pack-reused 0
# Receiving objects: 100% (1264/1264), 19.79 MiB | 12.67 MiB/s, done.
# Resolving deltas: 100% (645/645), done.

# %%
sys.path.append('mec647/')

# %%
import matplotlib.pyplot as plt
from petsc4py import PETSc
import numpy as np
from mpi4py import MPI

comm = MPI.COMM_WORLD

from dolfinx.fem import (
    Constant,
    Function,
    FunctionSpace,
    assemble_scalar,
    dirichletbc,
    form,
    locate_dofs_geometrical,
    set_bc,
)

# meshes
import meshes
from meshes import primitives

import models
from models import DamageElasticityModel as Brittle

# %%
import numpy as np
import yaml
import json
import sys
import os
from pathlib import Path

from mpi4py import MPI

import petsc4py
from petsc4py import PETSc

import dolfinx
import dolfinx.plot
from dolfinx import log
import ufl

import algorithms
from algorithms import am

from dolfinx.io import XDMFFile

import logging

logging.basicConfig(level=logging.INFO)

import dolfinx
import dolfinx.plot
import dolfinx.io
from dolfinx.fem import (
    Constant,
    Function,
    FunctionSpace,
    assemble_scalar,
    dirichletbc,
    form,
    locate_dofs_geometrical,
    set_bc,
)
import matplotlib.pyplot as plt
import pyvista 
from pyvista.utilities import xvfb


# visualisation
from utils import viz
import matplotlib.pyplot as plt
from utils.viz import plot_mesh, plot_vector, plot_scalar
generateStepwiseOutput=True

# %%
# Parameters
parameters = {
    'loading': {
        'min': 0.0,
        'max': 1.,
        'steps': 10
    },
    'geometry': {
        'geom_type': 'bar',
        'Lx': 0.66,
        'Ly': 1, 
        'theta':70*np.pi/180,
        's':0.15,
        #'s':0.086,
    },
    'model': {
        'E': 1,
        'nu': 0.37,
        'w1': 1.,
        'ell': 0.1, # 100/35,
        'k_res': 1.e-8
    },
    'solvers': {
          'elasticity': {        
            'snes': {
                'snes_type': 'newtontr',
                'snes_stol': 1e-8,
                'snes_atol': 1e-8,
                'snes_rtol': 1e-8,
                'snes_max_it': 250,
                'snes_monitor': "",
                'ksp_type': 'preonly',
                'pc_type': 'lu',
                'pc_factor_mat_solver_type': 'mumps'
            }
        },
          'damage': {        
            'snes': {
                'snes_type': 'vinewtonrsls',
                'snes_stol': 1e-5,
                'snes_atol': 1e-5,
                'snes_rtol': 1e-8,
                'snes_max_it': 100,
                'snes_monitor': "",
                'ksp_type': 'preonly',
                'pc_type': 'lu',
                'pc_factor_mat_solver_type': 'mumps'
            },
        },
          'damage_elasticity': {
            "max_it": 2000,
            "alpha_rtol": 1.0e-4,
            "criterion": "alpha_H1"
          }
    }
}

# %%
def  mesh_rh(name,
                     Lx,
                     Ly,
                     a,
                     b,
                     lc,
                     tdim,
                     order=1,
                     msh_file=None,
                     comm=MPI.COMM_WORLD):
    """
    Create mesh of 3d tensile test specimen according to ISO 6892-1:2019 using the Python API of Gmsh.
    """
    # Perform Gmsh work only on rank = 0

    if comm.rank == 0:

        import gmsh

        # Initialise gmsh and set options
        gmsh.initialize()
        gmsh.option.setNumber("General.Terminal", 1)

        gmsh.option.setNumber("Mesh.Algorithm", 6)
        model = gmsh.model()
        model.add("Rectangle")
        model.setCurrent("Rectangle")
        # points = [p1, p2, p3, p4, p5, p6, p7, p8,p9,p10,p11]
        p1 = model.geo.addPoint(0.0, 0.0, 0, lc, tag=1)
        p2 = model.geo.addPoint(Lx, 0.0, 0, lc, tag=2)
        p3 = model.geo.addPoint(Lx, Ly, 0.0, lc, tag=3)
        p4 = model.geo.addPoint(0, Ly, 0, lc, tag=4)
        p5 = model.geo.addPoint(Lx/2+b, Ly/2, 0.0, lc, tag=5)
        p6 = model.geo.addPoint(Lx/2, Ly/2+a, 0, lc/3, tag=6)
        p7 = model.geo.addPoint(Lx/2-b, Ly/2, 0.0, lc, tag=7)
        p8 = model.geo.addPoint(Lx/2, Ly/2-a, 0, lc/3 , tag=8)

        # Lines = [L1, L2, L3, L4, L5, L6, L7, L8]
        L1 = model.geo.addLine(p1, p2, tag=1)
        L2 = model.geo.addLine(p2, p3, tag=2)
        L3 = model.geo.addLine(p3, p4, tag=3)
        L4 = model.geo.addLine(p4, p1, tag=4)
        L5 = model.geo.addLine(p5, p6, tag=5)
        L6 = model.geo.addLine(p6, p7, tag=6)
        L7 = model.geo.addLine(p7, p8, tag=7)
        L8 = model.geo.addLine(p8, p5, tag=8)


        
        cloop1 = model.geo.addCurveLoop([L1, L2, L3, L4])
        cloop2 = model.geo.addCurveLoop([L5, L6, L7, L8])
        
        # surface_1 =
        model.geo.addPlaneSurface([cloop1, cloop2])

        model.geo.synchronize()
        surface_entities = [model[1] for model in model.getEntities(tdim)]

        model.addPhysicalGroup(tdim, surface_entities, tag=1)
        model.setPhysicalName(tdim, 1, "Rectangle surface")

        # Set mesh size via points
        # gmsh.model.mesh.setSize(points, lc)  # heuristic

        # gmsh.model.mesh.optimize("Netgen")

        # Set geometric order of mesh cells
        gmsh.model.mesh.setOrder(order)

        # Define physical groups for subdomains (! target tag > 0)
        # domain = 1
        # gmsh.model.addPhysicalGroup(tdim, [v[1] for v in volumes], domain)
        # gmsh.model.setPhysicalName(tdim, domain, 'domain')
              

        gmsh.model.addPhysicalGroup(tdim - 1, [1], tag=9)
        gmsh.model.setPhysicalName(tdim - 1, 9, "Bottom  of the Plate")
        gmsh.model.addPhysicalGroup(tdim - 1, [4], tag=10)
        gmsh.model.setPhysicalName(tdim - 1, 10, "Top  of the Plate")
        gmsh.model.addPhysicalGroup(tdim - 1, [5], tag=11)
        gmsh.model.setPhysicalName(tdim - 1, 11, "1/2 Top of the TipCrack")
        gmsh.model.addPhysicalGroup(tdim - 1, [6], tag=12)
        gmsh.model.setPhysicalName(tdim - 1, 12, "1/2 Top of the TipCrack")
        gmsh.model.addPhysicalGroup(tdim - 1, [7], tag=13)
        gmsh.model.setPhysicalName(tdim - 1, 13, "1/2 bottom of the TipCrack")
        gmsh.model.addPhysicalGroup(tdim - 1, [8], tag=14)
        gmsh.model.setPhysicalName(tdim - 1, 14, "1/2 bottom of the TipCrack")

        model.mesh.generate(tdim)


        #Generating the mesh
    model.geo.synchronize()
    model.mesh.generate(tdim)

    return gmsh.model

# %%
# Mesh

Lx = parameters.get("geometry").get("Lx")
Ly = parameters.get("geometry").get("Ly")
theta = parameters.get("geometry").get("theta")
s = parameters.get("geometry").get("s")

geom_type = parameters.get("geometry").get("geom_type")

lc=0.05

a=s* np.cos(theta/2)
b=s* np.sin(theta/2)


gmsh_model=mesh_rh('mesh', Lx, Ly, a,b,lc, 2, 1)


mesh, mts = meshes.gmsh_model_to_mesh(gmsh_model,
                               cell_data=False,
                               facet_data=True,
                               gdim=2)


plt.figure()
ax = plot_mesh(mesh)
fig = ax.get_figure()
fig.savefig(f"mesh.png")

# %%
# usedMesh=mesh 
# Enables opportunity to improve mesh at specific places, might lead to deformed elements
# Functional Setting

element_u = ufl.VectorElement("Lagrange", mesh.ufl_cell(),
                              degree=1, dim=2)

element_alpha = ufl.FiniteElement("Lagrange", mesh.ufl_cell(),
                              degree=1)

V_u = dolfinx.fem.FunctionSpace(mesh, element_u) 
V_alpha = dolfinx.fem.FunctionSpace(mesh, element_alpha) 

u = dolfinx.fem.Function(V_u, name="Displacement")
u_ = dolfinx.fem.Function(V_u, name="BoundaryDisplacement")


alpha = dolfinx.fem.Function(V_alpha, name="Damage")

# Pack state
state = {"u": u, "alpha": alpha}

# Bounds
alpha_ub = dolfinx.fem.Function(V_alpha, name="UpperBoundDamage")
alpha_lb = dolfinx.fem.Function(V_alpha, name="LowerBoundDamage")



dx = ufl.Measure("dx", domain = mesh)
ds = ufl.Measure("ds", domain = mesh)


# Boundary sets
dofs_alpha_left = locate_dofs_geometrical(V_alpha, lambda x: np.isclose(x[0], 0.))
dofs_alpha_right = locate_dofs_geometrical(V_alpha, lambda x: np.isclose(x[0], Lx))
dofs_alpha_bottom = locate_dofs_geometrical(V_alpha, lambda x: np.isclose(x[1], 0.))
dofs_alpha_top = locate_dofs_geometrical(V_alpha, lambda x: np.isclose(x[1], Ly))


dofs_u_left = locate_dofs_geometrical(V_u, lambda x: np.isclose(x[0], 0.))
dofs_u_right = locate_dofs_geometrical(V_u, lambda x: np.isclose(x[0], Lx))
dofs_u_top = locate_dofs_geometrical(V_u, lambda x: np.isclose(x[1], Ly))
dofs_u_bottom = locate_dofs_geometrical(V_u, lambda x: np.isclose(x[1], 0))

# Boundary data
u_.interpolate(lambda x: (np.zeros_like(x[0]), np.ones_like(x[1])))

# Bounds (nontrivial)
alpha_lb.interpolate(lambda x: np.zeros_like(x[0]))
alpha_ub.interpolate(lambda x: np.ones_like(x[0]))

# Boundary conditions
bcs_u = [
         dirichletbc(np.array([0., 0.], dtype=PETSc.ScalarType),
                      dofs_u_bottom,
                      
                      V_u),
         dirichletbc(u_, dofs_u_top)
         
         ]

bcs_alpha = [
             dirichletbc(np.array(0., dtype = PETSc.ScalarType),
                         np.concatenate([dofs_alpha_bottom, dofs_alpha_top]),
                         V_alpha)
]

bcs = {"bcs_u": bcs_u, "bcs_alpha": bcs_alpha}

model = Brittle(parameters["model"])

total_energy = model.total_energy_density(state) * dx
solver = am.AlternateMinimisation(total_energy,
                         state,
                         bcs,
                         parameters.get("solvers"),
                         bounds=(alpha_lb, alpha_ub)
                         )

# %%
# %%time
# Loop for evolution
loads = np.linspace(parameters.get("loading").get("min"),
                    parameters.get("loading").get("max"),
                    parameters.get("loading").get("steps"))

data = {
    'elastic': [],
    'surface': [],
    'total': [],
    'load': []
}
xvfb.start_xvfb(wait=0.05)
pyvista.OFF_SCREEN = True
plotter = pyvista.Plotter(
        title="Displacement",
        window_size=[1600, 600],
        shape=(1, 2),
    )

for (i_t, t) in enumerate(loads):
  # update boundary conditions

  u_.interpolate(lambda x: ( np.zeros_like(x[0]), t*np.ones_like(x[1])))
  u_.vector.ghostUpdate(addv=PETSc.InsertMode.INSERT,
                        mode=PETSc.ScatterMode.FORWARD)

  # update lower bound for damage
  alpha.vector.copy(alpha_lb.vector)
  alpha.vector.ghostUpdate(addv=PETSc.InsertMode.INSERT,
                        mode=PETSc.ScatterMode.FORWARD)

  # solve for current load step
  print(f"Solving timestep {i_t}, load: {t}")

  solver.solve()

  # postprocessing
  # global

  surface_energy = assemble_scalar(dolfinx.fem.form(model.damage_dissipation_density(state) * dx))

  elastic_energy = assemble_scalar(
        dolfinx.fem.form(model.elastic_energy_density(state) * dx))
  
  data.get('elastic').append(elastic_energy)
  data.get('surface').append(surface_energy)
  data.get('total').append(surface_energy+elastic_energy)
  data.get('load').append(t)

  print(f"Solved timestep {i_t}, load: {t}")
  print(f"Elastic Energy {elastic_energy:.3g}, Surface energy: {surface_energy:.3g}")
  print("\n\n")

  _plt = plot_scalar(alpha, plotter, subplot=(0, 0))
  _plt.screenshot(f"large_ell.png")
  if generateStepwiseOutput:
    if(surface_energy>1 and i_t%25==0):
    #if(i_t>1050 and i_t<1100):
        _plt = plot_scalar(alpha, plotter, subplot=(0, 0))
        #_plt.screenshot(f"./plots/s30/alpha"+str(i_t)+".png")
        _plt.screenshot(f"large_ell.png")
    #if i_t>1100:
    #    break
  if(i_t>20 and  elastic_energy<1E-3 and elastic_energy<surface_energy):
      #Brute force approach to determine, whether we have already reached a crack propagation state
      print("fail")
      break

  # savings?
# Out:
# Solving timestep 0, load: 0.0
#   0 SNES Function norm 0.000000000000e+00
#   0 SNES Function norm 0.000000000000e+00
# Solved timestep 0, load: 0.0
# Elastic Energy 0, Surface energy: 0
#
#
#
# Solving timestep 1, load: 0.1111111111111111
#   0 SNES Function norm 6.518770918364e-01
#   1 SNES Function norm 5.666919245723e-01
#   2 SNES Function norm 3.963215900440e-01
#   3 SNES Function norm 5.558092098740e-02
#   4 SNES Function norm 2.133836176809e-16
#   0 SNES Function norm 0.000000000000e+00
# Solved timestep 1, load: 0.1111111111111111
# Elastic Energy 0.00352, Surface energy: 0
#
#
#
# Solving timestep 2, load: 0.2222222222222222
#   0 SNES Function norm 6.518770918364e-01
#   1 SNES Function norm 5.215016734691e-01
#   2 SNES Function norm 2.607508367346e-01
#   3 SNES Function norm 4.949952078665e-16
#   0 SNES Function norm 0.000000000000e+00
# Solved timestep 2, load: 0.2222222222222222
# Elastic Energy 0.0141, Surface energy: 0
#
#
#
# Solving timestep 3, load: 0.3333333333333333
#   0 SNES Function norm 6.518770918364e-01
#   1 SNES Function norm 3.911262551018e-01
#   2 SNES Function norm 8.053897918913e-16
#   0 SNES Function norm 0.000000000000e+00
# Solved timestep 3, load: 0.3333333333333333
# Elastic Energy 0.0316, Surface energy: 0
#
#
#
# Solving timestep 4, load: 0.4444444444444444
#   0 SNES Function norm 6.518770918364e-01
#   1 SNES Function norm 2.607508367346e-01
#   2 SNES Function norm 8.167481377428e-16
#   0 SNES Function norm 0.000000000000e+00
# Solved timestep 4, load: 0.4444444444444444
# Elastic Energy 0.0563, Surface energy: 0
#
#
#
# Solving timestep 5, load: 0.5555555555555556
#   0 SNES Function norm 6.518770918364e-01
#   1 SNES Function norm 1.303754183673e-01
#   2 SNES Function norm 1.031185752317e-15
#   0 SNES Function norm 6.694662094069e-04
#   1 SNES Function norm 1.103095790987e-19
#   0 SNES Function norm 4.505183446862e-04
#   1 SNES Function norm 9.509116251915e-16
#   0 SNES Function norm 1.525254291054e-05
#   1 SNES Function norm 6.428528079669e-20
#   0 SNES Function norm 1.027525901964e-05
#   1 SNES Function norm 9.505858757886e-16
#   0 SNES Function norm 3.483517804083e-07
# Solved timestep 5, load: 0.5555555555555556
# Elastic Energy 0.0879, Surface energy: 2.7e-05
#
#
#
# Solving timestep 6, load: 0.6666666666666666
#   0 SNES Function norm 6.518770918364e-01
#   1 SNES Function norm 1.595120389488e-15
#   0 SNES Function norm 1.518399638025e-03
#   1 SNES Function norm 1.912727264421e-05
#   2 SNES Function norm 3.030437198788e-19
#   0 SNES Function norm 2.454053382721e-03
#   1 SNES Function norm 1.332956504230e-15
#   0 SNES Function norm 1.899278917041e-04
#   1 SNES Function norm 4.610349833339e-19
#   0 SNES Function norm 3.502986551223e-04
#   1 SNES Function norm 1.294909928983e-15
#   0 SNES Function norm 2.794615758366e-05
#   1 SNES Function norm 6.076385539967e-19
#   0 SNES Function norm 5.170638237416e-05
#   1 SNES Function norm 1.269720538675e-15
#   0 SNES Function norm 4.142013576159e-06
# Solved timestep 6, load: 0.6666666666666666
# Elastic Energy 0.126, Surface energy: 0.00038
#
#
#
# Solving timestep 7, load: 0.7777777777777777
#   0 SNES Function norm 6.518770918364e-01
#   1 SNES Function norm 1.583125014708e-15
#   0 SNES Function norm 2.514158202854e-03
#   1 SNES Function norm 1.582130253945e-03
#   2 SNES Function norm 3.662656872164e-04
#   3 SNES Function norm 1.032113035051e-18
#   0 SNES Function norm 5.839973974901e-03
#   1 SNES Function norm 1.597341948195e-15
#   0 SNES Function norm 7.433587921080e-04
#   1 SNES Function norm 1.694545922540e-04
#   2 SNES Function norm 1.338093311290e-18
#   0 SNES Function norm 1.959847767705e-03
#   1 SNES Function norm 1.457317682258e-15
#   0 SNES Function norm 2.641841601420e-04
#   1 SNES Function norm 3.968117401499e-06
#   0 SNES Function norm 7.178937149598e-04
#   1 SNES Function norm 1.481351545310e-15
#   0 SNES Function norm 9.992190187961e-05
#   1 SNES Function norm 2.063363914342e-18
#   0 SNES Function norm 2.904369448325e-04
#   1 SNES Function norm 1.437754427488e-15
#   0 SNES Function norm 4.028365395009e-05
#   1 SNES Function norm 2.026346423392e-18
#   0 SNES Function norm 1.175791779846e-04
#   1 SNES Function norm 1.436527832209e-15
#   0 SNES Function norm 1.631267684120e-05
#   1 SNES Function norm 1.606753406444e-18
#   0 SNES Function norm 4.764049293681e-05
#   1 SNES Function norm 1.526313238806e-15
#   0 SNES Function norm 6.611127852506e-06
# Solved timestep 7, load: 0.7777777777777777
# Elastic Energy 0.169, Surface energy: 0.00262
#
#
#
# Solving timestep 8, load: 0.8888888888888888
#   0 SNES Function norm 6.518770918364e-01
#   1 SNES Function norm 1.675061634760e-15
#   0 SNES Function norm 3.740571112758e-03
#   1 SNES Function norm 2.318764268056e-03
#   2 SNES Function norm 4.768731440275e-04
#   3 SNES Function norm 6.038623370227e-05
#   4 SNES Function norm 3.336894546717e-18
#   0 SNES Function norm 1.113800645307e-02
#   1 SNES Function norm 1.525925401361e-15
#   0 SNES Function norm 2.441539325082e-03
#   1 SNES Function norm 6.039821753434e-04
#   2 SNES Function norm 1.043684612799e-04
#   3 SNES Function norm 2.939323446195e-18
#   0 SNES Function norm 8.283686055474e-03
#   1 SNES Function norm 1.470700192978e-15
#   0 SNES Function norm 1.966635976888e-03
#   1 SNES Function norm 7.148071570215e-04
#   2 SNES Function norm 1.367841236061e-04
#   3 SNES Function norm 5.289708480732e-18
#   0 SNES Function norm 7.865798997508e-03
#   1 SNES Function norm 1.513341709253e-15
#   0 SNES Function norm 2.065599738509e-03
#   1 SNES Function norm 3.086653134544e-04
#   2 SNES Function norm 6.457306771735e-18
#   0 SNES Function norm 8.431729891061e-03
#   1 SNES Function norm 1.441325976081e-15
#   0 SNES Function norm 2.415523739336e-03
#   1 SNES Function norm 3.722361275501e-04
#   2 SNES Function norm 1.224762487453e-05
#   3 SNES Function norm 7.455552245147e-18
#   0 SNES Function norm 9.563270569082e-03
#   1 SNES Function norm 1.360815339512e-15
#   0 SNES Function norm 3.003161758259e-03
#   1 SNES Function norm 2.852307156346e-04
#   2 SNES Function norm 9.889876602371e-18
#   0 SNES Function norm 1.133741222870e-02
#   1 SNES Function norm 1.453703651925e-15
#   0 SNES Function norm 3.926319075819e-03
#   1 SNES Function norm 1.998202584908e-04
#   2 SNES Function norm 9.843301620073e-18
#   0 SNES Function norm 1.381598832550e-02
#   1 SNES Function norm 1.292444890018e-15
#   0 SNES Function norm 5.377713111547e-03
#   1 SNES Function norm 4.726917789263e-04
#   2 SNES Function norm 1.229225583043e-17
#   0 SNES Function norm 1.704174385278e-02
#   1 SNES Function norm 1.464017267656e-15
#   0 SNES Function norm 7.703869833195e-03
#   1 SNES Function norm 2.288902878360e-04
#   2 SNES Function norm 1.440298848456e-17
#   0 SNES Function norm 2.106055680808e-02
#   1 SNES Function norm 1.339316382500e-15
#   0 SNES Function norm 1.147133650014e-02
#   1 SNES Function norm 3.546672446227e-04
#   2 SNES Function norm 2.083431504173e-17
#   0 SNES Function norm 2.519303453787e-02
#   1 SNES Function norm 1.234868438273e-15
#   0 SNES Function norm 1.741097103703e-02
#   1 SNES Function norm 2.136075968309e-04
#   2 SNES Function norm 2.205774603580e-17
#   0 SNES Function norm 2.760683283532e-02
#   1 SNES Function norm 1.264045158523e-15
#   0 SNES Function norm 2.546065342226e-02
#   1 SNES Function norm 2.386224737469e-04
#   2 SNES Function norm 2.642878230359e-17
#   0 SNES Function norm 2.549536997398e-02
#   1 SNES Function norm 1.356069056388e-15
#   0 SNES Function norm 3.130837562639e-02
#   1 SNES Function norm 5.020007325902e-04
#   2 SNES Function norm 3.254363354016e-17
#   0 SNES Function norm 1.760739433169e-02
#   1 SNES Function norm 1.391502868999e-15
#   0 SNES Function norm 2.365790639031e-02
#   1 SNES Function norm 9.281470853617e-06
#   0 SNES Function norm 7.558104921176e-03
#   1 SNES Function norm 1.432776211614e-15
#   0 SNES Function norm 1.046748590226e-02
#   1 SNES Function norm 2.436967938414e-04
#   2 SNES Function norm 6.811741749296e-17
#   0 SNES Function norm 5.221897093854e-03
#   1 SNES Function norm 1.224018592288e-15
#   0 SNES Function norm 8.040702225333e-03
#   1 SNES Function norm 3.432080274558e-06
#   0 SNES Function norm 8.401306223818e-03
#   1 SNES Function norm 1.333955570477e-15
#   0 SNES Function norm 1.025214707928e-02
#   1 SNES Function norm 1.538107872587e-03
#   2 SNES Function norm 8.044429897771e-17
#   0 SNES Function norm 9.947147995944e-03
#   1 SNES Function norm 1.294421993969e-15
#   0 SNES Function norm 8.320204995598e-03
#   1 SNES Function norm 3.626200785439e-04
#   2 SNES Function norm 4.813790218965e-17
#   0 SNES Function norm 4.540070917203e-03
#   1 SNES Function norm 1.360852321748e-15
#   0 SNES Function norm 3.182006351178e-03
#   1 SNES Function norm 4.498237356976e-17
#   0 SNES Function norm 1.167911135606e-03
#   1 SNES Function norm 1.333234633025e-15
#   0 SNES Function norm 1.346771826581e-03
#   1 SNES Function norm 6.213334707491e-17
#   0 SNES Function norm 5.444628960860e-04
#   1 SNES Function norm 1.344384387019e-15
#   0 SNES Function norm 1.074984967190e-03
#   1 SNES Function norm 5.741723707175e-17
#   0 SNES Function norm 4.363364006595e-04
#   1 SNES Function norm 1.330753891053e-15
#   0 SNES Function norm 8.883047254177e-04
#   1 SNES Function norm 5.218240348310e-17
#   0 SNES Function norm 3.329578004539e-04
#   1 SNES Function norm 1.350390593510e-15
#   0 SNES Function norm 6.606155577022e-04
#   1 SNES Function norm 5.129091648132e-17
#   0 SNES Function norm 2.290887586412e-04
#   1 SNES Function norm 1.357417961582e-15
#   0 SNES Function norm 4.455311740303e-04
#   1 SNES Function norm 7.326488998571e-17
#   0 SNES Function norm 1.453485380011e-04
#   1 SNES Function norm 1.229212878265e-15
#   0 SNES Function norm 2.792117103957e-04
#   1 SNES Function norm 4.884367771153e-17
#   0 SNES Function norm 8.729584634294e-05
#   1 SNES Function norm 1.262387278278e-15
#   0 SNES Function norm 1.665334152146e-04
#   1 SNES Function norm 7.605005543897e-17
#   0 SNES Function norm 5.066379660998e-05
#   1 SNES Function norm 1.379888553003e-15
#   0 SNES Function norm 9.629014446128e-05
#   1 SNES Function norm 6.080319835355e-17
#   0 SNES Function norm 2.881088335102e-05
#   1 SNES Function norm 1.250966558552e-15
#   0 SNES Function norm 5.464904124618e-05
#   1 SNES Function norm 4.420543651822e-17
#   0 SNES Function norm 1.619236750323e-05
#   1 SNES Function norm 1.345158923291e-15
#   0 SNES Function norm 3.068205905440e-05
#   1 SNES Function norm 6.341189976499e-17
#   0 SNES Function norm 9.040006483232e-06
#   1 SNES Function norm 1.281379884952e-15
#   0 SNES Function norm 1.712001521258e-05
#   1 SNES Function norm 5.895550864342e-17
#   0 SNES Function norm 5.028073545521e-06
#   1 SNES Function norm 1.190886408807e-15
#   0 SNES Function norm 9.519410705531e-06
# Solved timestep 8, load: 0.8888888888888888
# Elastic Energy 0.00672, Surface energy: 0.156
#
#
#
# Solving timestep 9, load: 1.0
#   0 SNES Function norm 6.518770918364e-01
#   1 SNES Function norm 1.549255156720e-15
#   0 SNES Function norm 1.184775007182e-02
#   1 SNES Function norm 6.940351507750e-17
#   0 SNES Function norm 1.936715370312e-03
#   1 SNES Function norm 1.417983179638e-15
#   0 SNES Function norm 2.561043558324e-03
#   1 SNES Function norm 6.351488699903e-17
#   0 SNES Function norm 4.219875165731e-04
#   1 SNES Function norm 1.383773967146e-15
#   0 SNES Function norm 6.788293187998e-04
#   1 SNES Function norm 8.009294982056e-17
#   0 SNES Function norm 1.227872137169e-04
#   1 SNES Function norm 1.270583682796e-15
#   0 SNES Function norm 2.302280147475e-04
#   1 SNES Function norm 9.950813353827e-17
#   0 SNES Function norm 4.400048329372e-05
#   1 SNES Function norm 1.314997173560e-15
#   0 SNES Function norm 8.626793755080e-05
#   1 SNES Function norm 1.034202167218e-16
#   0 SNES Function norm 1.673002672617e-05
#   1 SNES Function norm 1.434012693927e-15
#   0 SNES Function norm 3.307595454328e-05
#   1 SNES Function norm 7.891187592198e-17
#   0 SNES Function norm 6.435516134912e-06
#   1 SNES Function norm 1.353686966575e-15
#   0 SNES Function norm 1.273205217392e-05
#   1 SNES Function norm 9.518617243045e-17
#   0 SNES Function norm 2.479653774694e-06
#   1 SNES Function norm 1.384374340557e-15
#   0 SNES Function norm 4.903399254769e-06
# Solved timestep 9, load: 1.0
# Elastic Energy 0.00538, Surface energy: 0.159
#
#
#
# CPU times: user 1min 31s, sys: 1min 8s, total: 2min 39s
# Wall time: 2min 51s

# %%
plt.figure()
plt.plot(data.get('load'), data.get('surface'), label='surface')
plt.plot(data.get('load'), data.get('elastic'), label='elastic')
# plt.plot(data.get('load'), [1./2. * t**2*Lx for t in data.get('load')], label='anal elast', ls=':', c='k')

plt.title('Traction bar energetics')
plt.legend()
# plt.yticks([0, 1/20], [0, '$1/2.\sigma_c^2/E_0$'])
plt.xticks([parameters.get('loading').get("min"), parameters.get('loading').get("max")], [0, parameters.get('loading').get("max")])
plt.savefig("energetics.png")
