# %% [markdown]
# <a href="https://colab.research.google.com/github/kumiori/mec647/blob/Assala_T/Angle30%C2%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
import sys

try:
    import google.colab  # noqa: F401
except ImportError:
    import ufl  # noqa: F401
    import dolfinx  # noqa: F401
else:
    try:
        import ufl
        import dolfinx
    except ImportError:
        # !wget "https://fem-on-colab.github.io/releases/fenicsx-install.sh" -O "/tmp/fenicsx-install.sh" && bash "/tmp/fenicsx-install.sh";
        import ufl  # noqa: F401
        import dolfinx  # noqa: F401

try:
    import pyvista
except ImportError:
    # !{sys.executable} -m pip install --upgrade pyvista itkwidgets;
    import pyvista  # noqa: F401
    from pyvista.utilities import xvfb

try:
    import gmsh
except ImportError:
    # !{sys.executable} -m pip install gmsh
    import gmsh

# !sudo apt install libgl1-mesa-glx xvfb;
# !{sys.executable} -m pip install pythreejs;
# !{sys.executable} -m pip install ipygany;
# !{sys.executable} -m pip install --upgrade PyYAML
# !pip install --ignore-installed PyYAML

# %%
branch_name = 'main'
# branch_name = 'Assala_T'

# !rm -rf mec647
try:
  # !git clone -b {branch_name} https://github.com/kumiori/mec647.git
  sys.path.append('mec647/')

  print()
  print(f'Cloned brach: {branch_name}')
  print(f'Last commit message')
  # !cd mec647/ && git log -n 1 && cd ..
  import mec647
  from mec647 import meshes
  from mec647.meshes import primitives
  # from mec647.algorithms import am
  from mec647.utils.viz import plot_mesh, plot_scalar, plot_vector

except Exception as e:
  print('Something went wrong', e)
  # !rm -rf mec647
  # !git clone https://github.com/kumiori/mec647.git
# Out:
# Cloning into 'mec647'...
# remote: Enumerating objects: 1220, done.
# remote: Counting objects: 100% (1220/1220), done.
# remote: Compressing objects: 100% (906/906), done.
# remote: Total 1220 (delta 621), reused 614 (delta 274), pack-reused 0
# Receiving objects: 100% (1220/1220), 19.29 MiB | 11.98 MiB/s, done.
# Resolving deltas: 100% (621/621), done.
#
# Cloned brach: main
# Last commit message
# commit 25aa48ad32b5c11d7dd6e087bdf09fea88442b28 (HEAD -> main, origin/main, origin/HEAD)
# Merge: 822d5b0 222efb0
# Author: igorassist <igorassist98@gmail.com>
# Date:   Sat Feb 26 14:14:34 2022 +0100
#
#     Merge branch 'main' of https://github.com/kumiori/mec647

# %%
import matplotlib.pyplot as plt
from petsc4py import PETSc
import numpy as np
from mpi4py import MPI

comm = MPI.COMM_WORLD

from dolfinx.fem import (
    Constant,
    Function,
    FunctionSpace,
    assemble_scalar,
    dirichletbc,
    form,
    locate_dofs_geometrical,
    set_bc,
)

# meshes
import meshes
from meshes import primitives

import models
from models import DamageElasticityModel as Brittle

# %%
import numpy as np
import yaml
import json
import sys
import os
from pathlib import Path

from mpi4py import MPI

import petsc4py
from petsc4py import PETSc

import dolfinx
import dolfinx.plot
from dolfinx import log
import ufl

import algorithms
from algorithms import am

from dolfinx.io import XDMFFile

import logging

logging.basicConfig(level=logging.INFO)

import dolfinx
import dolfinx.plot
import dolfinx.io
from dolfinx.fem import (
    Constant,
    Function,
    FunctionSpace,
    assemble_scalar,
    dirichletbc,
    form,
    locate_dofs_geometrical,
    set_bc,
)
import matplotlib.pyplot as plt
import pyvista 
from pyvista.utilities import xvfb


# visualisation
from utils import viz
import matplotlib.pyplot as plt
from utils.viz import plot_mesh, plot_vector, plot_scalar
generateStepwiseOutput=True

# %%
# Parameters
parameters = {
    'loading': {
        'min': 0.0,
        'max': 1.,
        'steps': 10
    },
    'geometry': {
        'geom_type': 'Plate with Kink',
        'Lx': .6,
        'Ly': 1, 
        'L0': 0.3,
        'theta': 30,
        'eta': 1e-2,
    },
    'model': {
        'E': 3.e+9,
        'nu': 0.4,
        'w1': 1.,
        'ell': 0.1, 
        'k_res': 1.e-8
    },
    'solvers': {
          'elasticity': {        
            'snes': {
                'snes_type': 'newtontr',
                'snes_stol': 1e-8,
                'snes_atol': 1e-8,
                'snes_rtol': 1e-8,
                'snes_max_it': 250,
                'snes_monitor': "",
                'ksp_type': 'preonly',
                'pc_type': 'lu',
                'pc_factor_mat_solver_type': 'mumps'
            }
        },
          'damage': {        
            'snes': {
                'snes_type': 'vinewtonrsls',
                'snes_stol': 1e-5,
                'snes_atol': 1e-5,
                'snes_rtol': 1e-8,
                'snes_max_it': 100,
                'snes_monitor': "",
                'ksp_type': 'preonly',
                'pc_type': 'lu',
                'pc_factor_mat_solver_type': 'mumps'
            },
        },
          'damage_elasticity': {
            "max_it": 2000,
            "alpha_rtol": 1.0e-4,
            "criterion": "alpha_H1"
          }
    }
}

# %%
def  mesh_kink(name,
                Lx,
                Ly,
                # a,
                # b,
               rad,
               theta,
              # theta
                eta,
                lc,
                tdim,
                order=1,
                msh_file=None,
                comm=MPI.COMM_WORLD):
    """
    Create mesh of 3d tensile test specimen according to ISO 6892-1:2019 using the Python API of Gmsh.
    """
    # Perform Gmsh work only on rank = 0

    if comm.rank == 0:

        import gmsh

        # Initialise gmsh and set options
        gmsh.initialize()
        gmsh.option.setNumber("General.Terminal", 1)

        gmsh.option.setNumber("Mesh.Algorithm", 6)
        model = gmsh.model()
        model.add("Rectangle")
        model.setCurrent("Rectangle")
        # points = [p1, p2, p3, p4, p5, p6, p7, p8,p9,p10,p11]
        p1 = model.geo.addPoint(0.0, 0.0, 0, lc, tag=1)
        p2 = model.geo.addPoint(Lx, 0.0, 0, lc, tag=2)
        p3 = model.geo.addPoint(Lx, Ly, 0.0, lc, tag=3)
        p4 = model.geo.addPoint(0, Ly, 0, lc, tag=4)

        p5 = model.geo.addPoint(Lx/2 + rad*np.cos(theta), Ly/2 + rad*np.sin(theta), 0.0, lc/3, tag=5)
        p7 = model.geo.addPoint(Lx/2 - rad*np.cos(theta), Ly/2 - rad*np.sin(theta), 0.0, lc/3, tag=7)

        # p5 = model.geo.addPoint(Lx/2 +a, Ly/2 +b,0.0, lc/1.5, tag=5)
        p6 = model.geo.addPoint(Lx/2, Ly/2 + eta,0, lc, tag=6)
        # p7 = model.geo.addPoint(Lx/2-a,Ly/2-b,0,lc/1.5, tag=7)
        p8 = model.geo.addPoint(Lx/2,Ly/2 - eta,0, lc, tag=8)

        # Lines = [L1, L2, L3, L4, L5, L6, L7, L8]
        L1 = model.geo.addLine(p1, p2, tag=1)
        L2 = model.geo.addLine(p2, p3, tag=2)
        L3 = model.geo.addLine(p3, p4, tag=3)
        L4 = model.geo.addLine(p4, p1, tag=4)
        L5 = model.geo.addLine(p5, p6, tag=5)
        L6 = model.geo.addLine(p6, p7, tag=6)
        L7 = model.geo.addLine(p7, p8, tag=7)
        L8 = model.geo.addLine(p8, p5, tag=8)


        
        cloop1 = model.geo.addCurveLoop([L1, L2, L3, L4])
        cloop2 = model.geo.addCurveLoop([L5, L6, L7, L8])
        
        # surface_1 =
        model.geo.addPlaneSurface([cloop1, cloop2])

        model.geo.synchronize()
        surface_entities = [model[1] for model in model.getEntities(tdim)]

        model.addPhysicalGroup(tdim, surface_entities, tag=1)
        model.setPhysicalName(tdim, 1, "Rectangle surface")

        # Set mesh size via points
        # gmsh.model.mesh.setSize(points, lc)  # heuristic

        # gmsh.model.mesh.optimize("Netgen")

        # Set geometric order of mesh cells
        gmsh.model.mesh.setOrder(order)

        # Define physical groups for subdomains (! target tag > 0)
        # domain = 1
        # gmsh.model.addPhysicalGroup(tdim, [v[1] for v in volumes], domain)
        # gmsh.model.setPhysicalName(tdim, domain, 'domain')
              

        gmsh.model.addPhysicalGroup(tdim - 1, [1], tag=9)
        gmsh.model.setPhysicalName(tdim - 1, 9, "Bottom  of the Plate")
        gmsh.model.addPhysicalGroup(tdim - 1, [4], tag=10)
        gmsh.model.setPhysicalName(tdim - 1, 10, "Top  of the Plate")
        gmsh.model.addPhysicalGroup(tdim - 1, [5], tag=11)
        gmsh.model.setPhysicalName(tdim - 1, 11, "1/2 Top of the TipCrack")
        gmsh.model.addPhysicalGroup(tdim - 1, [6], tag=12)
        gmsh.model.setPhysicalName(tdim - 1, 12, "1/2 Top of the TipCrack")
        gmsh.model.addPhysicalGroup(tdim - 1, [7], tag=13)
        gmsh.model.setPhysicalName(tdim - 1, 13, "1/2 bottom of the TipCrack")
        gmsh.model.addPhysicalGroup(tdim - 1, [8], tag=14)
        gmsh.model.setPhysicalName(tdim - 1, 14, "1/2 bottom of the TipCrack")

        model.mesh.generate(tdim)


        #Generating the mesh
    model.geo.synchronize()
    model.mesh.generate(tdim)

    return gmsh.model

# %%
Lx = parameters.get("geometry").get("Lx")
Ly = parameters.get("geometry").get("Ly")
L0 = parameters.get("geometry").get("L0")
eta = parameters.get("geometry").get("eta")

geom_type = parameters.get("geometry").get("geom_type")

lc=0.05
theta = 30/180 * np.pi

gmsh_model=mesh_kink('mesh', Lx, Ly, L0/2, theta, eta,lc, 2, 1)

mesh, mts = meshes.gmsh_model_to_mesh(gmsh_model,
                               cell_data=False,
                               facet_data=True,
                               gdim=2)


plt.figure()
ax = plot_mesh(mesh)
fig = ax.get_figure()
fig.savefig(f"mesh.png")

# %%
# usedMesh=mesh 
# Enables opportunity to improve mesh at specific places, might lead to deformed elements
# Functional Setting

element_u = ufl.VectorElement("Lagrange", mesh.ufl_cell(),
                              degree=1, dim=2)

element_alpha = ufl.FiniteElement("Lagrange", mesh.ufl_cell(),
                              degree=1)

V_u = dolfinx.fem.FunctionSpace(mesh, element_u) 
V_alpha = dolfinx.fem.FunctionSpace(mesh, element_alpha) 

u = dolfinx.fem.Function(V_u, name="Displacement")
u_ = dolfinx.fem.Function(V_u, name="BoundaryDisplacement")


alpha = dolfinx.fem.Function(V_alpha, name="Damage")

# Pack state
state = {"u": u, "alpha": alpha}

# Bounds
alpha_ub = dolfinx.fem.Function(V_alpha, name="UpperBoundDamage")
alpha_lb = dolfinx.fem.Function(V_alpha, name="LowerBoundDamage")



dx = ufl.Measure("dx", domain = mesh)
ds = ufl.Measure("ds", domain = mesh)


# Boundary sets
dofs_alpha_left = locate_dofs_geometrical(V_alpha, lambda x: np.isclose(x[0], 0.))
dofs_alpha_right = locate_dofs_geometrical(V_alpha, lambda x: np.isclose(x[0], Lx))
dofs_alpha_bottom = locate_dofs_geometrical(V_alpha, lambda x: np.isclose(x[1], 0.))
dofs_alpha_top = locate_dofs_geometrical(V_alpha, lambda x: np.isclose(x[1], Ly))


dofs_u_left = locate_dofs_geometrical(V_u, lambda x: np.isclose(x[0], 0.))
dofs_u_right = locate_dofs_geometrical(V_u, lambda x: np.isclose(x[0], Lx))
dofs_u_top = locate_dofs_geometrical(V_u, lambda x: np.isclose(x[1], Ly))
dofs_u_bottom = locate_dofs_geometrical(V_u, lambda x: np.isclose(x[1], 0))

# Boundary data
u_.interpolate(lambda x: (np.zeros_like(x[0]), np.ones_like(x[1])))

# Bounds (nontrivial)
alpha_lb.interpolate(lambda x: np.zeros_like(x[0]))
alpha_ub.interpolate(lambda x: np.ones_like(x[0]))

# Boundary conditions
bcs_u = [
         dirichletbc(np.array([0., 0.], dtype=PETSc.ScalarType),
                      dofs_u_bottom,
                      V_u),
         dirichletbc(u_, dofs_u_top)
         ]

bcs_alpha = [
             dirichletbc(np.array(0., dtype = PETSc.ScalarType),
                         np.concatenate([dofs_alpha_bottom, dofs_alpha_top]),
                         V_alpha)
]

bcs = {"bcs_u": bcs_u, "bcs_alpha": bcs_alpha}

model = Brittle(parameters["model"])

total_energy = model.total_energy_density(state) * dx
solver = am.AlternateMinimisation(total_energy,
                         state,
                         bcs,
                         parameters.get("solvers"),
                         bounds=(alpha_lb, alpha_ub)
                         )

# %%
# %%time
# Loop for evolution
loads = np.linspace(parameters.get("loading").get("min"),
                    parameters.get("loading").get("max"),
                    parameters.get("loading").get("steps"))

data = {
    'elastic': [],
    'surface': [],
    'total': [],
    'load': []
}
xvfb.start_xvfb(wait=0.05)
pyvista.OFF_SCREEN = True
plotter = pyvista.Plotter(
        title="Displacement",
        window_size=[1600, 600],
        shape=(1, 2),
    )

for (i_t, t) in enumerate(loads):
  # update boundary conditions

  u_.interpolate(lambda x: ( np.zeros_like(x[0]), t*np.ones_like(x[1])))
  u_.vector.ghostUpdate(addv=PETSc.InsertMode.INSERT,
                        mode=PETSc.ScatterMode.FORWARD)

  # update lower bound for damage
  alpha.vector.copy(alpha_lb.vector)
  alpha.vector.ghostUpdate(addv=PETSc.InsertMode.INSERT,
                        mode=PETSc.ScatterMode.FORWARD)

  # solve for current load step
  print(f"Solving timestep {i_t}, load: {t}")

  solver.solve()

  # postprocessing
  # global

  surface_energy = assemble_scalar(dolfinx.fem.form(model.damage_dissipation_density(state) * dx))

  elastic_energy = assemble_scalar(
        dolfinx.fem.form(model.elastic_energy_density(state) * dx))
  
  data.get('elastic').append(elastic_energy)
  data.get('surface').append(surface_energy)
  data.get('total').append(surface_energy+elastic_energy)
  data.get('load').append(t)

  print(f"Solved timestep {i_t}, load: {t}")
  print(f"Elastic Energy {elastic_energy:.3g}, Surface energy: {surface_energy:.3g}")
  print("\n\n")

  _plt = plot_scalar(alpha, plotter, subplot=(0, 0))
  _plt.screenshot(f"large_ell.png")
  if generateStepwiseOutput:
    if(surface_energy>1 and i_t%25==0):
    #if(i_t>1050 and i_t<1100):
        _plt = plot_scalar(alpha, plotter, subplot=(0, 0))
        #_plt.screenshot(f"./plots/s30/alpha"+str(i_t)+".png")
        _plt.screenshot(f"large_ell.png")
    #if i_t>1100:
    #    break
  if(i_t>20 and  elastic_energy<1E-3 and elastic_energy<surface_energy):
      #Brute force approach to determine, whether we have already reached a crack propagation state
      print("fail")
      break

  # savings?
# Out:
# Solving timestep 0, load: 0.0
#   0 SNES Function norm 0.000000000000e+00
#   0 SNES Function norm 0.000000000000e+00
# Solved timestep 0, load: 0.0
# Elastic Energy 0, Surface energy: 0
#
#
#
# Solving timestep 1, load: 0.1111111111111111
#   0 SNES Function norm 6.106611469267e-01
#   1 SNES Function norm 5.286106951788e-01
#   2 SNES Function norm 3.645097916831e-01
#   3 SNES Function norm 3.630798469155e-02
#   4 SNES Function norm 1.958810149008e-16
#   0 SNES Function norm 0.000000000000e+00
# Solved timestep 1, load: 0.1111111111111111
# Elastic Energy 0.00314, Surface energy: 0
#
#
#
# Solving timestep 2, load: 0.2222222222222222
#   0 SNES Function norm 6.106611469267e-01
#   1 SNES Function norm 4.885289175414e-01
#   2 SNES Function norm 2.442644587707e-01
#   3 SNES Function norm 4.605350362499e-16
#   0 SNES Function norm 0.000000000000e+00
# Solved timestep 2, load: 0.2222222222222222
# Elastic Energy 0.0125, Surface energy: 0
#
#
#
# Solving timestep 3, load: 0.3333333333333333
#   0 SNES Function norm 6.106611469267e-01
#   1 SNES Function norm 3.663966881560e-01
#   2 SNES Function norm 7.742082566322e-16
#   0 SNES Function norm 7.810587345218e-06
# Solved timestep 3, load: 0.3333333333333333
# Elastic Energy 0.0282, Surface energy: 0
#
#
#
# Solving timestep 4, load: 0.4444444444444444
#   0 SNES Function norm 6.106611469267e-01
#   1 SNES Function norm 2.442644587707e-01
#   2 SNES Function norm 7.980567850558e-16
#   0 SNES Function norm 3.719272478959e-04
#   1 SNES Function norm 8.607453386650e-05
#   2 SNES Function norm 3.677343916130e-07
#   0 SNES Function norm 2.150489499976e-04
#   1 SNES Function norm 6.596563066649e-16
#   0 SNES Function norm 6.054677225146e-06
# Solved timestep 4, load: 0.4444444444444444
# Elastic Energy 0.0502, Surface energy: 7.27e-06
#
#
#
# Solving timestep 5, load: 0.5555555555555556
#   0 SNES Function norm 6.106611469267e-01
#   1 SNES Function norm 1.221322293853e-01
#   2 SNES Function norm 9.093260870081e-16
#   0 SNES Function norm 6.535807497075e-04
#   1 SNES Function norm 3.841410314583e-04
#   2 SNES Function norm 2.590536408110e-19
#   0 SNES Function norm 7.450940103512e-04
#   1 SNES Function norm 9.249836448704e-16
#   0 SNES Function norm 3.667504295648e-05
#   1 SNES Function norm 7.952247965214e-07
#   0 SNES Function norm 5.368538065571e-05
#   1 SNES Function norm 8.709053140553e-16
#   0 SNES Function norm 2.747880201200e-06
# Solved timestep 5, load: 0.5555555555555556
# Elastic Energy 0.0783, Surface energy: 7e-05
#
#
#
# Solving timestep 6, load: 0.6666666666666666
#   0 SNES Function norm 6.106611469267e-01
#   1 SNES Function norm 1.641687198372e-15
#   0 SNES Function norm 9.858320723621e-04
#   1 SNES Function norm 5.713590621009e-04
#   2 SNES Function norm 4.386341852645e-05
#   3 SNES Function norm 7.483400667955e-19
#   0 SNES Function norm 1.902592754737e-03
#   1 SNES Function norm 1.222940144035e-15
#   0 SNES Function norm 1.424980780547e-04
#   1 SNES Function norm 7.910797992934e-19
#   0 SNES Function norm 3.158692743558e-04
#   1 SNES Function norm 1.227082090344e-15
#   0 SNES Function norm 2.381933524609e-05
#   1 SNES Function norm 7.593124796694e-19
#   0 SNES Function norm 5.373914634844e-05
#   1 SNES Function norm 1.247662849864e-15
#   0 SNES Function norm 4.017248268825e-06
# Solved timestep 6, load: 0.6666666666666666
# Elastic Energy 0.112, Surface energy: 0.000419
#
#
#
# Solving timestep 7, load: 0.7777777777777777
#   0 SNES Function norm 6.106611469267e-01
#   1 SNES Function norm 1.505184410102e-15
#   0 SNES Function norm 1.529902558158e-03
#   1 SNES Function norm 1.310158854435e-03
#   2 SNES Function norm 2.505164317001e-04
#   3 SNES Function norm 7.346443821060e-06
#   0 SNES Function norm 4.159856144363e-03
#   1 SNES Function norm 1.470638888973e-15
#   0 SNES Function norm 4.739993422714e-04
#   1 SNES Function norm 1.566450549889e-04
#   2 SNES Function norm 2.109250144735e-18
#   0 SNES Function norm 1.536296853644e-03
#   1 SNES Function norm 1.390400602467e-15
#   0 SNES Function norm 1.843256147860e-04
#   1 SNES Function norm 1.134774679612e-05
#   2 SNES Function norm 2.045152237002e-18
#   0 SNES Function norm 6.098758337711e-04
#   1 SNES Function norm 1.416396577761e-15
#   0 SNES Function norm 7.443895508538e-05
#   1 SNES Function norm 1.957856514201e-18
#   0 SNES Function norm 2.481893484427e-04
#   1 SNES Function norm 1.348543596527e-15
#   0 SNES Function norm 3.045142940599e-05
#   1 SNES Function norm 1.943612660893e-18
#   0 SNES Function norm 1.018964733740e-04
#   1 SNES Function norm 1.330361616279e-15
#   0 SNES Function norm 1.249967435308e-05
#   1 SNES Function norm 2.063466835735e-18
#   0 SNES Function norm 4.190305361993e-05
#   1 SNES Function norm 1.421108075593e-15
#   0 SNES Function norm 5.136696853608e-06
# Solved timestep 7, load: 0.7777777777777777
# Elastic Energy 0.151, Surface energy: 0.00249
#
#
#
# Solving timestep 8, load: 0.8888888888888888
#   0 SNES Function norm 6.106611469267e-01
#   1 SNES Function norm 1.591411160651e-15
#   0 SNES Function norm 2.420275679302e-03
#   1 SNES Function norm 2.179926606985e-03
#   2 SNES Function norm 9.054288241561e-04
#   3 SNES Function norm 1.970248450363e-04
#   4 SNES Function norm 4.227497420449e-18
#   0 SNES Function norm 9.324980004343e-03
#   1 SNES Function norm 1.471559742954e-15
#   0 SNES Function norm 1.842904910476e-03
#   1 SNES Function norm 8.327550804908e-04
#   2 SNES Function norm 4.040852670921e-05
#   3 SNES Function norm 6.307567666238e-18
#   0 SNES Function norm 8.789840967281e-03
#   1 SNES Function norm 1.427185410350e-15
#   0 SNES Function norm 1.965379250628e-03
#   1 SNES Function norm 1.934250101993e-04
#   2 SNES Function norm 8.797644983262e-18
#   0 SNES Function norm 9.203518184646e-03
#   1 SNES Function norm 1.491746913238e-15
#   0 SNES Function norm 2.303154659590e-03
#   1 SNES Function norm 3.820258303072e-04
#   2 SNES Function norm 6.225430815634e-07
#   0 SNES Function norm 1.024790319083e-02
#   1 SNES Function norm 1.407595702213e-15
#   0 SNES Function norm 2.925286772680e-03
#   1 SNES Function norm 3.366158411938e-04
#   2 SNES Function norm 1.277660547170e-17
#   0 SNES Function norm 1.207975353944e-02
#   1 SNES Function norm 1.429153202982e-15
#   0 SNES Function norm 4.018120985678e-03
#   1 SNES Function norm 1.485368881044e-04
#   2 SNES Function norm 1.477360862513e-17
#   0 SNES Function norm 1.481283616524e-02
#   1 SNES Function norm 1.367165088821e-15
#   0 SNES Function norm 5.944857725414e-03
#   1 SNES Function norm 5.339919200284e-04
#   2 SNES Function norm 2.035560282118e-17
#   0 SNES Function norm 1.842208229887e-02
#   1 SNES Function norm 1.205881823559e-15
#   0 SNES Function norm 9.459391236681e-03
#   1 SNES Function norm 2.285196945841e-04
#   2 SNES Function norm 2.278885448871e-17
#   0 SNES Function norm 2.231157522116e-02
#   1 SNES Function norm 1.272855169828e-15
#   0 SNES Function norm 1.581203745744e-02
#   1 SNES Function norm 1.837312472694e-04
#   2 SNES Function norm 2.758641953540e-17
#   0 SNES Function norm 2.440948042324e-02
#   1 SNES Function norm 1.317609175364e-15
#   0 SNES Function norm 2.518808458154e-02
#   1 SNES Function norm 3.299330139336e-04
#   2 SNES Function norm 2.879712951077e-17
#   0 SNES Function norm 2.121225764194e-02
#   1 SNES Function norm 1.106667743480e-15
#   0 SNES Function norm 3.043371779955e-02
#   1 SNES Function norm 2.305295693175e-04
#   2 SNES Function norm 5.005314693657e-17
#   0 SNES Function norm 1.215121423793e-02
#   1 SNES Function norm 1.232373165547e-15
#   0 SNES Function norm 2.172103681084e-02
#   1 SNES Function norm 1.698101883384e-04
#   2 SNES Function norm 7.005227152762e-17
#   0 SNES Function norm 4.889755347456e-03
#   1 SNES Function norm 1.193871557993e-15
#   0 SNES Function norm 8.839662405450e-03
#   1 SNES Function norm 7.366325396195e-05
#   2 SNES Function norm 4.138488076226e-17
#   0 SNES Function norm 2.152248194137e-03
#   1 SNES Function norm 1.184051662401e-15
#   0 SNES Function norm 3.443055036311e-03
#   1 SNES Function norm 1.441960759467e-04
#   2 SNES Function norm 7.608849213235e-17
#   0 SNES Function norm 9.127485851594e-04
#   1 SNES Function norm 1.115138625164e-15
#   0 SNES Function norm 1.342345196457e-03
#   1 SNES Function norm 7.752671720031e-17
#   0 SNES Function norm 4.270489922232e-04
#   1 SNES Function norm 1.239000641176e-15
#   0 SNES Function norm 6.442278204327e-04
#   1 SNES Function norm 6.271085028182e-17
#   0 SNES Function norm 2.403017359051e-04
#   1 SNES Function norm 1.202079344925e-15
#   0 SNES Function norm 3.784361864254e-04
#   1 SNES Function norm 6.377031054721e-17
#   0 SNES Function norm 1.469136059098e-04
#   1 SNES Function norm 1.157326697716e-15
#   0 SNES Function norm 2.416185339922e-04
#   1 SNES Function norm 5.297707350982e-17
#   0 SNES Function norm 9.300509876533e-05
#   1 SNES Function norm 1.199812161824e-15
#   0 SNES Function norm 1.582616105163e-04
#   1 SNES Function norm 4.623700517352e-17
#   0 SNES Function norm 6.000357366836e-05
#   1 SNES Function norm 1.069160428265e-15
#   0 SNES Function norm 1.045009335625e-04
#   1 SNES Function norm 5.453580121059e-17
#   0 SNES Function norm 3.915837399977e-05
#   1 SNES Function norm 1.176420766182e-15
#   0 SNES Function norm 6.921419387211e-05
#   1 SNES Function norm 5.845651459180e-17
#   0 SNES Function norm 2.574061698958e-05
#   1 SNES Function norm 1.155156364540e-15
#   0 SNES Function norm 4.592021771590e-05
#   1 SNES Function norm 6.787716423749e-17
#   0 SNES Function norm 1.700082212873e-05
#   1 SNES Function norm 1.277446640398e-15
#   0 SNES Function norm 3.050417005510e-05
#   1 SNES Function norm 5.404940554011e-17
#   0 SNES Function norm 1.126405712667e-05
#   1 SNES Function norm 1.116049993104e-15
#   0 SNES Function norm 2.028417636608e-05
#   1 SNES Function norm 7.152831410433e-17
#   0 SNES Function norm 7.479064314256e-06
#   1 SNES Function norm 1.209515163434e-15
#   0 SNES Function norm 1.349919678380e-05
#   1 SNES Function norm 7.538977960242e-17
#   0 SNES Function norm 4.973106791789e-06
#   1 SNES Function norm 1.249433831151e-15
#   0 SNES Function norm 8.989348779056e-06
# Solved timestep 8, load: 0.8888888888888888
# Elastic Energy 0.00497, Surface energy: 0.131
#
#
#
# Solving timestep 9, load: 1.0
#   0 SNES Function norm 6.106611469267e-01
#   1 SNES Function norm 1.334446263663e-15
#   0 SNES Function norm 8.712695860474e-03
#   1 SNES Function norm 1.059511024115e-04
#   2 SNES Function norm 5.009658116362e-17
#   0 SNES Function norm 1.116867538739e-03
#   1 SNES Function norm 1.131876127054e-15
#   0 SNES Function norm 1.858543873220e-03
#   1 SNES Function norm 7.958799690885e-17
#   0 SNES Function norm 2.724901188841e-04
#   1 SNES Function norm 1.239083622478e-15
#   0 SNES Function norm 5.350732580177e-04
#   1 SNES Function norm 6.186027378761e-17
#   0 SNES Function norm 9.463646880611e-05
#   1 SNES Function norm 1.303621199304e-15
#   0 SNES Function norm 2.060678424927e-04
#   1 SNES Function norm 7.885552337752e-17
#   0 SNES Function norm 4.318803670624e-05
#   1 SNES Function norm 1.265941065468e-15
#   0 SNES Function norm 9.548735501182e-05
#   1 SNES Function norm 6.769220938975e-17
#   0 SNES Function norm 2.216549577778e-05
#   1 SNES Function norm 1.270690322323e-15
#   0 SNES Function norm 4.811710807235e-05
#   1 SNES Function norm 7.372092695743e-17
#   0 SNES Function norm 1.182816200034e-05
#   1 SNES Function norm 1.164828398653e-15
#   0 SNES Function norm 2.517512067471e-05
#   1 SNES Function norm 1.144777219783e-16
#   0 SNES Function norm 6.396359385632e-06
#   1 SNES Function norm 1.231264347343e-15
#   0 SNES Function norm 1.341826361957e-05
#   1 SNES Function norm 7.463218247864e-17
#   0 SNES Function norm 3.476186906570e-06
#   1 SNES Function norm 1.254421064599e-15
#   0 SNES Function norm 7.222919569680e-06
# Solved timestep 9, load: 1.0
# Elastic Energy 0.00418, Surface energy: 0.132
#
#
#
# CPU times: user 1min 23s, sys: 1min 7s, total: 2min 30s
# Wall time: 2min 47s

# %%
plt.figure()
plt.plot(data.get('load'), data.get('surface'), label='surface')
plt.plot(data.get('load'), data.get('elastic'), label='elastic')
# plt.plot(data.get('load'), [1./2. * t**2*Lx for t in data.get('load')], label='anal elast', ls=':', c='k')

plt.title('Kinking in plate under traction energetics')
plt.legend()
# plt.yticks([0, 1/20], [0, '$1/2.\sigma_c^2/E_0$'])
plt.xticks([parameters.get('loading').get("min"), parameters.get('loading').get("max")], [0, parameters.get('loading').get("max")])
plt.savefig("energetics.png")

# # savings?
# plt.figure()
# plt.plot(data.get('load'), data.get('surface'), label='surface')
# plt.plot(data.get('load'), data.get('elastic'), label='elastic')

# plt.title('Last steps')
# plt.legend()
# plt.yticks([0, 1/20], [0, '$1/2.\sigma_c^2/E_0$'])
# plt.xticks([0, 1], [0, 1])
# plt.savefig("lastSteps.png")


#plotter = pyvista.Plotter(
       #  title="Displacement",
        # window_size=[1600, 600],
        # shape=(1, 2), )
#_plt = plot_scalar(u_.sub(0), plotter, subplot=(0, 0))
#_plt = plot_vector(u, plotter, subplot=(0, 1))
#_plt.screenshot(f"displacement_MPI.png")


 #xvfb.start_xvfb(wait=0.05)
 #pyvista.OFF_SCREEN = True

#plotter = pyvista.Plotter(
        # title="Displacement",
      # window_size=[1600, 600],
      #  shape=(1, 2),
   #  )
#
# _plt = plot_scalar(alpha, plotter, subplot=(0, 0))
#_plt.screenshot(f"alpha2.png")
