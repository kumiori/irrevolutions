# %% [markdown]
# <a href="https://colab.research.google.com/github/kumiori/mec647/blob/main/En_passant_SarahPolystyrene.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import site
import sys


try : 
    from google.colab import files
except:
    pass
    
try:
    from fenics import *; from mshr import *
except ImportError as e:
    # !apt-get install software-properties-common
    # !add-apt-repository -y ppa:fenics-packages/fenics
    # !apt-get update -qq
    # !apt install -y fenics    
    site.addsitedir('/usr/lib/petsc/lib/python3/dist-packages')  # Always appends to end

    from fenics import *; from mshr import *
    from ufl import replace

# !fenics-version
# Out:
# 2019.2.0.dev0

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# **Energy**
# $$
# E(u, \alpha):= \frac{1}{2}\int_\Omega
# \underbrace{a(\alpha) E \mathbb{C(\nu)}}_{\sigma(\alpha)} e(u) : e(u) + \frac{G_c}{c_w}\int \frac{\alpha}{\ell}+\ell |\nabla \alpha|^2 dx
# $$
#
# where $u = ..., \ell=$

# %%
# Geometry

L1=0.06;
L = 0.06/L1; H = 0.03/L1;
l0 = 0.003/L1; w = 0.005/L1;
L1=(L-w)/2;
L2=(L+w)/2;
H1=H-l0;
epsilon = 0.005; 


plate = Rectangle(Point(0,0), Point(L, H))

notchVertices1 = [Point(L2-epsilon, H), Point(L2 , H1), Point(L2 + epsilon , H)]
notch1 = Polygon(notchVertices1)
notchVertices2 = [Point(L1+epsilon, 0), Point(L1 , l0), Point(L1 - epsilon ,0)]
notch2 = Polygon(notchVertices2)

domain = plate - notch1 - notch2 

cellSize = .02
nel = H / cellSize
mesh   = generate_mesh(domain, nel)

# %%
 plot(mesh)
# Out:
# [<matplotlib.lines.Line2D at 0x7f13276dd828>,
#  <matplotlib.lines.Line2D at 0x7f13276dd9b0>]

# %%
ndim = mesh.topology().dim()

cell_mrk = MeshFunction('bool', mesh, ndim)
cell_mrk.set_all(False)

# %%
for cell in cells(mesh):
  if 0.3 < cell.midpoint()[0] < 0.7:
    cell_mrk[cell] = True

plot(cell_mrk)

for i in range(2): mesh = refine(mesh, cell_mrk)
# mesh = refine(mesh, cell_mrk)

# %%
plot(mesh)
# Out:
# [<matplotlib.lines.Line2D at 0x7f13281dfc88>,
#  <matplotlib.lines.Line2D at 0x7f13281df358>]

# %%
V_u = VectorFunctionSpace(mesh, 'CG', 1)
V_alpha = FunctionSpace(mesh, 'CG', 1)

u = Function(V_u)
du = TrialFunction(V_u)
v = TestFunction(V_u)

alpha = Function(V_alpha)
beta = TestFunction(V_alpha)
dalpha = TrialFunction(V_alpha)

# %%
ut = Expression('t', t=0., degree=0)

bcs_u = [DirichletBC(V_u.sub(0), ut, 'near(x[0], {}, 1e-5)'.format(0)), 
         DirichletBC(V_u.sub(0), Constant(0.), 'near(x[0], {}, 1e-5)'.format(L))]


bca_0 = DirichletBC(V_alpha, Constant(0.), 'near(x[0], {}, 1e-5)'.format(0))
bca_1 = DirichletBC(V_alpha, Constant(0.), 'near(x[0], {}, 1e-5)'.format(L))

bc_alpha = [bca_0, bca_1]

# %%
# Constitutive

# Constitutive functions

E, nu = Constant(1000000000.), Constant(0.03)
ell = Constant(0.1)

ndim = mesh.topology().dim()

def w(alpha):
  return alpha

def a(alpha):
  return (1-alpha)**2

def eps(u):
  return sym(grad(u))

def sigma0(u):
  mu = E/(2.*(1.+nu))
  lmbda = E*nu/(1-nu**2.)
  return (2*mu*eps(u) + lmbda*tr(eps(u))*Identity(ndim))/E

def sigma(alpha, u):
  return a(alpha)*sigma0(u)

# %%
print(f'ell {ell.values()[0]}')
print(f'h min {mesh.hmin():2f}')
# Out:
# ell 0.1
# h min 0.005046

# %%
# Energetics

elastic_energy = 0.5*inner(sigma(alpha, u), eps(u))*dx
dissipated_energy =(w(alpha)/ell + ell* inner(grad(alpha), grad(alpha)))*dx

total_energy = elastic_energy + dissipated_energy 

E_u = derivative(total_energy, u, v)

from ufl import replace
E_du = replace(E_u, {u: du})

E_alpha = derivative(total_energy, alpha, beta)
E_alpha_alpha = derivative(E_alpha,alpha, dalpha)

# %%
# Construction of linear and bilinear forms

# problem_u = LinearVariationalProblem()
problem_u = LinearVariationalProblem(lhs(E_du), rhs(E_du), u, bcs_u)
solver_u = LinearVariationalSolver(problem_u)
solver_u.parameters.update({"linear_solver" : "umfpack"})

# Alternatively, compute explicitly:

A = inner(sigma(alpha, du), eps(v))*dx
# f0, g0 exist in L^2(\Omega), L^2(\partial\Omega)
# LL = dot(f0, v)*dx + dot(g0, v)*ds
zero = project(Constant((0., 0.)), V_u)
LL = dot(zero, v)*dx

problem_u = LinearVariationalProblem(A, LL, u, bcs_u)

# %%
# u = TrialFunction(V_u)
ut.t = -0.1
solver_u.solve()

# %%
plot(u, mode='displacement')

# %%
# Bounds

upperbound = project(Constant(1.), V_alpha)
lowerbound = project(Constant(0.), V_alpha)

# Boundary conditions
# set damage = 0 where we impose displacement boundary conditions

# bc_a1 = DirichletBC(V_alpha, Constant(0.), left)
# bc_a2 = DirichletBC(V_alpha, Constant(0.), right)

# bc_a = [bc_a1, bc_a2]

# Nonlinear problem and solver

problem_alpha = NonlinearVariationalProblem(E_alpha, alpha, bc_alpha, J=E_alpha_alpha)
problem_alpha.set_bounds(lowerbound, upperbound)

# solver able to solve with bounds: SNES

solver_alpha = NonlinearVariationalSolver(problem_alpha)
# info(solver_alpha.parameters, True)

snes_solver_parameters_bounds = {"nonlinear_solver": "snes", 
                                 "snes_solver": {"maximum_iterations": 300,
                                                 "absolute_tolerance": 1e-10,
                                                 "relative_tolerance": 1e-5,
                                                 "solution_tolerance": 1e-5,
                                                 "report": True,
                                                 "linear_solver" : "mumps"
                                                 }
                                }
# Solver method  |  Description                                                 
# ------------------------------------------------------------------------------
# bicgstab       |  Biconjugate gradient stabilized method                      
# cg             |  Conjugate gradient method                                   
# default        |  default linear solver                                       
# gmres          |  Generalized minimal residual method                         
# minres         |  Minimal residual method                                     
# mumps          |  MUMPS (MUltifrontal Massively Parallel Sparse direct Solver)
# petsc          |  PETSc built in LU solver                                    
# richardson     |  Richardson method                                           
# superlu        |  SuperLU                                                     
# tfqmr          |  Transpose-free quasi-minimal residual method                
# umfpack        |  UMFPACK (Unsymmetric MultiFrontal sparse LU factorization)  

solver_alpha.parameters.update(snes_solver_parameters_bounds)
solver_alpha.solve()
# Out:
# (0, True)

# %%
# boundaries
gauche = CompiledSubDomain("near(x[0], {}, 1e-4)".format(0))
droite = CompiledSubDomain("near(x[0], {}, 1e-4)".format(L))

boundaries = MeshFunction("size_t", mesh, 1)
boundaries.set_all(0)
gauche.mark(boundaries, 1) # mark gauche as 1
droite.mark(boundaries, 2) # mark droite as 2
ds = Measure("ds",subdomain_data=boundaries) # gauche: ds(1), droite: ds(2),

# %%
def alternate_minimisation(alpha, u,
                           alpha_0 = project(Constant(0.), V_alpha),
                           tol=1e-5, maxiter=100):
  alpha_diff = Function(V_alpha)
  iter = 1; error = 1
  alpha.vector()[:] = alpha_0.vector()
  
  while iter < maxiter and error > tol:
    solver_u.solve()
    # u: solution

    solver_alpha.solve()
    # alpha: solution
    # alpha0: alpha at previous timestep

    alpha_diff.vector()[:] = alpha.vector() - alpha_0.vector()
    error = norm(alpha_diff.vector(), 'l2')
    print("Iteration %d, error %e, alpha_max=%.3f"%(iter, error, max(alpha.vector())))
    alpha_0.assign(alpha)

    iter = iter+1

  return (iter, error)

# %%
# alpha = Function(V_alpha)
ut.t = -10.
alternate_minimisation(alpha, u)
# Out:
# Iteration 1, error 6.988841e+01, alpha_max=0.929
# Iteration 2, error 1.255753e+01, alpha_max=0.991
# Iteration 3, error 2.464346e+01, alpha_max=1.000
# Iteration 4, error 2.590252e+01, alpha_max=1.000
# Iteration 5, error 1.144355e+01, alpha_max=1.000
# Iteration 6, error 4.333146e+00, alpha_max=1.000
# Iteration 7, error 1.365964e+00, alpha_max=1.000
# Iteration 8, error 2.202803e-01, alpha_max=1.000
# Iteration 9, error 9.086366e-02, alpha_max=1.000
# Iteration 10, error 1.719971e-01, alpha_max=1.000
# Iteration 11, error 9.300096e-03, alpha_max=1.000
# Iteration 12, error 1.279098e-02, alpha_max=1.000
# Iteration 13, error 2.338251e-04, alpha_max=1.000
# Iteration 14, error 1.954237e-05, alpha_max=1.000
# Iteration 15, error 9.401254e-06, alpha_max=1.000
# (16, 9.401254371106319e-06)

# %%
plot(alpha)

# %%
def postprocess():
    tot_en.append(assemble(total_energy))
    sur_en.append(assemble(dissipated_energy))
    ela_en.append(assemble(elastic_energy))
    # assemble(sigma(alpha, u)[1,1]*ds(1))
    react_gauche.append(assemble(sigma(alpha,u)[1,1]*ds(1)))
    print("** elastic = {:.3f}, surface = {:.3f}, total = {:.3f}"
      .format(ela_en[-1], sur_en[-1], tot_en[-1]))
    print("** Converged in {:d} iterations, error = {:.3f}"
      .format(iter, error))

# %%
import os
import shutil

savedir = "results/plate"
if os.path.isdir(savedir):
    shutil.rmtree(savedir)
    
file_alpha = File(savedir+"/alpha.pvd") 
file_u = File(savedir+"/u.pvd")

# %%
file_u << u

# %%
# Evolution monotonically increasing load

loads = np.linspace(.0, -4, 10)

energies = []

tot_en = []
sur_en = []
ela_en = []
react_gauche = []

for (i, t) in enumerate(loads):
  ut.t = t
  print('')
  print("** Load step: t=%.2f"%t)
  (iter, error) = alternate_minimisation(alpha, u, maxiter=200)
  lowerbound.vector()[:] = alpha.vector()
  # postproc
  postprocess()


energies = {'elastic': ela_en, 'surface': sur_en, 'total': tot_en}
# Out:
# ** Load step: t=0.00
# Iteration 1, error 3.043741e+01, alpha_max=0.000
# Iteration 2, error 9.001138e-08, alpha_max=0.000
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# ** elastic = 0.000, surface = 0.000, total = 0.000
# ** Converged in 3 iterations, error = 0.000
#
# ** Load step: t=-0.44
# Iteration 1, error 0.000000e+00, alpha_max=0.000
# ** elastic = 0.048, surface = 0.000, total = 0.048
# ** Converged in 2 iterations, error = 0.000
#
# ** Load step: t=-0.89
# Iteration 1, error 0.000000e+00, alpha_max=0.000
# ** elastic = 0.191, surface = 0.000, total = 0.191
# ** Converged in 2 iterations, error = 0.000
#
# ** Load step: t=-1.33
# Iteration 1, error 1.329263e-03, alpha_max=0.001
# Iteration 2, error 4.546090e-06, alpha_max=0.001
# ** elastic = 0.429, surface = 0.000, total = 0.429
# ** Converged in 3 iterations, error = 0.000
#
# ** Load step: t=-1.78
# Iteration 1, error 1.138953e-02, alpha_max=0.004
# Iteration 2, error 2.126835e-04, alpha_max=0.004
# Iteration 3, error 3.894417e-06, alpha_max=0.004
# ** elastic = 0.763, surface = 0.000, total = 0.763
# ** Converged in 4 iterations, error = 0.000
#
# ** Load step: t=-2.22
# Iteration 1, error 4.913958e-02, alpha_max=0.013
# Iteration 2, error 2.888340e-03, alpha_max=0.013
# Iteration 3, error 1.694458e-04, alpha_max=0.013
# Iteration 4, error 9.860291e-06, alpha_max=0.013
# ** elastic = 1.192, surface = 0.000, total = 1.193
# ** Converged in 5 iterations, error = 0.000
#
# ** Load step: t=-2.67
# Iteration 1, error 1.930436e-01, alpha_max=0.032
# Iteration 2, error 3.368921e-02, alpha_max=0.034
# Iteration 3, error 6.096984e-03, alpha_max=0.035
# Iteration 4, error 1.098627e-03, alpha_max=0.035
# Iteration 5, error 1.978622e-04, alpha_max=0.035
# Iteration 6, error 3.564103e-05, alpha_max=0.035
# Iteration 7, error 6.420539e-06, alpha_max=0.035
# ** elastic = 1.714, surface = 0.003, total = 1.717
# ** Converged in 8 iterations, error = 0.000
#
# ** Load step: t=-3.11
# Iteration 1, error 1.595545e+00, alpha_max=0.083
# Iteration 2, error 1.638733e+00, alpha_max=0.122
# Iteration 3, error 1.923551e+00, alpha_max=0.167
# Iteration 4, error 2.471648e+00, alpha_max=0.224
# Iteration 5, error 3.312965e+00, alpha_max=0.299
# Iteration 6, error 4.441565e+00, alpha_max=0.400
# Iteration 7, error 5.691885e+00, alpha_max=0.529
# Iteration 8, error 6.509166e+00, alpha_max=0.682
# Iteration 9, error 5.826681e+00, alpha_max=0.832
# Iteration 10, error 3.690964e+00, alpha_max=0.939
# Iteration 11, error 4.090947e+00, alpha_max=0.986
# Iteration 12, error 3.643799e+00, alpha_max=1.000
# Iteration 13, error 1.381493e+00, alpha_max=1.000
# Iteration 14, error 2.071579e-01, alpha_max=1.000
# Iteration 15, error 8.434553e-02, alpha_max=1.000
# Iteration 16, error 6.226197e-02, alpha_max=1.000
# Iteration 17, error 4.256468e-02, alpha_max=1.000
# Iteration 18, error 3.377562e-02, alpha_max=1.000
# Iteration 19, error 4.740309e-02, alpha_max=1.000
# Iteration 20, error 6.967716e-02, alpha_max=1.000
# Iteration 21, error 9.231535e-02, alpha_max=1.000
# Iteration 22, error 5.782613e-02, alpha_max=1.000
# Iteration 23, error 2.583319e-02, alpha_max=1.000
# Iteration 24, error 1.501703e-02, alpha_max=1.000
# Iteration 25, error 1.227846e-02, alpha_max=1.000
# Iteration 26, error 1.478717e-02, alpha_max=1.000
# Iteration 27, error 2.191880e-02, alpha_max=1.000
# Iteration 28, error 2.803041e-02, alpha_max=1.000
# Iteration 29, error 1.795145e-02, alpha_max=1.000
# Iteration 30, error 6.057296e-03, alpha_max=1.000
# Iteration 31, error 2.373278e-03, alpha_max=1.000
# Iteration 32, error 1.227738e-03, alpha_max=1.000
# Iteration 33, error 7.218646e-04, alpha_max=1.000
# Iteration 34, error 4.486877e-04, alpha_max=1.000
# Iteration 35, error 2.867798e-04, alpha_max=1.000
# Iteration 36, error 1.868331e-04, alpha_max=1.000
# Iteration 37, error 1.232964e-04, alpha_max=1.000
# Iteration 38, error 8.205266e-05, alpha_max=1.000
# Iteration 39, error 5.493465e-05, alpha_max=1.000
# Iteration 40, error 3.693938e-05, alpha_max=1.000
# Iteration 41, error 2.491748e-05, alpha_max=1.000
# Iteration 42, error 1.684673e-05, alpha_max=1.000
# Iteration 43, error 1.140916e-05, alpha_max=1.000
# Iteration 44, error 7.736110e-06, alpha_max=1.000
# ** elastic = 0.009, surface = 1.314, total = 1.323
# ** Converged in 45 iterations, error = 0.000
#
# ** Load step: t=-3.56
# Iteration 1, error 8.767245e-02, alpha_max=1.000
# Iteration 2, error 1.534450e-02, alpha_max=1.000
# Iteration 3, error 7.745167e-03, alpha_max=1.000
# Iteration 4, error 3.690428e-03, alpha_max=1.000
# Iteration 5, error 1.849319e-03, alpha_max=1.000
# Iteration 6, error 9.512252e-04, alpha_max=1.000
# Iteration 7, error 4.960439e-04, alpha_max=1.000
# Iteration 8, error 2.607152e-04, alpha_max=1.000
# Iteration 9, error 1.374201e-04, alpha_max=1.000
# Iteration 10, error 7.272956e-05, alpha_max=1.000
# Iteration 11, error 3.853821e-05, alpha_max=1.000
# Iteration 12, error 2.043362e-05, alpha_max=1.000
# Iteration 13, error 1.083834e-05, alpha_max=1.000
# Iteration 14, error 5.750202e-06, alpha_max=1.000
# ** elastic = 0.007, surface = 1.318, total = 1.325
# ** Converged in 15 iterations, error = 0.000
#
# ** Load step: t=-4.00
# Iteration 1, error 6.191503e-02, alpha_max=1.000
# Iteration 2, error 1.151191e-02, alpha_max=1.000
# Iteration 3, error 5.537724e-03, alpha_max=1.000
# Iteration 4, error 2.980466e-03, alpha_max=1.000
# Iteration 5, error 1.683175e-03, alpha_max=1.000
# Iteration 6, error 9.673658e-04, alpha_max=1.000
# Iteration 7, error 5.597864e-04, alpha_max=1.000
# Iteration 8, error 3.247922e-04, alpha_max=1.000
# Iteration 9, error 1.889600e-04, alpha_max=1.000
# Iteration 10, error 1.095225e-04, alpha_max=1.000
# Iteration 11, error 6.364754e-05, alpha_max=1.000
# Iteration 12, error 3.699465e-05, alpha_max=1.000
# Iteration 13, error 2.150522e-05, alpha_max=1.000
# Iteration 14, error 1.250210e-05, alpha_max=1.000
# Iteration 15, error 7.268527e-06, alpha_max=1.000
# ** elastic = 0.006, surface = 1.320, total = 1.326
# ** Converged in 16 iterations, error = 0.000

# %%
plt.figure(figsize=(10, 8))
plot(alpha)

# %%
def plot_stress():
    plt.plot(loads, react_gauche, 'b*', linewidth = 2)
    plt.xlabel('Displacement')
    plt.ylabel('Force')

def plot_energy():
    p1, = plt.plot(loads, energies['elastic'],'b*',linewidth=2)
    p2, = plt.plot(loads, energies['surface'],'r^',linewidth=2)
    p3, = plt.plot(loads, energies['total'],'ko',linewidth=2)
    plt.legend([p1, p2, p3], ["Elastic","Dissipated","Total"])
    plt.xlabel('Displacement')
    plt.ylabel('Energies')


def plot_energy_stress():
    plt.subplot(211)
    plot_stress()
    plt.subplot(212)
    plot_energy()
    plt.savefig('./energies_force.png')
    plt.show()

plot_energy_stress()
