# %% [markdown]
# <a href="https://colab.research.google.com/github/kumiori/mec647/blob/main/En_passant_SarahPolystyrene.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import site
import sys


try : 
    from google.colab import files
except:
    pass
    
try:
    from fenics import *; from mshr import *
except ImportError as e:
    # !apt-get install software-properties-common
    # !add-apt-repository -y ppa:fenics-packages/fenics
    # !apt-get update -qq
    # !apt install -y fenics    
    site.addsitedir('/usr/lib/petsc/lib/python3/dist-packages')  # Always appends to end

    from fenics import *; from mshr import *
    from ufl import replace

# !fenics-version
# Out:
# 2019.2.0.dev0

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# **Energy**
# $$
# E(u, \alpha):= \frac{1}{2}\int_\Omega
# \underbrace{a(\alpha) E \mathbb{C(\nu)}}_{\sigma(\alpha)} e(u) : e(u) + \frac{G_c}{c_w}\int \frac{\alpha}{\ell}+\ell |\nabla \alpha|^2 dx
# $$
#
# where $u = ..., \ell=$

# %%
# Geometry

L1=0.06;
L = 0.06/L1; H = 0.03/L1;
l0 = 0.003/L1; w = 0.005/L1;
L1=(L-w)/2;
L2=(L+w)/2;
H1=H-l0;
epsilon = 0.005; 


plate = Rectangle(Point(0,0), Point(L, H))

notchVertices1 = [Point(L2-epsilon, H), Point(L2 , H1), Point(L2 + epsilon , H)]
notch1 = Polygon(notchVertices1)
notchVertices2 = [Point(L1+epsilon, 0), Point(L1 , l0), Point(L1 - epsilon ,0)]
notch2 = Polygon(notchVertices2)

domain = plate - notch1 - notch2 

cellSize = .02
nel = H / cellSize
mesh   = generate_mesh(domain, nel)

# %%
 plot(mesh)
# Out:
# [<matplotlib.lines.Line2D at 0x7fde024627f0>,
#  <matplotlib.lines.Line2D at 0x7fde02cc55c0>]

# %%
ndim = mesh.topology().dim()

cell_mrk = MeshFunction('bool', mesh, ndim)
cell_mrk.set_all(False)

# %%
for cell in cells(mesh):
  if 0.3 < cell.midpoint()[0] < 0.7:
    cell_mrk[cell] = True

plot(cell_mrk)

for i in range(2): mesh = refine(mesh, cell_mrk)
# mesh = refine(mesh, cell_mrk)

# %%
plot(mesh)
# Out:
# [<matplotlib.lines.Line2D at 0x7fde03017be0>,
#  <matplotlib.lines.Line2D at 0x7fde033c6a90>]

# %%
V_u = VectorFunctionSpace(mesh, 'CG', 1)
V_alpha = FunctionSpace(mesh, 'CG', 1)

u = Function(V_u)
du = TrialFunction(V_u)
v = TestFunction(V_u)

alpha = Function(V_alpha)
beta = TestFunction(V_alpha)
dalpha = TrialFunction(V_alpha)

# %%
ut = Expression('t', t=0., degree=0)

bcs_u = [DirichletBC(V_u.sub(0), ut, 'near(x[0], {}, 1e-5)'.format(0)), 
         DirichletBC(V_u.sub(0), Constant(0.), 'near(x[0], {}, 1e-5)'.format(L))]


bca_0 = DirichletBC(V_alpha, Constant(0.), 'near(x[0], {}, 1e-5)'.format(0))
bca_1 = DirichletBC(V_alpha, Constant(0.), 'near(x[0], {}, 1e-5)'.format(L))

bc_alpha = [bca_0, bca_1]

# %%
# Constitutive

# Constitutive functions

E, nu = Constant(1000000000.), Constant(0.03)
#Gc = Constant(1294)
ell = Constant(4.82)

ndim = mesh.topology().dim()

def w(alpha):
  return alpha

def a(alpha):
  return (1-alpha)**2

def eps(u):
  return sym(grad(u))

def sigma0(u):
  mu = E/(2.*(1.+nu))
  lmbda = E*nu/(1-nu**2.)
  return (2*mu*eps(u) + lmbda*tr(eps(u))*Identity(ndim))/E

def sigma(alpha, u):
  return a(alpha)*sigma0(u)

# %%
print(f'ell {ell.values()[0]}')
print(f'h min {mesh.hmin():2f}')
# Out:
# ell 4.82
# h min 0.005046

# %%
# Energetics

elastic_energy = 0.5*inner(sigma(alpha, u), eps(u))*dx
dissipated_energy =(w(alpha)/ell + ell* inner(grad(alpha), grad(alpha)))*dx

total_energy = elastic_energy + dissipated_energy 

E_u = derivative(total_energy, u, v)

from ufl import replace
E_du = replace(E_u, {u: du})

E_alpha = derivative(total_energy, alpha, beta)
E_alpha_alpha = derivative(E_alpha,alpha, dalpha)

# %%
# Construction of linear and bilinear forms

# problem_u = LinearVariationalProblem()
problem_u = LinearVariationalProblem(lhs(E_du), rhs(E_du), u, bcs_u)
solver_u = LinearVariationalSolver(problem_u)
solver_u.parameters.update({"linear_solver" : "umfpack"})

# Alternatively, compute explicitly:

A = inner(sigma(alpha, du), eps(v))*dx
# f0, g0 exist in L^2(\Omega), L^2(\partial\Omega)
# LL = dot(f0, v)*dx + dot(g0, v)*ds
zero = project(Constant((0., 0.)), V_u)
LL = dot(zero, v)*dx

problem_u = LinearVariationalProblem(A, LL, u, bcs_u)

# %%
# u = TrialFunction(V_u)
ut.t = -0.1
solver_u.solve()

# %%
plot(u, mode='displacement')

# %%
# Bounds

upperbound = project(Constant(1.), V_alpha)
lowerbound = project(Constant(0.), V_alpha)

# Boundary conditions
# set damage = 0 where we impose displacement boundary conditions

# bc_a1 = DirichletBC(V_alpha, Constant(0.), left)
# bc_a2 = DirichletBC(V_alpha, Constant(0.), right)

# bc_a = [bc_a1, bc_a2]

# Nonlinear problem and solver

problem_alpha = NonlinearVariationalProblem(E_alpha, alpha, bc_alpha, J=E_alpha_alpha)
problem_alpha.set_bounds(lowerbound, upperbound)

# solver able to solve with bounds: SNES

solver_alpha = NonlinearVariationalSolver(problem_alpha)
# info(solver_alpha.parameters, True)

snes_solver_parameters_bounds = {"nonlinear_solver": "snes", 
                                 "snes_solver": {"maximum_iterations": 300,
                                                 "absolute_tolerance": 1e-10,
                                                 "relative_tolerance": 1e-5,
                                                 "solution_tolerance": 1e-5,
                                                 "report": True,
                                                 "linear_solver" : "mumps"
                                                 }
                                }
# Solver method  |  Description                                                 
# ------------------------------------------------------------------------------
# bicgstab       |  Biconjugate gradient stabilized method                      
# cg             |  Conjugate gradient method                                   
# default        |  default linear solver                                       
# gmres          |  Generalized minimal residual method                         
# minres         |  Minimal residual method                                     
# mumps          |  MUMPS (MUltifrontal Massively Parallel Sparse direct Solver)
# petsc          |  PETSc built in LU solver                                    
# richardson     |  Richardson method                                           
# superlu        |  SuperLU                                                     
# tfqmr          |  Transpose-free quasi-minimal residual method                
# umfpack        |  UMFPACK (Unsymmetric MultiFrontal sparse LU factorization)  

solver_alpha.parameters.update(snes_solver_parameters_bounds)
solver_alpha.solve()
# Out:
# (0, True)

# %%
# boundaries
gauche = CompiledSubDomain("near(x[0], {}, 1e-4)".format(0))
droite = CompiledSubDomain("near(x[0], {}, 1e-4)".format(L))

boundaries = MeshFunction("size_t", mesh, 1)
boundaries.set_all(0)
gauche.mark(boundaries, 1) # mark gauche as 1
droite.mark(boundaries, 2) # mark droite as 2
ds = Measure("ds",subdomain_data=boundaries) # gauche: ds(1), droite: ds(2),

# %%
def alternate_minimisation(alpha, u,
                           alpha_0 = project(Constant(0.), V_alpha),
                           tol=1e-5, maxiter=100):
  alpha_diff = Function(V_alpha)
  iter = 1; error = 1
  alpha.vector()[:] = alpha_0.vector()
  
  while iter < maxiter and error > tol:
    solver_u.solve()
    # u: solution

    solver_alpha.solve()
    # alpha: solution
    # alpha0: alpha at previous timestep

    alpha_diff.vector()[:] = alpha.vector() - alpha_0.vector()
    error = norm(alpha_diff.vector(), 'l2')
    print("Iteration %d, error %e, alpha_max=%.3f"%(iter, error, max(alpha.vector())))
    alpha_0.assign(alpha)

    iter = iter+1

  return (iter, error)

# %%
# alpha = Function(V_alpha)
ut.t = -100.
alternate_minimisation(alpha, u)
# Out:
# Iteration 1, error 7.226474e+00, alpha_max=1.000
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py in run_code(self, code_obj, result)
#    2881                 #rprint('Running code', repr(code_obj)) # dbg
# -> 2882                 exec(code_obj, self.user_global_ns, self.user_ns)
#    2883             finally:
#
# <ipython-input-157-dfce157760aa> in <module>()
#       2 ut.t = -100.
# ----> 3 alternate_minimisation(alpha, u)
#
# <ipython-input-154-790629606611> in alternate_minimisation(alpha, u, alpha_0, tol, maxiter)
#      11
# ---> 12     solver_alpha.solve()
#      13     # alpha: solution
#
# RuntimeError:
#
# *** -------------------------------------------------------------------------
# *** DOLFIN encountered an error. If you are not able to resolve this issue
# *** using the information listed below, you can ask for help at
# ***
# ***     fenics-support@googlegroups.com
# ***
# *** Remember to include the error message listed below and, if possible,
# *** include a *minimal* running example to reproduce the error.
# ***
# *** -------------------------------------------------------------------------
# *** Error:   Unable to solve nonlinear system with PETScSNESSolver.
# *** Reason:  Solver did not converge.
# *** Where:   This error was encountered inside PETScSNESSolver.cpp.
# *** Process: 0
# ***
# *** DOLFIN version: 2019.2.0.dev0
# *** Git changeset:  unknown
# *** -------------------------------------------------------------------------
#
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# KeyboardInterrupt:

# %%
plot(alpha)

# %%
def postprocess():
    tot_en.append(assemble(total_energy))
    sur_en.append(assemble(dissipated_energy))
    ela_en.append(assemble(elastic_energy))
    # assemble(sigma(alpha, u)[1,1]*ds(1))
    react_gauche.append(assemble(sigma(alpha,u)[1,1]*ds(1)))
    print("** elastic = {:.3f}, surface = {:.3f}, total = {:.3f}"
      .format(ela_en[-1], sur_en[-1], tot_en[-1]))
    print("** Converged in {:d} iterations, error = {:.3f}"
      .format(iter, error))

# %%
import os
import shutil

savedir = "results/plate"
if os.path.isdir(savedir):
    shutil.rmtree(savedir)
    
file_alpha = File(savedir+"/alpha.pvd") 
file_u = File(savedir+"/u.pvd")

# %%
file_u << u

# %%
# Evolution monotonically increasing load

loads = np.linspace(.0, -4, 10)

energies = []

tot_en = []
sur_en = []
ela_en = []
react_gauche = []

for (i, t) in enumerate(loads):
  ut.t = t
  print('')
  print("** Load step: t=%.2f"%t)
  (iter, error) = alternate_minimisation(alpha, u, maxiter=200)
  lowerbound.vector()[:] = alpha.vector()
  # postproc
  postprocess()


energies = {'elastic': ela_en, 'surface': sur_en, 'total': tot_en}
# Out:
# ** Load step: t=0.00
# Iteration 1, error 3.058323e+01, alpha_max=0.000
# Iteration 2, error 8.808561e-08, alpha_max=0.000
# ** elastic = 0.000, surface = 0.000, total = 0.000
# ** Converged in 3 iterations, error = 0.000
#
# ** Load step: t=-0.44
# Iteration 1, error 0.000000e+00, alpha_max=0.000
# ** elastic = 0.048, surface = 0.000, total = 0.048
# ** Converged in 2 iterations, error = 0.000
#
# ** Load step: t=-0.89
# Iteration 1, error 0.000000e+00, alpha_max=0.000
# ** elastic = 0.191, surface = 0.000, total = 0.191
# ** Converged in 2 iterations, error = 0.000
#
# ** Load step: t=-1.33
# Iteration 1, error 1.273176e-03, alpha_max=0.001
# Iteration 2, error 4.311066e-06, alpha_max=0.001
# ** elastic = 0.429, surface = 0.000, total = 0.429
# ** Converged in 3 iterations, error = 0.000
#
# ** Load step: t=-1.78
# Iteration 1, error 1.098688e-02, alpha_max=0.004
# Iteration 2, error 1.979596e-04, alpha_max=0.004
# Iteration 3, error 3.518659e-06, alpha_max=0.004
# ** elastic = 0.763, surface = 0.000, total = 0.763
# ** Converged in 4 iterations, error = 0.000
#
# ** Load step: t=-2.22
# Iteration 1, error 4.719167e-02, alpha_max=0.013
# Iteration 2, error 2.740609e-03, alpha_max=0.013
# Iteration 3, error 1.588195e-04, alpha_max=0.013
# Iteration 4, error 9.155039e-06, alpha_max=0.013
# ** elastic = 1.192, surface = 0.000, total = 1.193
# ** Converged in 5 iterations, error = 0.000
#
# ** Load step: t=-2.67
# Iteration 1, error 1.852105e-01, alpha_max=0.031
# Iteration 2, error 3.180710e-02, alpha_max=0.034
# Iteration 3, error 5.682242e-03, alpha_max=0.034
# Iteration 4, error 1.011557e-03, alpha_max=0.034
# Iteration 5, error 1.796830e-04, alpha_max=0.034
# Iteration 6, error 3.190525e-05, alpha_max=0.034
# Iteration 7, error 5.665312e-06, alpha_max=0.034
# ** elastic = 1.714, surface = 0.003, total = 1.717
# ** Converged in 8 iterations, error = 0.000
#
# ** Load step: t=-3.11
# Iteration 1, error 1.582196e+00, alpha_max=0.081
# Iteration 2, error 1.611315e+00, alpha_max=0.119
# Iteration 3, error 1.874615e+00, alpha_max=0.162
# Iteration 4, error 2.393672e+00, alpha_max=0.217
# Iteration 5, error 3.202638e+00, alpha_max=0.288
# Iteration 6, error 4.303727e+00, alpha_max=0.384
# Iteration 7, error 5.569247e+00, alpha_max=0.509
# Iteration 8, error 6.511948e+00, alpha_max=0.659
# Iteration 9, error 6.096227e+00, alpha_max=0.812
# Iteration 10, error 3.967270e+00, alpha_max=0.928
# Iteration 11, error 4.060677e+00, alpha_max=0.982
# Iteration 12, error 3.945010e+00, alpha_max=1.000
# Iteration 13, error 1.659639e+00, alpha_max=1.000
# Iteration 14, error 2.679508e-01, alpha_max=1.000
# Iteration 15, error 9.033092e-02, alpha_max=1.000
# Iteration 16, error 7.616761e-02, alpha_max=1.000
# Iteration 17, error 8.786035e-02, alpha_max=1.000
# Iteration 18, error 9.834039e-02, alpha_max=1.000
# Iteration 19, error 5.936102e-02, alpha_max=1.000
# Iteration 20, error 3.032757e-02, alpha_max=1.000
# Iteration 21, error 1.775906e-02, alpha_max=1.000
# Iteration 22, error 1.125114e-02, alpha_max=1.000
# Iteration 23, error 7.465517e-03, alpha_max=1.000
# Iteration 24, error 5.289356e-03, alpha_max=1.000
# Iteration 25, error 4.106282e-03, alpha_max=1.000
# Iteration 26, error 3.552461e-03, alpha_max=1.000
# Iteration 27, error 3.441463e-03, alpha_max=1.000
# Iteration 28, error 3.718336e-03, alpha_max=1.000
# Iteration 29, error 4.449156e-03, alpha_max=1.000
# Iteration 30, error 5.903733e-03, alpha_max=1.000
# Iteration 31, error 8.780777e-03, alpha_max=1.000
# Iteration 32, error 1.455427e-02, alpha_max=1.000
# Iteration 33, error 2.642333e-02, alpha_max=1.000
# Iteration 34, error 4.421202e-02, alpha_max=1.000
# Iteration 35, error 3.342449e-02, alpha_max=1.000
# Iteration 36, error 9.463691e-03, alpha_max=1.000
# Iteration 37, error 4.271746e-03, alpha_max=1.000
# Iteration 38, error 2.798555e-03, alpha_max=1.000
# Iteration 39, error 2.012394e-03, alpha_max=1.000
# Iteration 40, error 1.501198e-03, alpha_max=1.000
# Iteration 41, error 1.145248e-03, alpha_max=1.000
# Iteration 42, error 8.946988e-04, alpha_max=1.000
# Iteration 43, error 7.110032e-04, alpha_max=1.000
# Iteration 44, error 5.724275e-04, alpha_max=1.000
# Iteration 45, error 4.661528e-04, alpha_max=1.000
# Iteration 46, error 3.837904e-04, alpha_max=1.000
# Iteration 47, error 3.194495e-04, alpha_max=1.000
# Iteration 48, error 2.687358e-04, alpha_max=1.000
# Iteration 49, error 2.286554e-04, alpha_max=1.000
# Iteration 50, error 1.967866e-04, alpha_max=1.000
# Iteration 51, error 1.712309e-04, alpha_max=1.000
# Iteration 52, error 1.505906e-04, alpha_max=1.000
# Iteration 53, error 1.337940e-04, alpha_max=1.000
# Iteration 54, error 1.200147e-04, alpha_max=1.000
# Iteration 55, error 1.086142e-04, alpha_max=1.000
# Iteration 56, error 9.909888e-05, alpha_max=1.000
# Iteration 57, error 9.108652e-05, alpha_max=1.000
# Iteration 58, error 8.428079e-05, alpha_max=1.000
# Iteration 59, error 7.845123e-05, alpha_max=1.000
# Iteration 60, error 7.341795e-05, alpha_max=1.000
# Iteration 61, error 6.904044e-05, alpha_max=1.000
# Iteration 62, error 6.520553e-05, alpha_max=1.000
# Iteration 63, error 6.182666e-05, alpha_max=1.000
# Iteration 64, error 5.883251e-05, alpha_max=1.000
# Iteration 65, error 5.616610e-05, alpha_max=1.000
# Iteration 66, error 5.378119e-05, alpha_max=1.000
# Iteration 67, error 5.163994e-05, alpha_max=1.000
# Iteration 68, error 4.971120e-05, alpha_max=1.000
# Iteration 69, error 4.796911e-05, alpha_max=1.000
# Iteration 70, error 4.639208e-05, alpha_max=1.000
# Iteration 71, error 4.496195e-05, alpha_max=1.000
# Iteration 72, error 4.366338e-05, alpha_max=1.000
# Iteration 73, error 4.248332e-05, alpha_max=1.000
# Iteration 74, error 4.141063e-05, alpha_max=1.000
# Iteration 75, error 4.043574e-05, alpha_max=1.000
# Iteration 76, error 3.955042e-05, alpha_max=1.000
# Iteration 77, error 3.874756e-05, alpha_max=1.000
# Iteration 78, error 3.802100e-05, alpha_max=1.000
# Iteration 79, error 3.736538e-05, alpha_max=1.000
# Iteration 80, error 3.677608e-05, alpha_max=1.000
# Iteration 81, error 3.624905e-05, alpha_max=1.000
# Iteration 82, error 3.578082e-05, alpha_max=1.000
# Iteration 83, error 3.536835e-05, alpha_max=1.000
# Iteration 84, error 3.500905e-05, alpha_max=1.000
# Iteration 85, error 3.470071e-05, alpha_max=1.000
# Iteration 86, error 3.444143e-05, alpha_max=1.000
# Iteration 87, error 3.422967e-05, alpha_max=1.000
# Iteration 88, error 3.406414e-05, alpha_max=1.000
# Iteration 89, error 3.394384e-05, alpha_max=1.000
# Iteration 90, error 3.386803e-05, alpha_max=1.000
# Iteration 91, error 3.383620e-05, alpha_max=1.000
# Iteration 92, error 3.384809e-05, alpha_max=1.000
# Iteration 93, error 3.390367e-05, alpha_max=1.000
# Iteration 94, error 3.400313e-05, alpha_max=1.000
# Iteration 95, error 3.414690e-05, alpha_max=1.000
# Iteration 96, error 3.433564e-05, alpha_max=1.000
# Iteration 97, error 3.457026e-05, alpha_max=1.000
# Iteration 98, error 3.485190e-05, alpha_max=1.000
# Iteration 99, error 3.518198e-05, alpha_max=1.000
# Iteration 100, error 3.556217e-05, alpha_max=1.000
# Iteration 101, error 3.599447e-05, alpha_max=1.000
# Iteration 102, error 3.648118e-05, alpha_max=1.000
# Iteration 103, error 3.702492e-05, alpha_max=1.000
# Iteration 104, error 3.762873e-05, alpha_max=1.000
# Iteration 105, error 3.829603e-05, alpha_max=1.000
# Iteration 106, error 3.903071e-05, alpha_max=1.000
# Iteration 107, error 3.983714e-05, alpha_max=1.000
# Iteration 108, error 4.072028e-05, alpha_max=1.000
# Iteration 109, error 4.168572e-05, alpha_max=1.000
# Iteration 110, error 4.273974e-05, alpha_max=1.000
# Iteration 111, error 4.388944e-05, alpha_max=1.000
# Iteration 112, error 4.514284e-05, alpha_max=1.000
# Iteration 113, error 4.650896e-05, alpha_max=1.000
# Iteration 114, error 4.799806e-05, alpha_max=1.000
# Iteration 115, error 4.962175e-05, alpha_max=1.000
# Iteration 116, error 5.139319e-05, alpha_max=1.000
# Iteration 117, error 5.332742e-05, alpha_max=1.000
# Iteration 118, error 5.544156e-05, alpha_max=1.000
# Iteration 119, error 5.775524e-05, alpha_max=1.000
# Iteration 120, error 6.029101e-05, alpha_max=1.000
# Iteration 121, error 6.307484e-05, alpha_max=1.000
# Iteration 122, error 6.613681e-05, alpha_max=1.000
# Iteration 123, error 6.951182e-05, alpha_max=1.000
# Iteration 124, error 7.324063e-05, alpha_max=1.000
# Iteration 125, error 7.737103e-05, alpha_max=1.000
# Iteration 126, error 8.195932e-05, alpha_max=1.000
# Iteration 127, error 8.707234e-05, alpha_max=1.000
# Iteration 128, error 9.278986e-05, alpha_max=1.000
# Iteration 129, error 9.920795e-05, alpha_max=1.000
# Iteration 130, error 1.064427e-04, alpha_max=1.000
# Iteration 131, error 1.146252e-04, alpha_max=1.000
# Iteration 132, error 1.235587e-04, alpha_max=1.000
# Iteration 133, error 1.298349e-04, alpha_max=1.000
# Iteration 134, error 1.376654e-04, alpha_max=1.000
# Iteration 135, error 1.465735e-04, alpha_max=1.000
# Iteration 136, error 1.568115e-04, alpha_max=1.000
# Iteration 137, error 1.686308e-04, alpha_max=1.000
# Iteration 138, error 1.823461e-04, alpha_max=1.000
# Iteration 139, error 1.983531e-04, alpha_max=1.000
# Iteration 140, error 2.171559e-04, alpha_max=1.000
# Iteration 141, error 2.394041e-04, alpha_max=1.000
# Iteration 142, error 2.659461e-04, alpha_max=1.000
# Iteration 143, error 2.980998e-04, alpha_max=1.000
# Iteration 144, error 3.372581e-04, alpha_max=1.000
# Iteration 145, error 3.853474e-04, alpha_max=1.000
# Iteration 146, error 4.454046e-04, alpha_max=1.000
# Iteration 147, error 5.215929e-04, alpha_max=1.000
# Iteration 148, error 6.199895e-04, alpha_max=1.000
# Iteration 149, error 7.497160e-04, alpha_max=1.000
# Iteration 150, error 9.248855e-04, alpha_max=1.000
# Iteration 151, error 1.168092e-03, alpha_max=1.000
# Iteration 152, error 1.516896e-03, alpha_max=1.000
# Iteration 153, error 2.036344e-03, alpha_max=1.000
# Iteration 154, error 2.843737e-03, alpha_max=1.000
# Iteration 155, error 4.157301e-03, alpha_max=1.000
# Iteration 156, error 6.379329e-03, alpha_max=1.000
# Iteration 157, error 1.013016e-02, alpha_max=1.000
# Iteration 158, error 1.539192e-02, alpha_max=1.000
# Iteration 159, error 1.766048e-02, alpha_max=1.000
# Iteration 160, error 1.061812e-02, alpha_max=1.000
# Iteration 161, error 4.311123e-03, alpha_max=1.000
# Iteration 162, error 2.212345e-03, alpha_max=1.000
# Iteration 163, error 1.464375e-03, alpha_max=1.000
# Iteration 164, error 1.089300e-03, alpha_max=1.000
# Iteration 165, error 8.547153e-04, alpha_max=1.000
# Iteration 166, error 6.911466e-04, alpha_max=1.000
# Iteration 167, error 5.705316e-04, alpha_max=1.000
# Iteration 168, error 4.785768e-04, alpha_max=1.000
# Iteration 169, error 4.068767e-04, alpha_max=1.000
# Iteration 170, error 3.500421e-04, alpha_max=1.000
# Iteration 171, error 3.044154e-04, alpha_max=1.000
# Iteration 172, error 2.672689e-04, alpha_max=1.000
# Iteration 173, error 2.369270e-04, alpha_max=1.000
# Iteration 174, error 2.120320e-04, alpha_max=1.000
# Iteration 175, error 1.913808e-04, alpha_max=1.000
# Iteration 176, error 1.741454e-04, alpha_max=1.000
# Iteration 177, error 1.596838e-04, alpha_max=1.000
# Iteration 178, error 1.474914e-04, alpha_max=1.000
# Iteration 179, error 1.371686e-04, alpha_max=1.000
# Iteration 180, error 1.283972e-04, alpha_max=1.000
# Iteration 181, error 1.209224e-04, alpha_max=1.000
# Iteration 182, error 1.145396e-04, alpha_max=1.000
# Iteration 183, error 1.090838e-04, alpha_max=1.000
# Iteration 184, error 1.044216e-04, alpha_max=1.000
# Iteration 185, error 1.004450e-04, alpha_max=1.000
# Iteration 186, error 9.706604e-05, alpha_max=1.000
# Iteration 187, error 9.421363e-05, alpha_max=1.000
# Iteration 188, error 9.182996e-05, alpha_max=1.000
# Iteration 189, error 8.986837e-05, alpha_max=1.000
# Iteration 190, error 8.829144e-05, alpha_max=1.000
# Iteration 191, error 8.706956e-05, alpha_max=1.000
# Iteration 192, error 8.617978e-05, alpha_max=1.000
# Iteration 193, error 8.560495e-05, alpha_max=1.000
# Iteration 194, error 8.533310e-05, alpha_max=1.000
# Iteration 195, error 8.535697e-05, alpha_max=1.000
# Iteration 196, error 8.567367e-05, alpha_max=1.000
# Iteration 197, error 8.628460e-05, alpha_max=1.000
# Iteration 198, error 8.719533e-05, alpha_max=1.000
# Iteration 199, error 8.841575e-05, alpha_max=1.000
# ** elastic = 0.010, surface = 1.314, total = 1.324
# ** Converged in 200 iterations, error = 0.000
#
# ** Load step: t=-3.56
# Iteration 1, error 1.036910e-01, alpha_max=1.000
# Iteration 2, error 2.422712e-02, alpha_max=1.000
# Iteration 3, error 1.777940e-02, alpha_max=1.000
# Iteration 4, error 7.731482e-03, alpha_max=1.000
# Iteration 5, error 3.550384e-03, alpha_max=1.000
# Iteration 6, error 1.685498e-03, alpha_max=1.000
# Iteration 7, error 8.130831e-04, alpha_max=1.000
# Iteration 8, error 3.968359e-04, alpha_max=1.000
# Iteration 9, error 1.957022e-04, alpha_max=1.000
# Iteration 10, error 9.749328e-05, alpha_max=1.000
# Iteration 11, error 4.895445e-05, alpha_max=1.000
# Iteration 12, error 2.474725e-05, alpha_max=1.000
# Iteration 13, error 1.257759e-05, alpha_max=1.000
# Iteration 14, error 6.419676e-06, alpha_max=1.000
# ** elastic = 0.008, surface = 1.318, total = 1.326
# ** Converged in 15 iterations, error = 0.000
#
# ** Load step: t=-4.00
# Iteration 1, error 6.827896e-02, alpha_max=1.000
# Iteration 2, error 1.461596e-02, alpha_max=1.000
# Iteration 3, error 6.499529e-03, alpha_max=1.000
# Iteration 4, error 3.203062e-03, alpha_max=1.000
# Iteration 5, error 1.699909e-03, alpha_max=1.000
# Iteration 6, error 9.385686e-04, alpha_max=1.000
# Iteration 7, error 5.265796e-04, alpha_max=1.000
# Iteration 8, error 2.977680e-04, alpha_max=1.000
# Iteration 9, error 1.674613e-04, alpha_max=1.000
# Iteration 10, error 9.455903e-05, alpha_max=1.000
# Iteration 11, error 5.337919e-05, alpha_max=1.000
# Iteration 12, error 3.012327e-05, alpha_max=1.000
# Iteration 13, error 1.699727e-05, alpha_max=1.000
# Iteration 14, error 9.588622e-06, alpha_max=1.000
# ** elastic = 0.006, surface = 1.321, total = 1.328
# ** Converged in 15 iterations, error = 0.000

# %%
plt.figure(figsize=(10, 8))
plot(alpha)

# %%
def plot_stress():
    plt.plot(loads, react_gauche, 'b*', linewidth = 2)
    plt.xlabel('Displacement')
    plt.ylabel('Force')

def plot_energy():
    p1, = plt.plot(loads, energies['elastic'],'b*',linewidth=2)
    p2, = plt.plot(loads, energies['surface'],'r^',linewidth=2)
    p3, = plt.plot(loads, energies['total'],'ko',linewidth=2)
    plt.legend([p1, p2, p3], ["Elastic","Dissipated","Total"])
    plt.xlabel('Displacement')
    plt.ylabel('Energies')


def plot_energy_stress():
    plt.subplot(211)
    plot_stress()
    plt.subplot(212)
    plot_energy()
    plt.savefig('./energies_force.png')
    plt.show()

plot_energy_stress()
