# %% [markdown]
# <a href="https://colab.research.google.com/github/kumiori/mec647/blob/Assala_T/angle45%C2%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
import sys

try:
    import google.colab  # noqa: F401
except ImportError:
    import ufl  # noqa: F401
    import dolfinx  # noqa: F401
else:
    try:
        import ufl
        import dolfinx
    except ImportError:
        # !wget "https://fem-on-colab.github.io/releases/fenicsx-install.sh" -O "/tmp/fenicsx-install.sh" && bash "/tmp/fenicsx-install.sh";
        import ufl  # noqa: F401
        import dolfinx  # noqa: F401

try:
    import pyvista
except ImportError:
    # !{sys.executable} -m pip install --upgrade pyvista itkwidgets;
    import pyvista  # noqa: F401
    from pyvista.utilities import xvfb

try:
    import gmsh
except ImportError:
    # !{sys.executable} -m pip install gmsh
    import gmsh

# !sudo apt install libgl1-mesa-glx xvfb;
# !{sys.executable} -m pip install pythreejs;
# !{sys.executable} -m pip install ipygany;
# !{sys.executable} -m pip install --upgrade PyYAML
# !pip install --ignore-installed PyYAML

# %%
branch_name = 'main'
# branch_name = 'Assala_T'

# !rm -rf mec647
try:
  # !git clone -b {branch_name} https://github.com/kumiori/mec647.git
  sys.path.append('mec647/')

  print()
  print(f'Cloned brach: {branch_name}')
  print(f'Last commit message')
  # !cd mec647/ && git log -n 1 && cd ..
  import mec647
  from mec647 import meshes
  from mec647.meshes import primitives
  # from mec647.algorithms import am
  from mec647.utils.viz import plot_mesh, plot_scalar, plot_vector

except Exception as e:
  print('Something went wrong', e)
  # !rm -rf mec647
  # !git clone https://github.com/kumiori/mec647.git
# Out:
# Cloning into 'mec647'...
# remote: Enumerating objects: 1226, done.
# remote: Counting objects: 100% (1226/1226), done.
# remote: Compressing objects: 100% (912/912), done.
# remote: Total 1226 (delta 624), reused 613 (delta 274), pack-reused 0
# Receiving objects: 100% (1226/1226), 19.42 MiB | 8.87 MiB/s, done.
# Resolving deltas: 100% (624/624), done.
#
# Cloned brach: main
# Last commit message
# commit 25aa48ad32b5c11d7dd6e087bdf09fea88442b28 (HEAD -> main, origin/main, origin/HEAD)
# Merge: 822d5b0 222efb0
# Author: igorassist <igorassist98@gmail.com>
# Date:   Sat Feb 26 14:14:34 2022 +0100
#
#     Merge branch 'main' of https://github.com/kumiori/mec647

# %%
import matplotlib.pyplot as plt
from petsc4py import PETSc
import numpy as np
from mpi4py import MPI

comm = MPI.COMM_WORLD

from dolfinx.fem import (
    Constant,
    Function,
    FunctionSpace,
    assemble_scalar,
    dirichletbc,
    form,
    locate_dofs_geometrical,
    set_bc,
)

# meshes
import meshes
from meshes import primitives

import models
from models import DamageElasticityModel as Brittle

# %%
import numpy as np
import yaml
import json
import sys
import os
from pathlib import Path

from mpi4py import MPI

import petsc4py
from petsc4py import PETSc

import dolfinx
import dolfinx.plot
from dolfinx import log
import ufl

import algorithms
from algorithms import am

from dolfinx.io import XDMFFile

import logging

logging.basicConfig(level=logging.INFO)

import dolfinx
import dolfinx.plot
import dolfinx.io
from dolfinx.fem import (
    Constant,
    Function,
    FunctionSpace,
    assemble_scalar,
    dirichletbc,
    form,
    locate_dofs_geometrical,
    set_bc,
)
import matplotlib.pyplot as plt
import pyvista 
from pyvista.utilities import xvfb


# visualisation
from utils import viz
import matplotlib.pyplot as plt
from utils.viz import plot_mesh, plot_vector, plot_scalar
generateStepwiseOutput=True

# %%
# Parameters
parameters = {
    'loading': {
        'min': 0.0,
        'max': 1.,
        'steps': 10
    },
    'geometry': {
        'geom_type': 'Plate with Kink',
        'Lx': .6,
        'Ly': 1, 
        'L0': 0.3,
        'theta': 45,
        'eta': 1e-2,
    },
    'model': {
        'E': 3.e+9,
        'nu': 0.4,
        'w1': 1.,
        'ell': 0.1, 
        'k_res': 1.e-8
    },
    'solvers': {
          'elasticity': {        
            'snes': {
                'snes_type': 'newtontr',
                'snes_stol': 1e-8,
                'snes_atol': 1e-8,
                'snes_rtol': 1e-8,
                'snes_max_it': 250,
                'snes_monitor': "",
                'ksp_type': 'preonly',
                'pc_type': 'lu',
                'pc_factor_mat_solver_type': 'mumps'
            }
        },
          'damage': {        
            'snes': {
                'snes_type': 'vinewtonrsls',
                'snes_stol': 1e-5,
                'snes_atol': 1e-5,
                'snes_rtol': 1e-8,
                'snes_max_it': 100,
                'snes_monitor': "",
                'ksp_type': 'preonly',
                'pc_type': 'lu',
                'pc_factor_mat_solver_type': 'mumps'
            },
        },
          'damage_elasticity': {
            "max_it": 2000,
            "alpha_rtol": 1.0e-4,
            "criterion": "alpha_H1"
          }
    }
}

# %%
def  mesh_kink(name,
                Lx,
                Ly,
                # a,
                # b,
               rad,
               theta,
              # theta
                eta,
                lc,
                tdim,
                order=1,
                msh_file=None,
                comm=MPI.COMM_WORLD):
    """
    Create mesh of 3d tensile test specimen according to ISO 6892-1:2019 using the Python API of Gmsh.
    """
    # Perform Gmsh work only on rank = 0

    if comm.rank == 0:

        import gmsh

        # Initialise gmsh and set options
        gmsh.initialize()
        gmsh.option.setNumber("General.Terminal", 1)

        gmsh.option.setNumber("Mesh.Algorithm", 6)
        model = gmsh.model()
        model.add("Rectangle")
        model.setCurrent("Rectangle")
        # points = [p1, p2, p3, p4, p5, p6, p7, p8,p9,p10,p11]
        p1 = model.geo.addPoint(0.0, 0.0, 0, lc, tag=1)
        p2 = model.geo.addPoint(Lx, 0.0, 0, lc, tag=2)
        p3 = model.geo.addPoint(Lx, Ly, 0.0, lc, tag=3)
        p4 = model.geo.addPoint(0, Ly, 0, lc, tag=4)

        p5 = model.geo.addPoint(Lx/2 + rad*np.cos(theta), Ly/2 + rad*np.sin(theta), 0.0, lc/3, tag=5)
        p7 = model.geo.addPoint(Lx/2 - rad*np.cos(theta), Ly/2 - rad*np.sin(theta), 0.0, lc/3, tag=7)

        # p5 = model.geo.addPoint(Lx/2 +a, Ly/2 +b,0.0, lc/1.5, tag=5)
        p6 = model.geo.addPoint(Lx/2, Ly/2 + eta,0, lc, tag=6)
        # p7 = model.geo.addPoint(Lx/2-a,Ly/2-b,0,lc/1.5, tag=7)
        p8 = model.geo.addPoint(Lx/2,Ly/2 - eta,0, lc, tag=8)

        # Lines = [L1, L2, L3, L4, L5, L6, L7, L8]
        L1 = model.geo.addLine(p1, p2, tag=1)
        L2 = model.geo.addLine(p2, p3, tag=2)
        L3 = model.geo.addLine(p3, p4, tag=3)
        L4 = model.geo.addLine(p4, p1, tag=4)
        L5 = model.geo.addLine(p5, p6, tag=5)
        L6 = model.geo.addLine(p6, p7, tag=6)
        L7 = model.geo.addLine(p7, p8, tag=7)
        L8 = model.geo.addLine(p8, p5, tag=8)


        
        cloop1 = model.geo.addCurveLoop([L1, L2, L3, L4])
        cloop2 = model.geo.addCurveLoop([L5, L6, L7, L8])
        
        # surface_1 =
        model.geo.addPlaneSurface([cloop1, cloop2])

        model.geo.synchronize()
        surface_entities = [model[1] for model in model.getEntities(tdim)]

        model.addPhysicalGroup(tdim, surface_entities, tag=1)
        model.setPhysicalName(tdim, 1, "Rectangle surface")

        # Set mesh size via points
        # gmsh.model.mesh.setSize(points, lc)  # heuristic

        # gmsh.model.mesh.optimize("Netgen")

        # Set geometric order of mesh cells
        gmsh.model.mesh.setOrder(order)

        # Define physical groups for subdomains (! target tag > 0)
        # domain = 1
        # gmsh.model.addPhysicalGroup(tdim, [v[1] for v in volumes], domain)
        # gmsh.model.setPhysicalName(tdim, domain, 'domain')
              

        gmsh.model.addPhysicalGroup(tdim - 1, [1], tag=9)
        gmsh.model.setPhysicalName(tdim - 1, 9, "Bottom  of the Plate")
        gmsh.model.addPhysicalGroup(tdim - 1, [4], tag=10)
        gmsh.model.setPhysicalName(tdim - 1, 10, "Top  of the Plate")
        gmsh.model.addPhysicalGroup(tdim - 1, [5], tag=11)
        gmsh.model.setPhysicalName(tdim - 1, 11, "1/2 Top of the TipCrack")
        gmsh.model.addPhysicalGroup(tdim - 1, [6], tag=12)
        gmsh.model.setPhysicalName(tdim - 1, 12, "1/2 Top of the TipCrack")
        gmsh.model.addPhysicalGroup(tdim - 1, [7], tag=13)
        gmsh.model.setPhysicalName(tdim - 1, 13, "1/2 bottom of the TipCrack")
        gmsh.model.addPhysicalGroup(tdim - 1, [8], tag=14)
        gmsh.model.setPhysicalName(tdim - 1, 14, "1/2 bottom of the TipCrack")

        model.mesh.generate(tdim)


        #Generating the mesh
    model.geo.synchronize()
    model.mesh.generate(tdim)

    return gmsh.model

# %%
Lx = parameters.get("geometry").get("Lx")
Ly = parameters.get("geometry").get("Ly")
L0 = parameters.get("geometry").get("L0")
eta = parameters.get("geometry").get("eta")

geom_type = parameters.get("geometry").get("geom_type")

lc=0.05
theta = 45/180 * np.pi

gmsh_model=mesh_kink('mesh', Lx, Ly, L0/2, theta, eta,lc, 2, 1)

mesh, mts = meshes.gmsh_model_to_mesh(gmsh_model,
                               cell_data=False,
                               facet_data=True,
                               gdim=2)


plt.figure()
ax = plot_mesh(mesh)
fig = ax.get_figure()
fig.savefig(f"mesh.png")

# %%
# usedMesh=mesh 
# Enables opportunity to improve mesh at specific places, might lead to deformed elements
# Functional Setting

element_u = ufl.VectorElement("Lagrange", mesh.ufl_cell(),
                              degree=1, dim=2)

element_alpha = ufl.FiniteElement("Lagrange", mesh.ufl_cell(),
                              degree=1)

V_u = dolfinx.fem.FunctionSpace(mesh, element_u) 
V_alpha = dolfinx.fem.FunctionSpace(mesh, element_alpha) 

u = dolfinx.fem.Function(V_u, name="Displacement")
u_ = dolfinx.fem.Function(V_u, name="BoundaryDisplacement")


alpha = dolfinx.fem.Function(V_alpha, name="Damage")

# Pack state
state = {"u": u, "alpha": alpha}

# Bounds
alpha_ub = dolfinx.fem.Function(V_alpha, name="UpperBoundDamage")
alpha_lb = dolfinx.fem.Function(V_alpha, name="LowerBoundDamage")



dx = ufl.Measure("dx", domain = mesh)
ds = ufl.Measure("ds", domain = mesh)


# Boundary sets
dofs_alpha_left = locate_dofs_geometrical(V_alpha, lambda x: np.isclose(x[0], 0.))
dofs_alpha_right = locate_dofs_geometrical(V_alpha, lambda x: np.isclose(x[0], Lx))
dofs_alpha_bottom = locate_dofs_geometrical(V_alpha, lambda x: np.isclose(x[1], 0.))
dofs_alpha_top = locate_dofs_geometrical(V_alpha, lambda x: np.isclose(x[1], Ly))


dofs_u_left = locate_dofs_geometrical(V_u, lambda x: np.isclose(x[0], 0.))
dofs_u_right = locate_dofs_geometrical(V_u, lambda x: np.isclose(x[0], Lx))
dofs_u_top = locate_dofs_geometrical(V_u, lambda x: np.isclose(x[1], Ly))
dofs_u_bottom = locate_dofs_geometrical(V_u, lambda x: np.isclose(x[1], 0))

# Boundary data
u_.interpolate(lambda x: (np.zeros_like(x[0]), np.ones_like(x[1])))

# Bounds (nontrivial)
alpha_lb.interpolate(lambda x: np.zeros_like(x[0]))
alpha_ub.interpolate(lambda x: np.ones_like(x[0]))

# Boundary conditions
bcs_u = [
         dirichletbc(np.array([0., 0.], dtype=PETSc.ScalarType),
                      dofs_u_bottom,
                      V_u),
         dirichletbc(u_, dofs_u_top)
         ]

bcs_alpha = [
             dirichletbc(np.array(0., dtype = PETSc.ScalarType),
                         np.concatenate([dofs_alpha_bottom, dofs_alpha_top]),
                         V_alpha)
]

bcs = {"bcs_u": bcs_u, "bcs_alpha": bcs_alpha}

model = Brittle(parameters["model"])

total_energy = model.total_energy_density(state) * dx
solver = am.AlternateMinimisation(total_energy,
                         state,
                         bcs,
                         parameters.get("solvers"),
                         bounds=(alpha_lb, alpha_ub)
                         )

# %%
# %%time
# Loop for evolution
loads = np.linspace(parameters.get("loading").get("min"),
                    parameters.get("loading").get("max"),
                    parameters.get("loading").get("steps"))

data = {
    'elastic': [],
    'surface': [],
    'total': [],
    'load': []
}
xvfb.start_xvfb(wait=0.05)
pyvista.OFF_SCREEN = True
plotter = pyvista.Plotter(
        title="Displacement",
        window_size=[1600, 600],
        shape=(1, 2),
    )

for (i_t, t) in enumerate(loads):
  # update boundary conditions

  u_.interpolate(lambda x: ( np.zeros_like(x[0]), t*np.ones_like(x[1])))
  u_.vector.ghostUpdate(addv=PETSc.InsertMode.INSERT,
                        mode=PETSc.ScatterMode.FORWARD)

  # update lower bound for damage
  alpha.vector.copy(alpha_lb.vector)
  alpha.vector.ghostUpdate(addv=PETSc.InsertMode.INSERT,
                        mode=PETSc.ScatterMode.FORWARD)

  # solve for current load step
  print(f"Solving timestep {i_t}, load: {t}")

  solver.solve()

  # postprocessing
  # global

  surface_energy = assemble_scalar(dolfinx.fem.form(model.damage_dissipation_density(state) * dx))

  elastic_energy = assemble_scalar(
        dolfinx.fem.form(model.elastic_energy_density(state) * dx))
  
  data.get('elastic').append(elastic_energy)
  data.get('surface').append(surface_energy)
  data.get('total').append(surface_energy+elastic_energy)
  data.get('load').append(t)

  print(f"Solved timestep {i_t}, load: {t}")
  print(f"Elastic Energy {elastic_energy:.3g}, Surface energy: {surface_energy:.3g}")
  print("\n\n")

  _plt = plot_scalar(alpha, plotter, subplot=(0, 0))
  _plt.screenshot(f"large_ell.png")
  if generateStepwiseOutput:
    if(surface_energy>1 and i_t%25==0):
    #if(i_t>1050 and i_t<1100):
        _plt = plot_scalar(alpha, plotter, subplot=(0, 0))
        #_plt.screenshot(f"./plots/s30/alpha"+str(i_t)+".png")
        _plt.screenshot(f"large_ell.png")
    #if i_t>1100:
    #    break
  if(i_t>20 and  elastic_energy<1E-3 and elastic_energy<surface_energy):
      #Brute force approach to determine, whether we have already reached a crack propagation state
      print("fail")
      break

  # savings?
# Out:
# Solving timestep 0, load: 0.0
#   0 SNES Function norm 0.000000000000e+00
#   0 SNES Function norm 0.000000000000e+00
# Solved timestep 0, load: 0.0
# Elastic Energy 0, Surface energy: 0
#
#
#
# Solving timestep 1, load: 0.1111111111111111
#   0 SNES Function norm 6.096634705445e-01
#   1 SNES Function norm 5.277503036139e-01
#   2 SNES Function norm 3.639239697527e-01
#   3 SNES Function norm 3.627130203021e-02
#   4 SNES Function norm 2.054088101804e-16
#   0 SNES Function norm 0.000000000000e+00
# Solved timestep 1, load: 0.1111111111111111
# Elastic Energy 0.00332, Surface energy: 0
#
#
#
# Solving timestep 2, load: 0.2222222222222222
#   0 SNES Function norm 6.096634705445e-01
#   1 SNES Function norm 4.877307764356e-01
#   2 SNES Function norm 2.438653882178e-01
#   3 SNES Function norm 5.081300539466e-16
#   0 SNES Function norm 0.000000000000e+00
# Solved timestep 2, load: 0.2222222222222222
# Elastic Energy 0.0133, Surface energy: 0
#
#
#
# Solving timestep 3, load: 0.3333333333333333
#   0 SNES Function norm 6.096634705445e-01
#   1 SNES Function norm 3.657980823267e-01
#   2 SNES Function norm 7.929997387064e-16
#   0 SNES Function norm 0.000000000000e+00
# Solved timestep 3, load: 0.3333333333333333
# Elastic Energy 0.0299, Surface energy: 0
#
#
#
# Solving timestep 4, load: 0.4444444444444444
#   0 SNES Function norm 6.096634705445e-01
#   1 SNES Function norm 2.438653882178e-01
#   2 SNES Function norm 8.147259977491e-16
#   0 SNES Function norm 2.740313430120e-04
#   1 SNES Function norm 8.809142651445e-20
#   0 SNES Function norm 1.696993524170e-04
#   1 SNES Function norm 8.069172017866e-16
#   0 SNES Function norm 4.000047794569e-06
# Solved timestep 4, load: 0.4444444444444444
# Elastic Energy 0.0531, Surface energy: 4.74e-06
#
#
#
# Solving timestep 5, load: 0.5555555555555556
#   0 SNES Function norm 6.096634705445e-01
#   1 SNES Function norm 1.219326941089e-01
#   2 SNES Function norm 9.098656287872e-16
#   0 SNES Function norm 5.212815174169e-04
#   1 SNES Function norm 2.509636504557e-04
#   2 SNES Function norm 5.050854533069e-05
#   3 SNES Function norm 1.836479947182e-19
#   0 SNES Function norm 6.345230604683e-04
#   1 SNES Function norm 1.021585950492e-15
#   0 SNES Function norm 2.577061977249e-05
#   1 SNES Function norm 1.613903423313e-19
#   0 SNES Function norm 3.505875184766e-05
#   1 SNES Function norm 8.877732647434e-16
#   0 SNES Function norm 1.518681251856e-06
# Solved timestep 5, load: 0.5555555555555556
# Elastic Energy 0.0829, Surface energy: 4.41e-05
#
#
#
# Solving timestep 6, load: 0.6666666666666666
#   0 SNES Function norm 6.096634705445e-01
#   1 SNES Function norm 1.665926361068e-15
#   0 SNES Function norm 8.314290110198e-04
#   1 SNES Function norm 4.434167638536e-04
#   2 SNES Function norm 1.027492009921e-04
#   3 SNES Function norm 5.178995229054e-19
#   0 SNES Function norm 1.541020145061e-03
#   1 SNES Function norm 1.197671843036e-15
#   0 SNES Function norm 1.050315372069e-04
#   1 SNES Function norm 2.753216257099e-05
#   2 SNES Function norm 6.298058784472e-19
#   0 SNES Function norm 2.251640761793e-04
#   1 SNES Function norm 1.134681425975e-15
#   0 SNES Function norm 1.548240326950e-05
#   1 SNES Function norm 3.377369337052e-06
#   0 SNES Function norm 3.372433996798e-05
#   1 SNES Function norm 1.168987119841e-15
#   0 SNES Function norm 4.220214705174e-06
# Solved timestep 6, load: 0.6666666666666666
# Elastic Energy 0.119, Surface energy: 0.000268
#
#
#
# Solving timestep 7, load: 0.7777777777777777
#   0 SNES Function norm 6.096634705445e-01
#   1 SNES Function norm 1.686206110547e-15
#   0 SNES Function norm 1.283060684689e-03
#   1 SNES Function norm 9.067016540250e-04
#   2 SNES Function norm 3.144003369430e-04
#   3 SNES Function norm 9.967079112495e-06
#   0 SNES Function norm 3.465387272492e-03
#   1 SNES Function norm 1.334152025090e-15
#   0 SNES Function norm 3.540502517311e-04
#   1 SNES Function norm 6.365737823568e-05
#   2 SNES Function norm 1.245732942237e-18
#   0 SNES Function norm 1.108074504870e-03
#   1 SNES Function norm 1.404371225442e-15
#   0 SNES Function norm 1.190285967210e-04
#   1 SNES Function norm 1.575222596831e-18
#   0 SNES Function norm 3.771470400398e-04
#   1 SNES Function norm 1.465277158058e-15
#   0 SNES Function norm 4.071151556606e-05
#   1 SNES Function norm 5.443299711303e-06
#   0 SNES Function norm 1.295791904531e-04
#   1 SNES Function norm 1.251022180292e-15
#   0 SNES Function norm 1.482628327151e-05
#   1 SNES Function norm 1.185900202890e-06
#   0 SNES Function norm 4.429810640978e-05
#   1 SNES Function norm 1.355462813116e-15
#   0 SNES Function norm 4.977147010205e-06
# Solved timestep 7, load: 0.7777777777777777
# Elastic Energy 0.161, Surface energy: 0.00154
#
#
#
# Solving timestep 8, load: 0.8888888888888888
#   0 SNES Function norm 6.096634705445e-01
#   1 SNES Function norm 1.645578365884e-15
#   0 SNES Function norm 2.068849847299e-03
#   1 SNES Function norm 1.988368013860e-03
#   2 SNES Function norm 5.217693822594e-04
#   3 SNES Function norm 3.506257698841e-05
#   4 SNES Function norm 3.678543166817e-18
#   0 SNES Function norm 7.334142539861e-03
#   1 SNES Function norm 1.513648947841e-15
#   0 SNES Function norm 1.197243829965e-03
#   1 SNES Function norm 4.097449556349e-04
#   2 SNES Function norm 1.042955016219e-04
#   3 SNES Function norm 4.829854672837e-18
#   0 SNES Function norm 5.106359892707e-03
#   1 SNES Function norm 1.400766741269e-15
#   0 SNES Function norm 9.250946383298e-04
#   1 SNES Function norm 3.978330496133e-04
#   2 SNES Function norm 3.997602936710e-07
#   0 SNES Function norm 4.669568144250e-03
#   1 SNES Function norm 1.435041426844e-15
#   0 SNES Function norm 9.101887035909e-04
#   1 SNES Function norm 2.679318075241e-04
#   2 SNES Function norm 5.925345590905e-18
#   0 SNES Function norm 4.707517907978e-03
#   1 SNES Function norm 1.395966584547e-15
#   0 SNES Function norm 9.913801679866e-04
#   1 SNES Function norm 1.862678071485e-04
#   2 SNES Function norm 6.263400177335e-18
#   0 SNES Function norm 5.056543770587e-03
#   1 SNES Function norm 1.452465702040e-15
#   0 SNES Function norm 1.136905045746e-03
#   1 SNES Function norm 2.368622139764e-04
#   2 SNES Function norm 8.781804267828e-18
#   0 SNES Function norm 5.664822980553e-03
#   1 SNES Function norm 1.420298707232e-15
#   0 SNES Function norm 1.368264132057e-03
#   1 SNES Function norm 2.455219389543e-04
#   2 SNES Function norm 6.153149030789e-06
#   0 SNES Function norm 6.620497404387e-03
#   1 SNES Function norm 1.296938514085e-15
#   0 SNES Function norm 1.732794256344e-03
#   1 SNES Function norm 3.791082637188e-04
#   2 SNES Function norm 1.055618554616e-17
#   0 SNES Function norm 8.018770035110e-03
#   1 SNES Function norm 1.281051213742e-15
#   0 SNES Function norm 2.305212713008e-03
#   1 SNES Function norm 1.768707954333e-05
#   2 SNES Function norm 1.252659954906e-17
#   0 SNES Function norm 1.005559174257e-02
#   1 SNES Function norm 1.352294887481e-15
#   0 SNES Function norm 3.227024045306e-03
#   1 SNES Function norm 3.167152288712e-04
#   2 SNES Function norm 5.128393106928e-06
#   0 SNES Function norm 1.290822712403e-02
#   1 SNES Function norm 1.384167817345e-15
#   0 SNES Function norm 4.790778319320e-03
#   1 SNES Function norm 7.341419631449e-04
#   2 SNES Function norm 1.988427089159e-17
#   0 SNES Function norm 1.675111942155e-02
#   1 SNES Function norm 1.299788930305e-15
#   0 SNES Function norm 7.579915227039e-03
#   1 SNES Function norm 3.315807149770e-04
#   2 SNES Function norm 2.241180339145e-17
#   0 SNES Function norm 2.137933666069e-02
#   1 SNES Function norm 1.283320712236e-15
#   0 SNES Function norm 1.262362311896e-02
#   1 SNES Function norm 2.453876061397e-04
#   2 SNES Function norm 2.250664516556e-17
#   0 SNES Function norm 2.533961842001e-02
#   1 SNES Function norm 1.339769809855e-15
#   0 SNES Function norm 2.109186545896e-02
#   1 SNES Function norm 8.380011081205e-05
#   2 SNES Function norm 2.840317822340e-17
#   0 SNES Function norm 2.548720114377e-02
#   1 SNES Function norm 1.094142509212e-15
#   0 SNES Function norm 3.080599829693e-02
#   1 SNES Function norm 4.687724733836e-04
#   2 SNES Function norm 3.023837295792e-17
#   0 SNES Function norm 1.899797717338e-02
#   1 SNES Function norm 1.255668305014e-15
#   0 SNES Function norm 3.014173752916e-02
#   1 SNES Function norm 5.925865552163e-04
#   2 SNES Function norm 5.126651031277e-17
#   0 SNES Function norm 9.282780491817e-03
#   1 SNES Function norm 1.240901571292e-15
#   0 SNES Function norm 2.044146764168e-02
#   1 SNES Function norm 2.578387847775e-04
#   2 SNES Function norm 6.449294576292e-17
#   0 SNES Function norm 5.274350768503e-03
#   1 SNES Function norm 1.212491397385e-15
#   0 SNES Function norm 9.004904366984e-03
#   1 SNES Function norm 2.410702114939e-05
#   2 SNES Function norm 7.583705153901e-17
#   0 SNES Function norm 1.460533152562e-03
#   1 SNES Function norm 1.197593739611e-15
#   0 SNES Function norm 2.305802905387e-03
#   1 SNES Function norm 1.124518605115e-16
#   0 SNES Function norm 3.739335208264e-04
#   1 SNES Function norm 1.217236884170e-15
#   0 SNES Function norm 1.049619226824e-03
#   1 SNES Function norm 7.808322106712e-17
#   0 SNES Function norm 2.981260208292e-04
#   1 SNES Function norm 1.212244110197e-15
#   0 SNES Function norm 1.172475257166e-03
#   1 SNES Function norm 9.585908866404e-17
#   0 SNES Function norm 3.623688697356e-04
#   1 SNES Function norm 1.330594144969e-15
#   0 SNES Function norm 1.497160479763e-03
#   1 SNES Function norm 6.771726807761e-17
#   0 SNES Function norm 4.882124445381e-04
#   1 SNES Function norm 1.268197237915e-15
#   0 SNES Function norm 2.064439870677e-03
#   1 SNES Function norm 8.187929211924e-17
#   0 SNES Function norm 7.111211656532e-04
#   1 SNES Function norm 1.158976625591e-15
#   0 SNES Function norm 3.004086804718e-03
#   1 SNES Function norm 8.614394601624e-17
#   0 SNES Function norm 1.074899652242e-03
#   1 SNES Function norm 1.199855881382e-15
#   0 SNES Function norm 4.234066857637e-03
#   1 SNES Function norm 8.518713376812e-17
#   0 SNES Function norm 1.464921908473e-03
#   1 SNES Function norm 1.276551557419e-15
#   0 SNES Function norm 4.611244520774e-03
#   1 SNES Function norm 2.026532172790e-04
#   2 SNES Function norm 9.632263543788e-17
#   0 SNES Function norm 1.252629215562e-03
#   1 SNES Function norm 1.275560642710e-15
#   0 SNES Function norm 2.739940205894e-03
#   1 SNES Function norm 2.228341007578e-06
#   0 SNES Function norm 5.313262822995e-04
#   1 SNES Function norm 1.339794576523e-15
#   0 SNES Function norm 9.435576234661e-04
#   1 SNES Function norm 1.200762334263e-16
#   0 SNES Function norm 1.462117847171e-04
#   1 SNES Function norm 1.205568322614e-15
#   0 SNES Function norm 2.466829172095e-04
#   1 SNES Function norm 8.783553766337e-17
#   0 SNES Function norm 3.509421976727e-05
#   1 SNES Function norm 1.183357942160e-15
#   0 SNES Function norm 5.899869379111e-05
#   1 SNES Function norm 1.205149679799e-16
#   0 SNES Function norm 8.146516864412e-06
#   1 SNES Function norm 1.242651299154e-15
#   0 SNES Function norm 1.376502511534e-05
#   1 SNES Function norm 7.107655402875e-17
#   0 SNES Function norm 1.877481628323e-06
#   1 SNES Function norm 1.296398921934e-15
#   0 SNES Function norm 3.188938737501e-06
# Solved timestep 8, load: 0.8888888888888888
# Elastic Energy 0.00319, Surface energy: 0.14
#
#
#
# Solving timestep 9, load: 1.0
#   0 SNES Function norm 6.096634705445e-01
#   1 SNES Function norm 1.510068234574e-15
#   0 SNES Function norm 9.248338176794e-03
#   1 SNES Function norm 2.597767322670e-05
#   2 SNES Function norm 1.321582016741e-16
#   0 SNES Function norm 7.798014280210e-04
#   1 SNES Function norm 1.310632216738e-15
#   0 SNES Function norm 1.348992099959e-03
#   1 SNES Function norm 1.198259223644e-16
#   0 SNES Function norm 1.134861227020e-04
#   1 SNES Function norm 1.265518424618e-15
#   0 SNES Function norm 2.087621328668e-04
#   1 SNES Function norm 1.204330471459e-16
#   0 SNES Function norm 1.797974028740e-05
#   1 SNES Function norm 1.183879388842e-15
#   0 SNES Function norm 3.453178864321e-05
#   1 SNES Function norm 1.123128212550e-16
#   0 SNES Function norm 3.009102349441e-06
#   1 SNES Function norm 1.282141618366e-15
#   0 SNES Function norm 5.878951089294e-06
# Solved timestep 9, load: 1.0
# Elastic Energy 0.00261, Surface energy: 0.141
#
#
#
# CPU times: user 1min 26s, sys: 1min 12s, total: 2min 38s
# Wall time: 3min 6s

# %%
plt.figure()
plt.plot(data.get('load'), data.get('surface'), label='surface')
plt.plot(data.get('load'), data.get('elastic'), label='elastic')
# plt.plot(data.get('load'), [1./2. * t**2*Lx for t in data.get('load')], label='anal elast', ls=':', c='k')

plt.title('Kinking in plate under traction energetics')
plt.legend()
# plt.yticks([0, 1/20], [0, '$1/2.\sigma_c^2/E_0$'])
plt.xticks([parameters.get('loading').get("min"), parameters.get('loading').get("max")], [0, parameters.get('loading').get("max")])
plt.savefig("energetics.png")

# # savings?
# plt.figure()
# plt.plot(data.get('load'), data.get('surface'), label='surface')
# plt.plot(data.get('load'), data.get('elastic'), label='elastic')

# plt.title('Last steps')
# plt.legend()
# plt.yticks([0, 1/20], [0, '$1/2.\sigma_c^2/E_0$'])
# plt.xticks([0, 1], [0, 1])
# plt.savefig("lastSteps.png")


#plotter = pyvista.Plotter(
       #  title="Displacement",
        # window_size=[1600, 600],
        # shape=(1, 2), )
#_plt = plot_scalar(u_.sub(0), plotter, subplot=(0, 0))
#_plt = plot_vector(u, plotter, subplot=(0, 1))
#_plt.screenshot(f"displacement_MPI.png")


 #xvfb.start_xvfb(wait=0.05)
 #pyvista.OFF_SCREEN = True

#plotter = pyvista.Plotter(
        # title="Displacement",
      # window_size=[1600, 600],
      #  shape=(1, 2),
   #  )
#
# _plt = plot_scalar(alpha, plotter, subplot=(0, 0))
#_plt.screenshot(f"alpha2.png")
