# %% [markdown]
# <a href="https://colab.research.google.com/github/kumiori/mec647/blob/Assala_T/angle45etagrande%C2%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
import sys

try:
    import google.colab  # noqa: F401
except ImportError:
    import ufl  # noqa: F401
    import dolfinx  # noqa: F401
else:
    try:
        import ufl
        import dolfinx
    except ImportError:
        # !wget "https://fem-on-colab.github.io/releases/fenicsx-install.sh" -O "/tmp/fenicsx-install.sh" && bash "/tmp/fenicsx-install.sh";
        import ufl  # noqa: F401
        import dolfinx  # noqa: F401

try:
    import pyvista
except ImportError:
    # !{sys.executable} -m pip install --upgrade pyvista itkwidgets;
    import pyvista  # noqa: F401
    from pyvista.utilities import xvfb

try:
    import gmsh
except ImportError:
    # !{sys.executable} -m pip install gmsh
    import gmsh

# !sudo apt install libgl1-mesa-glx xvfb;
# !{sys.executable} -m pip install pythreejs;
# !{sys.executable} -m pip install ipygany;
# !{sys.executable} -m pip install --upgrade PyYAML
# !pip install --ignore-installed PyYAML

# %%
branch_name = 'main'
# branch_name = 'Assala_T'

# !rm -rf mec647
try:
  # !git clone -b {branch_name} https://github.com/kumiori/mec647.git
  sys.path.append('mec647/')

  print()
  print(f'Cloned brach: {branch_name}')
  print(f'Last commit message')
  # !cd mec647/ && git log -n 1 && cd ..
  import mec647
  from mec647 import meshes
  from mec647.meshes import primitives
  # from mec647.algorithms import am
  from mec647.utils.viz import plot_mesh, plot_scalar, plot_vector

except Exception as e:
  print('Something went wrong', e)
  # !rm -rf mec647
  # !git clone https://github.com/kumiori/mec647.git
# Out:
# Cloning into 'mec647'...
# remote: Enumerating objects: 1258, done.
# remote: Counting objects: 100% (1258/1258), done.
# remote: Compressing objects: 100% (932/932), done.
# remote: Total 1258 (delta 642), reused 628 (delta 285), pack-reused 0
# Receiving objects: 100% (1258/1258), 19.70 MiB | 7.56 MiB/s, done.
# Resolving deltas: 100% (642/642), done.
#
# Cloned brach: main
# Last commit message
# commit 25aa48ad32b5c11d7dd6e087bdf09fea88442b28 (HEAD -> main, origin/main, origin/HEAD)
# Merge: 822d5b0 222efb0
# Author: igorassist <igorassist98@gmail.com>
# Date:   Sat Feb 26 14:14:34 2022 +0100
#
#     Merge branch 'main' of https://github.com/kumiori/mec647

# %%
import matplotlib.pyplot as plt
from petsc4py import PETSc
import numpy as np
from mpi4py import MPI

comm = MPI.COMM_WORLD

from dolfinx.fem import (
    Constant,
    Function,
    FunctionSpace,
    assemble_scalar,
    dirichletbc,
    form,
    locate_dofs_geometrical,
    set_bc,
)

# meshes
import meshes
from meshes import primitives

import models
from models import DamageElasticityModel as Brittle

# %%
import numpy as np
import yaml
import json
import sys
import os
from pathlib import Path

from mpi4py import MPI

import petsc4py
from petsc4py import PETSc

import dolfinx
import dolfinx.plot
from dolfinx import log
import ufl

import algorithms
from algorithms import am

from dolfinx.io import XDMFFile

import logging

logging.basicConfig(level=logging.INFO)

import dolfinx
import dolfinx.plot
import dolfinx.io
from dolfinx.fem import (
    Constant,
    Function,
    FunctionSpace,
    assemble_scalar,
    dirichletbc,
    form,
    locate_dofs_geometrical,
    set_bc,
)
import matplotlib.pyplot as plt
import pyvista 
from pyvista.utilities import xvfb


# visualisation
from utils import viz
import matplotlib.pyplot as plt
from utils.viz import plot_mesh, plot_vector, plot_scalar
generateStepwiseOutput=True

# %%
# Parameters
parameters = {
    'loading': {
        'min': 0.0,
        'max': 1.,
        'steps': 10
    },
    'geometry': {
        'geom_type': 'Plate with Kink',
        'Lx': .6,
        'Ly': 1, 
        'L0': 0.3,
        'theta': 45,
        'eta': 0.05,
    },
    'model': {
        'E': 3.e+9,
        'nu': 0.4,
        'w1': 1.,
        'ell': 0.1, 
        'k_res': 1.e-8
    },
    'solvers': {
          'elasticity': {        
            'snes': {
                'snes_type': 'newtontr',
                'snes_stol': 1e-8,
                'snes_atol': 1e-8,
                'snes_rtol': 1e-8,
                'snes_max_it': 250,
                'snes_monitor': "",
                'ksp_type': 'preonly',
                'pc_type': 'lu',
                'pc_factor_mat_solver_type': 'mumps'
            }
        },
          'damage': {        
            'snes': {
                'snes_type': 'vinewtonrsls',
                'snes_stol': 1e-5,
                'snes_atol': 1e-5,
                'snes_rtol': 1e-8,
                'snes_max_it': 100,
                'snes_monitor': "",
                'ksp_type': 'preonly',
                'pc_type': 'lu',
                'pc_factor_mat_solver_type': 'mumps'
            },
        },
          'damage_elasticity': {
            "max_it": 2000,
            "alpha_rtol": 1.0e-4,
            "criterion": "alpha_H1"
          }
    }
}

# %%
def  mesh_kink(name,
                Lx,
                Ly,
                # a,
                # b,
               rad,
               theta,
              # theta
                eta,
                lc,
                tdim,
                order=1,
                msh_file=None,
                comm=MPI.COMM_WORLD):
    """
    Create mesh of 3d tensile test specimen according to ISO 6892-1:2019 using the Python API of Gmsh.
    """
    # Perform Gmsh work only on rank = 0

    if comm.rank == 0:

        import gmsh

        # Initialise gmsh and set options
        gmsh.initialize()
        gmsh.option.setNumber("General.Terminal", 1)

        gmsh.option.setNumber("Mesh.Algorithm", 6)
        model = gmsh.model()
        model.add("Rectangle")
        model.setCurrent("Rectangle")
        # points = [p1, p2, p3, p4, p5, p6, p7, p8,p9,p10,p11]
        p1 = model.geo.addPoint(0.0, 0.0, 0, lc, tag=1)
        p2 = model.geo.addPoint(Lx, 0.0, 0, lc, tag=2)
        p3 = model.geo.addPoint(Lx, Ly, 0.0, lc, tag=3)
        p4 = model.geo.addPoint(0, Ly, 0, lc, tag=4)

        p5 = model.geo.addPoint(Lx/2 + rad*np.cos(theta), Ly/2 + rad*np.sin(theta), 0.0, lc/3, tag=5)
        p7 = model.geo.addPoint(Lx/2 - rad*np.cos(theta), Ly/2 - rad*np.sin(theta), 0.0, lc/3, tag=7)

        # p5 = model.geo.addPoint(Lx/2 +a, Ly/2 +b,0.0, lc/1.5, tag=5)
        p6 = model.geo.addPoint(Lx/2, Ly/2 + eta,0, lc, tag=6)
        # p7 = model.geo.addPoint(Lx/2-a,Ly/2-b,0,lc/1.5, tag=7)
        p8 = model.geo.addPoint(Lx/2,Ly/2 - eta,0, lc, tag=8)

        # Lines = [L1, L2, L3, L4, L5, L6, L7, L8]
        L1 = model.geo.addLine(p1, p2, tag=1)
        L2 = model.geo.addLine(p2, p3, tag=2)
        L3 = model.geo.addLine(p3, p4, tag=3)
        L4 = model.geo.addLine(p4, p1, tag=4)
        L5 = model.geo.addLine(p5, p6, tag=5)
        L6 = model.geo.addLine(p6, p7, tag=6)
        L7 = model.geo.addLine(p7, p8, tag=7)
        L8 = model.geo.addLine(p8, p5, tag=8)


        
        cloop1 = model.geo.addCurveLoop([L1, L2, L3, L4])
        cloop2 = model.geo.addCurveLoop([L5, L6, L7, L8])
        
        # surface_1 =
        model.geo.addPlaneSurface([cloop1, cloop2])

        model.geo.synchronize()
        surface_entities = [model[1] for model in model.getEntities(tdim)]

        model.addPhysicalGroup(tdim, surface_entities, tag=1)
        model.setPhysicalName(tdim, 1, "Rectangle surface")

        # Set mesh size via points
        # gmsh.model.mesh.setSize(points, lc)  # heuristic

        # gmsh.model.mesh.optimize("Netgen")

        # Set geometric order of mesh cells
        gmsh.model.mesh.setOrder(order)

        # Define physical groups for subdomains (! target tag > 0)
        # domain = 1
        # gmsh.model.addPhysicalGroup(tdim, [v[1] for v in volumes], domain)
        # gmsh.model.setPhysicalName(tdim, domain, 'domain')
              

        gmsh.model.addPhysicalGroup(tdim - 1, [1], tag=9)
        gmsh.model.setPhysicalName(tdim - 1, 9, "Bottom  of the Plate")
        gmsh.model.addPhysicalGroup(tdim - 1, [4], tag=10)
        gmsh.model.setPhysicalName(tdim - 1, 10, "Top  of the Plate")
        gmsh.model.addPhysicalGroup(tdim - 1, [5], tag=11)
        gmsh.model.setPhysicalName(tdim - 1, 11, "1/2 Top of the TipCrack")
        gmsh.model.addPhysicalGroup(tdim - 1, [6], tag=12)
        gmsh.model.setPhysicalName(tdim - 1, 12, "1/2 Top of the TipCrack")
        gmsh.model.addPhysicalGroup(tdim - 1, [7], tag=13)
        gmsh.model.setPhysicalName(tdim - 1, 13, "1/2 bottom of the TipCrack")
        gmsh.model.addPhysicalGroup(tdim - 1, [8], tag=14)
        gmsh.model.setPhysicalName(tdim - 1, 14, "1/2 bottom of the TipCrack")

        model.mesh.generate(tdim)


        #Generating the mesh
    model.geo.synchronize()
    model.mesh.generate(tdim)

    return gmsh.model

# %%
Lx = parameters.get("geometry").get("Lx")
Ly = parameters.get("geometry").get("Ly")
L0 = parameters.get("geometry").get("L0")
eta = parameters.get("geometry").get("eta")

geom_type = parameters.get("geometry").get("geom_type")

lc=0.02
theta = 45/180 * np.pi

gmsh_model=mesh_kink('mesh', Lx, Ly, L0/2, theta, eta,lc, 2, 1)

mesh, mts = meshes.gmsh_model_to_mesh(gmsh_model,
                               cell_data=False,
                               facet_data=True,
                               gdim=2)


plt.figure()
ax = plot_mesh(mesh)
fig = ax.get_figure()
fig.savefig(f"mesh.png")

# %%
# usedMesh=mesh 
# Enables opportunity to improve mesh at specific places, might lead to deformed elements
# Functional Setting

element_u = ufl.VectorElement("Lagrange", mesh.ufl_cell(),
                              degree=1, dim=2)

element_alpha = ufl.FiniteElement("Lagrange", mesh.ufl_cell(),
                              degree=1)

V_u = dolfinx.fem.FunctionSpace(mesh, element_u) 
V_alpha = dolfinx.fem.FunctionSpace(mesh, element_alpha) 

u = dolfinx.fem.Function(V_u, name="Displacement")
u_ = dolfinx.fem.Function(V_u, name="BoundaryDisplacement")


alpha = dolfinx.fem.Function(V_alpha, name="Damage")

# Pack state
state = {"u": u, "alpha": alpha}

# Bounds
alpha_ub = dolfinx.fem.Function(V_alpha, name="UpperBoundDamage")
alpha_lb = dolfinx.fem.Function(V_alpha, name="LowerBoundDamage")



dx = ufl.Measure("dx", domain = mesh)
ds = ufl.Measure("ds", domain = mesh)


# Boundary sets
dofs_alpha_left = locate_dofs_geometrical(V_alpha, lambda x: np.isclose(x[0], 0.))
dofs_alpha_right = locate_dofs_geometrical(V_alpha, lambda x: np.isclose(x[0], Lx))
dofs_alpha_bottom = locate_dofs_geometrical(V_alpha, lambda x: np.isclose(x[1], 0.))
dofs_alpha_top = locate_dofs_geometrical(V_alpha, lambda x: np.isclose(x[1], Ly))


dofs_u_left = locate_dofs_geometrical(V_u, lambda x: np.isclose(x[0], 0.))
dofs_u_right = locate_dofs_geometrical(V_u, lambda x: np.isclose(x[0], Lx))
dofs_u_top = locate_dofs_geometrical(V_u, lambda x: np.isclose(x[1], Ly))
dofs_u_bottom = locate_dofs_geometrical(V_u, lambda x: np.isclose(x[1], 0))

# Boundary data
u_.interpolate(lambda x: (np.zeros_like(x[0]), np.ones_like(x[1])))

# Bounds (nontrivial)
alpha_lb.interpolate(lambda x: np.zeros_like(x[0]))
alpha_ub.interpolate(lambda x: np.ones_like(x[0]))

# Boundary conditions
bcs_u = [
         dirichletbc(np.array([0., 0.], dtype=PETSc.ScalarType),
                      dofs_u_bottom,
                      V_u),
         dirichletbc(u_, dofs_u_top)
         ]

bcs_alpha = [
             dirichletbc(np.array(0., dtype = PETSc.ScalarType),
                         np.concatenate([dofs_alpha_bottom, dofs_alpha_top]),
                         V_alpha)
]

bcs = {"bcs_u": bcs_u, "bcs_alpha": bcs_alpha}

model = Brittle(parameters["model"])

total_energy = model.total_energy_density(state) * dx
solver = am.AlternateMinimisation(total_energy,
                         state,
                         bcs,
                         parameters.get("solvers"),
                         bounds=(alpha_lb, alpha_ub)
                         )

# %%
# %%time
# Loop for evolution
loads = np.linspace(parameters.get("loading").get("min"),
                    parameters.get("loading").get("max"),
                    parameters.get("loading").get("steps"))

data = {
    'elastic': [],
    'surface': [],
    'total': [],
    'load': []
}
xvfb.start_xvfb(wait=0.05)
pyvista.OFF_SCREEN = True
plotter = pyvista.Plotter(
        title="Displacement",
        window_size=[1600, 600],
        shape=(1, 2),
    )

for (i_t, t) in enumerate(loads):
  # update boundary conditions

  u_.interpolate(lambda x: ( np.zeros_like(x[0]), t*np.ones_like(x[1])))
  u_.vector.ghostUpdate(addv=PETSc.InsertMode.INSERT,
                        mode=PETSc.ScatterMode.FORWARD)

  # update lower bound for damage
  alpha.vector.copy(alpha_lb.vector)
  alpha.vector.ghostUpdate(addv=PETSc.InsertMode.INSERT,
                        mode=PETSc.ScatterMode.FORWARD)

  # solve for current load step
  print(f"Solving timestep {i_t}, load: {t}")

  solver.solve()

  # postprocessing
  # global

  surface_energy = assemble_scalar(dolfinx.fem.form(model.damage_dissipation_density(state) * dx))

  elastic_energy = assemble_scalar(
        dolfinx.fem.form(model.elastic_energy_density(state) * dx))
  
  data.get('elastic').append(elastic_energy)
  data.get('surface').append(surface_energy)
  data.get('total').append(surface_energy+elastic_energy)
  data.get('load').append(t)

  print(f"Solved timestep {i_t}, load: {t}")
  print(f"Elastic Energy {elastic_energy:.3g}, Surface energy: {surface_energy:.3g}")
  print("\n\n")

  _plt = plot_scalar(alpha, plotter, subplot=(0, 0))
  _plt.screenshot(f"large_ell.png")
  if generateStepwiseOutput:
    if(surface_energy>1 and i_t%25==0):
    #if(i_t>1050 and i_t<1100):
        _plt = plot_scalar(alpha, plotter, subplot=(0, 0))
        #_plt.screenshot(f"./plots/s30/alpha"+str(i_t)+".png")
        _plt.screenshot(f"large_ell.png")
    #if i_t>1100:
    #    break
  if(i_t>20 and  elastic_energy<1E-3 and elastic_energy<surface_energy):
      #Brute force approach to determine, whether we have already reached a crack propagation state
      print("fail")
      break

  # savings?
# Out:
# Solving timestep 0, load: 0.0
#   0 SNES Function norm 0.000000000000e+00
#   0 SNES Function norm 0.000000000000e+00
# Solved timestep 0, load: 0.0
# Elastic Energy 0, Surface energy: 0
#
#
#
# Solving timestep 1, load: 0.1111111111111111
#   0 SNES Function norm 9.481679379992e-01
#   1 SNES Function norm 8.918200430560e-01
#   2 SNES Function norm 7.791242531695e-01
#   3 SNES Function norm 5.537326733966e-01
#   4 SNES Function norm 1.029495138508e-01
#   5 SNES Function norm 4.795460099340e-16
#   0 SNES Function norm 0.000000000000e+00
# Solved timestep 1, load: 0.1111111111111111
# Elastic Energy 0.00326, Surface energy: 0
#
#
#
# Solving timestep 2, load: 0.2222222222222222
#   0 SNES Function norm 9.481679379992e-01
#   1 SNES Function norm 7.585343503994e-01
#   2 SNES Function norm 3.792671751997e-01
#   3 SNES Function norm 1.194384180163e-15
#   0 SNES Function norm 3.349202288098e-07
# Solved timestep 2, load: 0.2222222222222222
# Elastic Energy 0.013, Surface energy: 0
#
#
#
# Solving timestep 3, load: 0.3333333333333333
#   0 SNES Function norm 9.481679379992e-01
#   1 SNES Function norm 5.689007627995e-01
#   2 SNES Function norm 1.877780417009e-15
#   0 SNES Function norm 7.665976121628e-05
#   1 SNES Function norm 2.348251874717e-05
#   2 SNES Function norm 1.409590942065e-06
#   0 SNES Function norm 2.845253647445e-05
#   1 SNES Function norm 1.431341010838e-15
#   0 SNES Function norm 1.458900054481e-06
# Solved timestep 3, load: 0.3333333333333333
# Elastic Energy 0.0293, Surface energy: 4.95e-07
#
#
#
# Solving timestep 4, load: 0.4444444444444444
#   0 SNES Function norm 9.481679379992e-01
#   1 SNES Function norm 3.792671751997e-01
#   2 SNES Function norm 1.889637273152e-15
#   0 SNES Function norm 1.710743643477e-04
#   1 SNES Function norm 1.342076406325e-04
#   2 SNES Function norm 3.705224514040e-05
#   3 SNES Function norm 1.391399964803e-06
#   0 SNES Function norm 1.347027557811e-04
#   1 SNES Function norm 1.749148264742e-15
#   0 SNES Function norm 3.978039817566e-06
# Solved timestep 4, load: 0.4444444444444444
# Elastic Energy 0.0522, Surface energy: 7.62e-06
#
#
#
# Solving timestep 5, load: 0.5555555555555556
#   0 SNES Function norm 9.481679379992e-01
#   1 SNES Function norm 1.896335875998e-01
#   2 SNES Function norm 2.262536155998e-15
#   0 SNES Function norm 2.917779255543e-04
#   0 SNES Function norm 2.090551125220e-04
#   1 SNES Function norm 2.225344237465e-15
#   0 SNES Function norm 7.143522757687e-03
#   1 SNES Function norm 1.774022178370e-04
#   2 SNES Function norm 3.475266931944e-05
#   3 SNES Function norm 3.527765752792e-19
#   0 SNES Function norm 5.575553672553e-04
#   1 SNES Function norm 2.177906662608e-15
#   0 SNES Function norm 2.516343981601e-05
#   1 SNES Function norm 1.855512504431e-06
#   0 SNES Function norm 4.026189187073e-05
#   1 SNES Function norm 2.204435615694e-15
#   0 SNES Function norm 2.677292797715e-06
# Solved timestep 5, load: 0.5555555555555556
# Elastic Energy 0.0814, Surface energy: 6.45e-05
#
#
#
# Solving timestep 6, load: 0.6666666666666666
#   0 SNES Function norm 9.481679379992e-01
#   1 SNES Function norm 4.685596385792e-15
#   0 SNES Function norm 4.402676058572e-04
#   0 SNES Function norm 7.360293999300e-04
#   1 SNES Function norm 2.905447948158e-15
#   0 SNES Function norm 6.108601517961e-03
#   1 SNES Function norm 3.207758277862e-04
#   2 SNES Function norm 1.244086007830e-04
#   3 SNES Function norm 2.705627098312e-05
#   4 SNES Function norm 1.001349556865e-18
#   0 SNES Function norm 1.425652370600e-03
#   1 SNES Function norm 2.813552458590e-15
#   0 SNES Function norm 1.008211568033e-04
#   1 SNES Function norm 4.223900217608e-05
#   2 SNES Function norm 3.285204382355e-06
#   0 SNES Function norm 2.367364345852e-04
#   1 SNES Function norm 2.946839231582e-15
#   0 SNES Function norm 1.841635472772e-05
#   1 SNES Function norm 2.086894029856e-06
#   0 SNES Function norm 4.511894414766e-05
#   1 SNES Function norm 2.839070874671e-15
#   0 SNES Function norm 4.053457837527e-06
# Solved timestep 6, load: 0.6666666666666666
# Elastic Energy 0.117, Surface energy: 0.000392
#
#
#
# Solving timestep 7, load: 0.7777777777777777
#   0 SNES Function norm 9.481679379992e-01
#   1 SNES Function norm 3.718904297158e-15
#   0 SNES Function norm 6.625890147711e-04
#   0 SNES Function norm 2.118460727929e-03
#   1 SNES Function norm 3.190644324654e-15
#   0 SNES Function norm 4.974558132244e-03
#   1 SNES Function norm 6.691884369171e-04
#   2 SNES Function norm 3.250690962059e-04
#   3 SNES Function norm 6.343196350606e-05
#   4 SNES Function norm 1.466179765172e-06
#   0 SNES Function norm 3.060300950458e-03
#   1 SNES Function norm 3.235246155535e-15
#   0 SNES Function norm 3.264337262626e-04
#   1 SNES Function norm 1.937358261072e-04
#   2 SNES Function norm 1.183072371446e-05
#   3 SNES Function norm 3.634273148945e-18
#   0 SNES Function norm 1.046568722782e-03
#   1 SNES Function norm 3.245080509532e-15
#   0 SNES Function norm 1.230455506848e-04
#   1 SNES Function norm 8.759611223474e-05
#   2 SNES Function norm 6.106656445105e-06
#   0 SNES Function norm 4.222752939640e-04
#   1 SNES Function norm 3.251646289697e-15
#   0 SNES Function norm 5.170394651279e-05
#   1 SNES Function norm 2.352829085329e-05
#   2 SNES Function norm 3.568948577837e-18
#   0 SNES Function norm 1.805650398988e-04
#   1 SNES Function norm 3.322997732599e-15
#   0 SNES Function norm 2.227306267658e-05
#   1 SNES Function norm 4.177181689547e-18
#   0 SNES Function norm 7.898647398864e-05
#   1 SNES Function norm 3.298680490066e-15
#   0 SNES Function norm 9.747244645936e-06
# Solved timestep 7, load: 0.7777777777777777
# Elastic Energy 0.157, Surface energy: 0.00233
#
#
#
# Solving timestep 8, load: 0.8888888888888888
#   0 SNES Function norm 9.481679379992e-01
#   1 SNES Function norm 3.947944302378e-15
#   0 SNES Function norm 1.047907344638e-03
#   0 SNES Function norm 6.262143168440e-03
#   1 SNES Function norm 3.538402103434e-15
#   0 SNES Function norm 3.837648116617e-03
#   1 SNES Function norm 1.057289462807e-03
#   2 SNES Function norm 8.067560533099e-04
#   3 SNES Function norm 1.792896488315e-04
#   4 SNES Function norm 4.039020882028e-05
#   5 SNES Function norm 5.944798025471e-18
#   0 SNES Function norm 5.756766747397e-03
#   1 SNES Function norm 3.391504818473e-15
#   0 SNES Function norm 9.233688752078e-04
#   1 SNES Function norm 6.290300477164e-04
#   2 SNES Function norm 1.661732861183e-04
#   3 SNES Function norm 4.446495220451e-05
#   4 SNES Function norm 8.795965443344e-07
#   0 SNES Function norm 3.575774174948e-03
#   1 SNES Function norm 3.398027845229e-15
#   0 SNES Function norm 6.842951554459e-04
#   1 SNES Function norm 4.857876599460e-04
#   2 SNES Function norm 1.955041264137e-04
#   3 SNES Function norm 6.907627785081e-05
#   4 SNES Function norm 1.633382919013e-05
#   5 SNES Function norm 4.115564350775e-06
#   0 SNES Function norm 3.220103967531e-03
#   1 SNES Function norm 3.312980635534e-15
#   0 SNES Function norm 7.027425037539e-04
#   1 SNES Function norm 3.876018334884e-04
#   2 SNES Function norm 7.236979299457e-05
#   3 SNES Function norm 1.612008098008e-17
#   0 SNES Function norm 3.410158971957e-03
#   1 SNES Function norm 3.281272977299e-15
#   0 SNES Function norm 8.287137757046e-04
#   1 SNES Function norm 2.817062904481e-04
#   2 SNES Function norm 2.232019094541e-05
#   3 SNES Function norm 2.006742019545e-17
#   0 SNES Function norm 3.897318250269e-03
#   1 SNES Function norm 3.225865950394e-15
#   0 SNES Function norm 1.058385051261e-03
#   1 SNES Function norm 4.089444683148e-04
#   2 SNES Function norm 2.150378945756e-05
#   3 SNES Function norm 2.256723736536e-17
#   0 SNES Function norm 4.699691559708e-03
#   1 SNES Function norm 3.153362956600e-15
#   0 SNES Function norm 1.454324913188e-03
#   1 SNES Function norm 3.133905790903e-04
#   2 SNES Function norm 8.137601112360e-06
#   0 SNES Function norm 5.884365117969e-03
#   1 SNES Function norm 3.128145493515e-15
#   0 SNES Function norm 2.144607038733e-03
#   1 SNES Function norm 4.090710356668e-04
#   2 SNES Function norm 2.963038193446e-05
#   3 SNES Function norm 3.739241568672e-17
#   0 SNES Function norm 7.536125153911e-03
#   1 SNES Function norm 3.067720840309e-15
#   0 SNES Function norm 3.413902714933e-03
#   1 SNES Function norm 2.772998380597e-04
#   2 SNES Function norm 4.573810132042e-05
#   3 SNES Function norm 4.668340188371e-17
#   0 SNES Function norm 9.583171520963e-03
#   1 SNES Function norm 2.925356631039e-15
#   0 SNES Function norm 5.858633165654e-03
#   1 SNES Function norm 9.996751620710e-05
#   2 SNES Function norm 5.120083968565e-17
#   0 SNES Function norm 1.148654686429e-02
#   1 SNES Function norm 2.982713408012e-15
#   0 SNES Function norm 1.056156066859e-02
#   1 SNES Function norm 3.264068276643e-04
#   2 SNES Function norm 9.557862166625e-06
#   0 SNES Function norm 1.207234790604e-02
#   1 SNES Function norm 2.892947188794e-15
#   0 SNES Function norm 1.796635337725e-02
#   1 SNES Function norm 5.763865441341e-04
#   2 SNES Function norm 1.561534494284e-04
#   3 SNES Function norm 1.859071641752e-05
#   4 SNES Function norm 5.395975746249e-17
#   0 SNES Function norm 1.035012336725e-02
#   1 SNES Function norm 2.987244700986e-15
#   0 SNES Function norm 2.348641798165e-02
#   1 SNES Function norm 6.853289213071e-04
#   2 SNES Function norm 1.732794735101e-04
#   3 SNES Function norm 6.728139263350e-17
#   0 SNES Function norm 6.598779665062e-03
#   1 SNES Function norm 3.012868821806e-15
#   0 SNES Function norm 1.850566849070e-02
#   1 SNES Function norm 4.118226666150e-04
#   2 SNES Function norm 4.130916670138e-06
#   0 SNES Function norm 2.249029164733e-03
#   1 SNES Function norm 2.899288329059e-15
#   0 SNES Function norm 6.259416755171e-03
#   1 SNES Function norm 5.451703129458e-06
#   0 SNES Function norm 7.974551977667e-04
#   1 SNES Function norm 2.967023520900e-15
#   0 SNES Function norm 4.587275237199e-03
#   1 SNES Function norm 1.095513101769e-04
#   2 SNES Function norm 9.838270317621e-17
#   0 SNES Function norm 6.735067455836e-04
#   1 SNES Function norm 2.983290365828e-15
#   0 SNES Function norm 2.996498489191e-03
#   1 SNES Function norm 1.372634683863e-06
#   0 SNES Function norm 4.158811754222e-04
#   1 SNES Function norm 2.943718077260e-15
#   0 SNES Function norm 2.131577802524e-03
#   1 SNES Function norm 6.032763072449e-05
#   2 SNES Function norm 1.206936088886e-16
#   0 SNES Function norm 2.677104729486e-04
#   1 SNES Function norm 2.945750010167e-15
#   0 SNES Function norm 1.227173381088e-03
#   1 SNES Function norm 9.601527707768e-17
#   0 SNES Function norm 1.195332036167e-04
#   1 SNES Function norm 2.862409361830e-15
#   0 SNES Function norm 6.596253203816e-04
#   1 SNES Function norm 1.039873343606e-16
#   0 SNES Function norm 5.549108917300e-05
#   1 SNES Function norm 2.938009281422e-15
#   0 SNES Function norm 5.296899073226e-04
#   1 SNES Function norm 9.688841525418e-17
#   0 SNES Function norm 4.410640122047e-05
#   1 SNES Function norm 2.903521196219e-15
#   0 SNES Function norm 4.945313089403e-04
#   1 SNES Function norm 1.010439908972e-16
#   0 SNES Function norm 3.891560500047e-05
#   1 SNES Function norm 2.937660266020e-15
#   0 SNES Function norm 4.227134933413e-04
#   1 SNES Function norm 9.792758591686e-17
#   0 SNES Function norm 3.068511978304e-05
#   1 SNES Function norm 2.866827326737e-15
#   0 SNES Function norm 3.171510212415e-04
#   1 SNES Function norm 9.376072149525e-17
#   0 SNES Function norm 2.127292231162e-05
#   1 SNES Function norm 2.908340503820e-15
#   0 SNES Function norm 2.109296978765e-04
#   1 SNES Function norm 1.042695212213e-16
#   0 SNES Function norm 1.328582543248e-05
#   1 SNES Function norm 2.906868889445e-15
#   0 SNES Function norm 1.279223531102e-04
#   1 SNES Function norm 1.246094794890e-16
#   0 SNES Function norm 7.719719542194e-06
#   1 SNES Function norm 2.879328299764e-15
#   0 SNES Function norm 7.294903340245e-05
#   1 SNES Function norm 9.494168091412e-17
#   0 SNES Function norm 4.288386122260e-06
#   1 SNES Function norm 2.879834529487e-15
#   0 SNES Function norm 4.007490355926e-05
#   1 SNES Function norm 1.217594474756e-16
#   0 SNES Function norm 2.320769873207e-06
#   1 SNES Function norm 2.848292251517e-15
#   0 SNES Function norm 2.155097681249e-05
#   1 SNES Function norm 1.174660158478e-16
#   0 SNES Function norm 1.237777226960e-06
#   1 SNES Function norm 2.849989511661e-15
#   0 SNES Function norm 1.145424982992e-05
#   1 SNES Function norm 1.097421065186e-16
#   0 SNES Function norm 6.549611653868e-07
#   1 SNES Function norm 2.885618747273e-15
#   0 SNES Function norm 6.049528611468e-06
# Solved timestep 8, load: 0.8888888888888888
# Elastic Energy 0.00166, Surface energy: 0.128
#
#
#
# Solving timestep 9, load: 1.0
#   0 SNES Function norm 9.481679379992e-01
#   1 SNES Function norm 3.448854275420e-15
#   0 SNES Function norm 5.397995406760e-03
#   1 SNES Function norm 1.174659725641e-04
#   2 SNES Function norm 1.215509811585e-16
#   0 SNES Function norm 2.472747173483e-04
#   1 SNES Function norm 2.875838641327e-15
#   0 SNES Function norm 1.032137513541e-03
#   1 SNES Function norm 1.364516586296e-16
#   0 SNES Function norm 4.741540817484e-05
#   1 SNES Function norm 2.781532716519e-15
#   0 SNES Function norm 2.643984488237e-04
#   1 SNES Function norm 8.562718756126e-06
#   0 SNES Function norm 1.076359163604e-05
#   1 SNES Function norm 2.827246758116e-15
#   0 SNES Function norm 7.430570066811e-05
#   1 SNES Function norm 1.465957203843e-16
#   0 SNES Function norm 2.543462825666e-06
#   1 SNES Function norm 2.933195015706e-15
#   0 SNES Function norm 1.795954862968e-05
#   1 SNES Function norm 1.462143165908e-16
#   0 SNES Function norm 5.989399656436e-07
#   1 SNES Function norm 2.997629125351e-15
#   0 SNES Function norm 4.474209643919e-06
# Solved timestep 9, load: 1.0
# Elastic Energy 0.00139, Surface energy: 0.129
#
#
#
# CPU times: user 1min 51s, sys: 1min 18s, total: 3min 10s
# Wall time: 3min 3s

# %%
plt.figure()
plt.plot(data.get('load'), data.get('surface'), label='surface')
plt.plot(data.get('load'), data.get('elastic'), label='elastic')
# plt.plot(data.get('load'), [1./2. * t**2*Lx for t in data.get('load')], label='anal elast', ls=':', c='k')

plt.title('Kinking in plate under traction energetics')
plt.legend()
# plt.yticks([0, 1/20], [0, '$1/2.\sigma_c^2/E_0$'])
plt.xticks([parameters.get('loading').get("min"), parameters.get('loading').get("max")], [0, parameters.get('loading').get("max")])
plt.savefig("energetics.png")

# # savings?
# plt.figure()
# plt.plot(data.get('load'), data.get('surface'), label='surface')
# plt.plot(data.get('load'), data.get('elastic'), label='elastic')

# plt.title('Last steps')
# plt.legend()
# plt.yticks([0, 1/20], [0, '$1/2.\sigma_c^2/E_0$'])
# plt.xticks([0, 1], [0, 1])
# plt.savefig("lastSteps.png")


#plotter = pyvista.Plotter(
       #  title="Displacement",
        # window_size=[1600, 600],
        # shape=(1, 2), )
#_plt = plot_scalar(u_.sub(0), plotter, subplot=(0, 0))
#_plt = plot_vector(u, plotter, subplot=(0, 1))
#_plt.screenshot(f"displacement_MPI.png")


 #xvfb.start_xvfb(wait=0.05)
 #pyvista.OFF_SCREEN = True

#plotter = pyvista.Plotter(
        # title="Displacement",
      # window_size=[1600, 600],
      #  shape=(1, 2),
   #  )
#
# _plt = plot_scalar(alpha, plotter, subplot=(0, 0))
#_plt.screenshot(f"alpha2.png")
