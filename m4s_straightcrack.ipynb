# %% [markdown]
# <a href="https://colab.research.google.com/github/kumiori/mec647/blob/main/m4s_straightcrack.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import site
import sys


try : 
    from google.colab import files
except:
    pass
    
try:
    from fenics import *; from mshr import *
except ImportError as e:
    # !apt-get install software-properties-common
    # !add-apt-repository -y ppa:fenics-packages/fenics
    # !apt-get update -qq
    # !apt install -y fenics    
    site.addsitedir('/usr/lib/petsc/lib/python3/dist-packages')  # Always appends to end

    from fenics import *; from mshr import *
    from ufl import replace

# !fenics-version
# Out:
# 2019.2.0.dev0

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Geometry


Lx = 1; Ly = 3.
h = .3; a = .2 


plate = Rectangle(Point(-Lx/2, -Ly/2), Point(Lx/2, Ly/2))

notchVertices = [Point(-Lx/2, -a/2), Point(-Lx/2 +h , 0.), Point(-Lx/2 , a/2)]
notch = Polygon(notchVertices)

domain = plate - notch

cellSize = .05
nel = Lx / cellSize
mesh   = generate_mesh(domain, nel)

# %%
plt.figure(figsize=(10, 8))
plot(mesh)
# Out:
# [<matplotlib.lines.Line2D at 0x7f50557e6278>,
#  <matplotlib.lines.Line2D at 0x7f50557e65c0>]

# %%
ndim = mesh.topology().dim()

cell_mrk = MeshFunction('bool', mesh, ndim)
cell_mrk.set_all(False)

# %%
ref_threshold = 0.3

for cell in cells(mesh):
  if -ref_threshold < cell.midpoint()[1] < ref_threshold:
    cell_mrk[cell] = True

plot(cell_mrk)

for i in range(2): mesh = refine(mesh, cell_mrk)
# mesh = refine(mesh, cell_mrk)

# %%
plot(mesh)
# Out:
# [<matplotlib.lines.Line2D at 0x7f50556a2128>,
#  <matplotlib.lines.Line2D at 0x7f50556a22b0>]

# %%
# Functional setting


V_u = VectorFunctionSpace(mesh, 'CG', 1)
V_alpha = FunctionSpace(mesh, 'CG', 1)

u = Function(V_u)
du = TrialFunction(V_u)
v = TestFunction(V_u)

alpha = Function(V_alpha)
beta = TestFunction(V_alpha)
dalpha = TrialFunction(V_alpha)

# %%
# Boundary conditions

ut = Expression('t', t=0., degree=0)

bcs_u = [DirichletBC(V_u.sub(1), ut, 'near(x[1], {}, 1e-5)'.format(Ly/2)), 
         DirichletBC(V_u.sub(1), Constant(0.), 'near(x[1], {}, 1e-5)'.format(-Ly/2))]



bca_0 = DirichletBC(V_alpha, Constant(0.), 'near(x[1], {}, 1e-5)'.format(Ly/2))
bca_1 = DirichletBC(V_alpha, Constant(0.), 'near(x[1], {}, 1e-5)'.format(-Ly/2))

bc_alpha = [bca_0, bca_1]

# %%
# Constitutive

# Constitutive functions

E, nu = Constant(1.), Constant(.0)
Gc = Constant(1.)
ell = Constant(0.05)

ndim = mesh.topology().dim()

def w(alpha):
  return alpha

def a(alpha):
  return (1-alpha)**2

def eps(u):
  return sym(grad(u))

def sigma0(u):
  mu = E/(2.*(1.+nu))
  lmbda = E*nu/(1-nu**2.)
  return 2*mu*eps(u) + lmbda*tr(eps(u))*Identity(ndim)

def sigma(alpha, u):
  return a(alpha)*sigma0(u)

# %%
import sympy

s = sympy.Symbol('s')
cw = float(sympy.integrate(4*sympy.sqrt(w(s)), (s, 0, 1)))


tmp = 2*(sympy.diff(w(s),s)/sympy.diff(1/a(s),s)).subs({"s":0})

print("Gc = %2.3f"%((ell*cw)/tmp))

Gc = Constant((ell*cw)/tmp)
# Out:
# Gc = 0.133

# %%
# Energetics


elastic_energy = 0.5*inner(sigma(alpha, u), eps(u))*dx
dissipated_energy = Gc/cw * (w(alpha)/ell + ell* inner(grad(alpha), grad(alpha)))*dx

total_energy = elastic_energy + dissipated_energy 

E_u = derivative(total_energy, u, v)

from ufl import replace
E_du = replace(E_u, {u: du})

E_alpha = derivative(total_energy, alpha, beta)
E_alpha_alpha = derivative(E_alpha,alpha, dalpha)

# %%
# Solve displacement problem, using automated derivative, and autmated 
# construction of linear and bilinear forms

# problem_u = LinearVariationalProblem()
problem_u = LinearVariationalProblem(lhs(E_du), rhs(E_du), u, bcs_u)
solver_u = LinearVariationalSolver(problem_u)
solver_u.parameters.update({"linear_solver" : "umfpack"})

# Alternatively, compute explicitly:

A = inner(sigma(alpha, du), eps(v))*dx
# f0, g0 exist in L^2(\Omega), L^2(\partial\Omega)
# L = dot(f0, v)*dx + dot(g0, v)*ds
zero = project(Constant((0., 0.)), V_u)
L = dot(zero, v)*dx

problem_u = LinearVariationalProblem(A, L, u, bcs_u)

# %%
# u = TrialFunction(V_u)
ut.t = .1
solver_u.solve()

# %%
# dir(plot, mo)
plot(dot(u,u))

# %%
# Bounds

upperbound = project(Constant(1.), V_alpha)
lowerbound = project(Constant(0.), V_alpha)

# Boundary conditions
# set damage = 0 where we impose displacement boundary conditions

# bc_a1 = DirichletBC(V_alpha, Constant(0.), left)
# bc_a2 = DirichletBC(V_alpha, Constant(0.), right)

# bc_a = [bc_a1, bc_a2]

# Nonlinear problem and solver

problem_alpha = NonlinearVariationalProblem(E_alpha, alpha, bc_alpha, J=E_alpha_alpha)
problem_alpha.set_bounds(lowerbound, upperbound)

# solver able to solve with bounds: SNES

solver_alpha = NonlinearVariationalSolver(problem_alpha)
# info(solver_alpha.parameters, True)

snes_solver_parameters_bounds = {"nonlinear_solver": "snes", 
                                 "snes_solver": {"maximum_iterations": 300,
                                                 "absolute_tolerance": 1e-10,
                                                 "relative_tolerance": 1e-5,
                                                 "solution_tolerance": 1e-5,
                                                 "report": True,
                                                 "linear_solver" : "mumps"
                                                 }
                                }


# Solver method  |  Description                                                 
# ------------------------------------------------------------------------------
# bicgstab       |  Biconjugate gradient stabilized method                      
# cg             |  Conjugate gradient method                                   
# default        |  default linear solver                                       
# gmres          |  Generalized minimal residual method                         
# minres         |  Minimal residual method                                     
# mumps          |  MUMPS (MUltifrontal Massively Parallel Sparse direct Solver)
# petsc          |  PETSc built in LU solver                                    
# richardson     |  Richardson method                                           
# superlu        |  SuperLU                                                     
# tfqmr          |  Transpose-free quasi-minimal residual method                
# umfpack        |  UMFPACK (Unsymmetric MultiFrontal sparse LU factorization)  

solver_alpha.parameters.update(snes_solver_parameters_bounds)

solver_alpha.solve()
# Out:
# (0, True)

# %%
# boundaries
top = CompiledSubDomain("near(x[1], {}, 1e-4)".format(Ly/2.))
bottom = CompiledSubDomain("near(x[1], {}, 1e-4)".format(-Ly/2.))

right = CompiledSubDomain("near(x[0], {}, 1e-4)".format(Lx/2.))

boundaries = MeshFunction("size_t", mesh, 1)
boundaries.set_all(0)
top.mark(boundaries, 1) # mark top as 1
bottom.mark(boundaries, 2) # mark bottom as 2
right.mark(boundaries, 3) # mark right as 3
ds = Measure("ds",subdomain_data=boundaries) # top: ds(1), bottom: ds(2), right

# %%
def alternate_minimisation(alpha, u,
                           alpha_0 = project(Constant(0.), V_alpha),
                           tol=1e-5, maxiter=100):
  alpha_diff = Function(V_alpha)
  iter = 1; error = 1
  alpha.vector()[:] = alpha_0.vector()
  
  while iter < maxiter and error > tol:
    solver_u.solve()
    # u: solution

    solver_alpha.solve()
    # alpha: solution
    # alpha0: alpha at previous timestep

    alpha_diff.vector()[:] = alpha.vector() - alpha_0.vector()
    error = norm(alpha_diff.vector(), 'l2')
    print("Iteration %d, error %e, alpha_max=%.3f"%(iter, error, max(alpha.vector())))
    alpha_0.assign(alpha)

    iter = iter+1

  return (iter, error)

# %%
# alpha = Function(V_alpha)
# ut.t = 4.
# alternate_minimisation(alpha, u)

# %%
plot(alpha)

# %%
def postprocess():
    tot_en.append(assemble(total_energy))
    sur_en.append(assemble(dissipated_energy))
    ela_en.append(assemble(elastic_energy))
    # assemble(sigma(alpha, u)[1,1]*ds(1))
    react_top.append(assemble(sigma(alpha,u)[1,1]*ds(1)))
    print("** elastic = {:.3f}, surface = {:.3f}, total = {:.3f}"
      .format(ela_en[-1], sur_en[-1], tot_en[-1]))
    print("** Converged in {:d} iterations, error = {:.3f}"
      .format(iter, error))

# %%
import os
import shutil

savedir = "results/plate"
if os.path.isdir(savedir):
    shutil.rmtree(savedir)
    
file_alpha = File(savedir+"/alpha.pvd") 
file_u = File(savedir+"/u.pvd")

# %%
file_u << u

# %%
# Evolution monotonically increasing load

loads = np.linspace(.0, 2.5, 30)

energies = []

tot_en = []
sur_en = []
ela_en = []
react_top = []

for (i, t) in enumerate(loads):
  ut.t = t
  print('')
  print("** Load step: t=%.2f"%t)
  (iter, error) = alternate_minimisation(alpha, u, maxiter=200)
  lowerbound.vector()[:] = alpha.vector()
  # postproc
  postprocess()


energies = {'elastic': ela_en, 'surface': sur_en, 'total': tot_en}
# Out:
# ** Load step: t=0.00
# Iteration 1, error 0.000000e+00, alpha_max=0.000
# ** elastic = 0.000, surface = 0.000, total = 0.000
# ** Converged in 2 iterations, error = 0.000
#
# ** Load step: t=0.09
# Iteration 1, error 0.000000e+00, alpha_max=0.000
# ** elastic = 0.001, surface = 0.000, total = 0.001
# ** Converged in 2 iterations, error = 0.000
#
# ** Load step: t=0.17
# Iteration 1, error 0.000000e+00, alpha_max=0.000
# ** elastic = 0.004, surface = 0.000, total = 0.004
# ** Converged in 2 iterations, error = 0.000
#
# ** Load step: t=0.26
# Iteration 1, error 0.000000e+00, alpha_max=0.000
# ** elastic = 0.010, surface = 0.000, total = 0.010
# ** Converged in 2 iterations, error = 0.000
#
# ** Load step: t=0.34
# Iteration 1, error 0.000000e+00, alpha_max=0.000
# ** elastic = 0.018, surface = 0.000, total = 0.018
# ** Converged in 2 iterations, error = 0.000
#
# ** Load step: t=0.43
# Iteration 1, error 0.000000e+00, alpha_max=0.000
# ** elastic = 0.028, surface = 0.000, total = 0.028
# ** Converged in 2 iterations, error = 0.000
#
# ** Load step: t=0.52
# Iteration 1, error 0.000000e+00, alpha_max=0.000
# ** elastic = 0.040, surface = 0.000, total = 0.040
# ** Converged in 2 iterations, error = 0.000
#
# ** Load step: t=0.60
# Iteration 1, error 0.000000e+00, alpha_max=0.000
# ** elastic = 0.054, surface = 0.000, total = 0.054
# ** Converged in 2 iterations, error = 0.000
#
# ** Load step: t=0.69
# Iteration 1, error 0.000000e+00, alpha_max=0.000
# ** elastic = 0.070, surface = 0.000, total = 0.070
# ** Converged in 2 iterations, error = 0.000
#
# ** Load step: t=0.78
# Iteration 1, error 0.000000e+00, alpha_max=0.000
# ** elastic = 0.089, surface = 0.000, total = 0.089
# ** Converged in 2 iterations, error = 0.000
#
# ** Load step: t=0.86
# Iteration 1, error 0.000000e+00, alpha_max=0.000
# ** elastic = 0.110, surface = 0.000, total = 0.110
# ** Converged in 2 iterations, error = 0.000
#
# ** Load step: t=0.95
# Iteration 1, error 9.737820e-03, alpha_max=0.008
# Iteration 2, error 1.534994e-03, alpha_max=0.009
# Iteration 3, error 2.435945e-04, alpha_max=0.009
# Iteration 4, error 3.862066e-05, alpha_max=0.009
# Iteration 5, error 6.121858e-06, alpha_max=0.009
# ** elastic = 0.133, surface = 0.000, total = 0.133
# ** Converged in 6 iterations, error = 0.000
#
# ** Load step: t=1.03
# Iteration 1, error 3.680432e-02, alpha_max=0.039
# Iteration 2, error 6.916594e-03, alpha_max=0.044
# Iteration 3, error 1.367701e-03, alpha_max=0.045
# Iteration 4, error 2.690738e-04, alpha_max=0.046
# Iteration 5, error 5.284452e-05, alpha_max=0.046
# Iteration 6, error 1.038751e-05, alpha_max=0.046
# Iteration 7, error 2.043857e-06, alpha_max=0.046
# ** elastic = 0.158, surface = 0.000, total = 0.158
# ** Converged in 8 iterations, error = 0.000
#
# ** Load step: t=1.12
# Iteration 1, error 5.006627e-02, alpha_max=0.083
# Iteration 2, error 1.496961e-02, alpha_max=0.093
# Iteration 3, error 5.026526e-03, alpha_max=0.096
# Iteration 4, error 1.672104e-03, alpha_max=0.097
# Iteration 5, error 5.556212e-04, alpha_max=0.097
# Iteration 6, error 1.845625e-04, alpha_max=0.097
# Iteration 7, error 6.130087e-05, alpha_max=0.097
# Iteration 8, error 2.035889e-05, alpha_max=0.097
# Iteration 9, error 6.761251e-06, alpha_max=0.097
# ** elastic = 0.185, surface = 0.000, total = 0.186
# ** Converged in 10 iterations, error = 0.000
#
# ** Load step: t=1.21
# Iteration 1, error 8.514973e-02, alpha_max=0.146
# Iteration 2, error 4.303209e-02, alpha_max=0.168
# Iteration 3, error 2.375464e-02, alpha_max=0.180
# Iteration 4, error 1.415843e-02, alpha_max=0.187
# Iteration 5, error 8.521876e-03, alpha_max=0.191
# Iteration 6, error 5.168956e-03, alpha_max=0.194
# Iteration 7, error 3.149389e-03, alpha_max=0.195
# Iteration 8, error 1.923944e-03, alpha_max=0.196
# Iteration 9, error 1.206488e-03, alpha_max=0.197
# Iteration 10, error 7.826426e-04, alpha_max=0.197
# Iteration 11, error 5.056766e-04, alpha_max=0.198
# Iteration 12, error 3.267831e-04, alpha_max=0.198
# Iteration 13, error 2.112485e-04, alpha_max=0.198
# Iteration 14, error 1.365859e-04, alpha_max=0.198
# Iteration 15, error 8.832133e-05, alpha_max=0.198
# Iteration 16, error 5.711560e-05, alpha_max=0.198
# Iteration 17, error 3.693707e-05, alpha_max=0.198
# Iteration 18, error 2.388811e-05, alpha_max=0.198
# Iteration 19, error 1.544930e-05, alpha_max=0.198
# Iteration 20, error 9.991729e-06, alpha_max=0.198
# ** elastic = 0.214, surface = 0.001, total = 0.215
# ** Converged in 21 iterations, error = 0.000
#
# ** Load step: t=1.29
# Iteration 1, error 1.397358e-01, alpha_max=0.259
# Iteration 2, error 1.014596e-01, alpha_max=0.305
# Iteration 3, error 8.652060e-02, alpha_max=0.342
# Iteration 4, error 7.964564e-02, alpha_max=0.373
# Iteration 5, error 7.423737e-02, alpha_max=0.401
# Iteration 6, error 7.185943e-02, alpha_max=0.428
# Iteration 7, error 7.359567e-02, alpha_max=0.453
# Iteration 8, error 7.737659e-02, alpha_max=0.479
# Iteration 9, error 8.415290e-02, alpha_max=0.506
# Iteration 10, error 9.450628e-02, alpha_max=0.536
# Iteration 11, error 1.079387e-01, alpha_max=0.568
# Iteration 12, error 1.267574e-01, alpha_max=0.604
# Iteration 13, error 1.536870e-01, alpha_max=0.645
# Iteration 14, error 1.951937e-01, alpha_max=0.693
# Iteration 15, error 2.443773e-01, alpha_max=0.749
# Iteration 16, error 3.074588e-01, alpha_max=0.810
# Iteration 17, error 3.649644e-01, alpha_max=0.871
# Iteration 18, error 3.996339e-01, alpha_max=0.919
# Iteration 19, error 4.110762e-01, alpha_max=0.950
# Iteration 20, error 4.206629e-01, alpha_max=0.966
# Iteration 21, error 4.178061e-01, alpha_max=0.991
# Iteration 22, error 4.313948e-01, alpha_max=1.000
# Iteration 23, error 4.450139e-01, alpha_max=1.000
# Iteration 24, error 4.704673e-01, alpha_max=1.000
# Iteration 25, error 5.017926e-01, alpha_max=1.000
# Iteration 26, error 4.994412e-01, alpha_max=1.000
# Iteration 27, error 5.098496e-01, alpha_max=1.000
# Iteration 28, error 5.363912e-01, alpha_max=1.000
# Iteration 29, error 5.380796e-01, alpha_max=1.000
# Iteration 30, error 5.496757e-01, alpha_max=1.000
# Iteration 31, error 5.378692e-01, alpha_max=1.000
# Iteration 32, error 5.055231e-01, alpha_max=1.000
# Iteration 33, error 4.747591e-01, alpha_max=1.000
# Iteration 34, error 4.693588e-01, alpha_max=1.000
# Iteration 35, error 4.962405e-01, alpha_max=1.000
# Iteration 36, error 4.097659e-01, alpha_max=1.000
# Iteration 37, error 3.546327e-01, alpha_max=1.000
# Iteration 38, error 3.217099e-01, alpha_max=1.000
# Iteration 39, error 2.997341e-01, alpha_max=1.000
# Iteration 40, error 3.104753e-01, alpha_max=1.000
# Iteration 41, error 3.270429e-01, alpha_max=1.000
# Iteration 42, error 4.861466e-01, alpha_max=1.000
# Iteration 43, error 7.855225e-01, alpha_max=1.000
# Iteration 44, error 1.021303e+00, alpha_max=1.000
# Iteration 45, error 6.062451e-01, alpha_max=1.000
# Iteration 46, error 7.210514e-01, alpha_max=1.000
# Iteration 47, error 7.752943e-01, alpha_max=1.000
# Iteration 48, error 5.611743e-04, alpha_max=1.000
# Iteration 49, error 2.552489e-05, alpha_max=1.000
# Iteration 50, error 2.156965e-06, alpha_max=1.000
# ** elastic = 0.001, surface = 0.136, total = 0.137
# ** Converged in 51 iterations, error = 0.000
#
# ** Load step: t=1.38
# Iteration 1, error 9.528277e-03, alpha_max=1.000
# Iteration 2, error 1.634565e-04, alpha_max=1.000
# Iteration 3, error 3.908813e-06, alpha_max=1.000
# ** elastic = 0.001, surface = 0.137, total = 0.137
# ** Converged in 4 iterations, error = 0.000
#
# ** Load step: t=1.47
# Iteration 1, error 7.956576e-03, alpha_max=1.000
# Iteration 2, error 1.087256e-04, alpha_max=1.000
# Iteration 3, error 2.143588e-06, alpha_max=1.000
# ** elastic = 0.001, surface = 0.137, total = 0.137
# ** Converged in 4 iterations, error = 0.000
#
# ** Load step: t=1.55
# Iteration 1, error 6.710451e-03, alpha_max=1.000
# Iteration 2, error 8.510102e-05, alpha_max=1.000
# Iteration 3, error 1.217272e-06, alpha_max=1.000
# ** elastic = 0.001, surface = 0.137, total = 0.137
# ** Converged in 4 iterations, error = 0.000
#
# ** Load step: t=1.64
# Iteration 1, error 5.712590e-03, alpha_max=1.000
# Iteration 2, error 6.145851e-05, alpha_max=1.000
# Iteration 3, error 2.048431e-06, alpha_max=1.000
# ** elastic = 0.001, surface = 0.137, total = 0.138
# ** Converged in 4 iterations, error = 0.000
#
# ** Load step: t=1.72
# Iteration 1, error 4.903966e-03, alpha_max=1.000
# Iteration 2, error 3.707262e-05, alpha_max=1.000
# Iteration 3, error 5.849556e-07, alpha_max=1.000
# ** elastic = 0.000, surface = 0.137, total = 0.138
# ** Converged in 4 iterations, error = 0.000
#
# ** Load step: t=1.81
# Iteration 1, error 4.239891e-03, alpha_max=1.000
# Iteration 2, error 2.674791e-05, alpha_max=1.000
# Iteration 3, error 3.892846e-07, alpha_max=1.000
# ** elastic = 0.000, surface = 0.137, total = 0.138
# ** Converged in 4 iterations, error = 0.000
#
# ** Load step: t=1.90
# Iteration 1, error 3.689545e-03, alpha_max=1.000
# Iteration 2, error 2.664780e-05, alpha_max=1.000
# Iteration 3, error 6.077276e-07, alpha_max=1.000
# ** elastic = 0.000, surface = 0.137, total = 0.138
# ** Converged in 4 iterations, error = 0.000
#
# ** Load step: t=1.98
# Iteration 1, error 3.230763e-03, alpha_max=1.000
# Iteration 2, error 2.131889e-05, alpha_max=1.000
# Iteration 3, error 4.744451e-07, alpha_max=1.000
# ** elastic = 0.000, surface = 0.137, total = 0.138
# ** Converged in 4 iterations, error = 0.000
#
# ** Load step: t=2.07
# Iteration 1, error 2.844810e-03, alpha_max=1.000
# Iteration 2, error 1.757320e-05, alpha_max=1.000
# Iteration 3, error 4.232452e-07, alpha_max=1.000
# ** elastic = 0.000, surface = 0.137, total = 0.138
# ** Converged in 4 iterations, error = 0.000
#
# ** Load step: t=2.16
# Iteration 1, error 2.517760e-03, alpha_max=1.000
# Iteration 2, error 1.543133e-05, alpha_max=1.000
# Iteration 3, error 5.426553e-07, alpha_max=1.000
# ** elastic = 0.000, surface = 0.137, total = 0.138
# ** Converged in 4 iterations, error = 0.000
#
# ** Load step: t=2.24
# Iteration 1, error 2.238665e-03, alpha_max=1.000
# Iteration 2, error 1.108071e-05, alpha_max=1.000
# Iteration 3, error 8.200379e-06, alpha_max=1.000
# ** elastic = 0.000, surface = 0.137, total = 0.138
# ** Converged in 4 iterations, error = 0.000
#
# ** Load step: t=2.33
# Iteration 1, error 1.998745e-03, alpha_max=1.000
# Iteration 2, error 1.817038e-05, alpha_max=1.000
# Iteration 3, error 8.625217e-06, alpha_max=1.000
# ** elastic = 0.000, surface = 0.138, total = 0.138
# ** Converged in 4 iterations, error = 0.000
#
# ** Load step: t=2.41
# Iteration 1, error 1.792267e-03, alpha_max=1.000
# Iteration 2, error 1.399967e-05, alpha_max=1.000
# Iteration 3, error 8.334724e-06, alpha_max=1.000
# ** elastic = 0.000, surface = 0.138, total = 0.138
# ** Converged in 4 iterations, error = 0.000
#
# ** Load step: t=2.50
# Iteration 1, error 1.613309e-03, alpha_max=1.000
# Iteration 2, error 1.150259e-05, alpha_max=1.000
# Iteration 3, error 1.043093e-05, alpha_max=1.000
# Iteration 4, error 1.269192e-07, alpha_max=1.000
# ** elastic = 0.000, surface = 0.138, total = 0.138
# ** Converged in 5 iterations, error = 0.000

# %%
plt.figure(figsize=(10, 8))
plot(alpha)

# %%
def plot_stress():
    plt.plot(loads, react_top, 'b*', linewidth = 2)
    plt.xlabel('Displacement')
    plt.ylabel('Force')

def plot_energy():
    p1, = plt.plot(loads, energies['elastic'],'b*',linewidth=2)
    p2, = plt.plot(loads, energies['surface'],'r^',linewidth=2)
    p3, = plt.plot(loads, energies['total'],'ko',linewidth=2)
    plt.legend([p1, p2, p3], ["Elastic","Dissipated","Total"])
    plt.xlabel('Displacement')
    plt.ylabel('Energies')


def plot_energy_stress():
    plt.subplot(211)
    plot_stress()
    plt.subplot(212)
    plot_energy()
    plt.savefig('./energies_force.png')
    plt.show()

plot_energy_stress()
